# %%
import pandas as pd
import re
import stanza
stanza.download("lt")
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt_tab')
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-12-14 10:47:59 INFO: Downloaded file to /Users/urtejakubauskaite/stanza_resources/resources.json
# 2024-12-14 10:47:59 INFO: Downloading default packages for language: lt (Lithuanian) ...
# 2024-12-14 10:48:02 INFO: File exists: /Users/urtejakubauskaite/stanza_resources/lt/default.zip
# 2024-12-14 10:48:13 INFO: Finished downloading models and saved to /Users/urtejakubauskaite/stanza_resources
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/urtejakubauskaite/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/urtejakubauskaite/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/urtejakubauskaite/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
#Converting my dataset from .parquet to .csv
df = pd.read_parquet('train-00000-of-00001.parquet')
df.to_csv('train-00000-of-00001.csv')

# %% [markdown]
# # Original Dataset

# %%
# Opening the file
file_path = 'train-00000-of-00001.csv'
data = pd.read_csv(file_path)
print(data.head())
# Out:
#    line_count                            en                  lt
# 0           1            Meeting in Vilnius  Sutikimas Vilniuje
# 1           2           That is the address        Štai adresas
# 2           3       Where does Sigita live?  Kur gyvena Sigita?
# 3           4  I am looking for Miss Sigita   Aš ieškau Sigitos
# 4           5                 Just a moment            Minutėlę

# %%
# Printing the number of columns
num_columns = data.shape[1]
print(f"The number of columns is: {num_columns}")
# Out:
# The number of columns is: 3

# %%
# Getting Lithuanian sentences
sentences = data.iloc[:, -1]
print(sentences.head())
# Out:
# 0    Sutikimas Vilniuje
# 1          Štai adresas
# 2    Kur gyvena Sigita?
# 3     Aš ieškau Sigitos
# 4              Minutėlę
# Name: lt, dtype: object

# %%
# Splitting rows into sentences and counting words
def split_and_count(sentences):
    all_sentences = []
    for row in sentences:
        split_sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<!\b\w\.)[.?!]', row)
        split_sentences = [sentence.strip() for sentence in split_sentences if sentence.strip()]
        all_sentences.extend(split_sentences)
    return all_sentences

# Selecting only the sentences in the original dataset
original_sentences = sentences[1:499]

# Getting a list of all Lithuanian sentences
all_sentences = split_and_count(original_sentences)

# Counting words in each sentence
sentence_lengths = [len(sentence.split()) for sentence in all_sentences]

# Computing the average sentence length
average_length = sum(sentence_lengths) / len(sentence_lengths) if sentence_lengths else 0

print(f"Average sentence length for the original dataset is {average_length:.2f} words.")
# Out:
# Average sentence length for the original dataset is 3.75 words.

# %%
# Splitting rows into sentences and counting tokens
# Tokenizing each sentence and counting the tokens
sentence_lengths = [len(word_tokenize(sentence)) for sentence in all_sentences]

# Computing the average token count per sentence
average_tokens = sum(sentence_lengths) / len(sentence_lengths) if sentence_lengths else 0

print(f"Average token count per sentence for the original dataset is {average_tokens:.2f} tokens.")
# Out:
# Average token count per sentence for the original dataset is 4.07 tokens.

# %%
# Loading the Lithuanian pipeline
nlp = stanza.Pipeline("lt")

# POS tagging
pos_tags = []
for sentence in all_sentences:
    doc = nlp(sentence)
    for sentence in doc.sentences:
        for word in sentence.words:
            print(f"Word: {word.text}, POS: {word.upos}")
            pos_tags.append(word.upos)
# Out:
# 2024-12-14 10:29:24 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.9.0.json:   0%|   …
# 2024-12-14 10:29:24 INFO: Downloaded file to /Users/urtejakubauskaite/stanza_resources/resources.json
# 2024-12-14 10:29:26 INFO: Loading these models for language: lt (Lithuanian):
# ================================
# | Processor | Package          |
# --------------------------------
# | tokenize  | alksnis          |
# | pos       | alksnis_nocharlm |
# | lemma     | alksnis_nocharlm |
# | depparse  | alksnis_nocharlm |
# ================================
#
# 2024-12-14 10:29:26 INFO: Using device: cpu
# 2024-12-14 10:29:26 INFO: Loading: tokenize
# 2024-12-14 10:29:31 INFO: Loading: pos
# 2024-12-14 10:29:32 INFO: Loading: lemma
# 2024-12-14 10:29:32 INFO: Loading: depparse
# 2024-12-14 10:29:32 INFO: Done loading processors!
# Word: Štai, POS: PART
# Word: adresas, POS: NOUN
# Word: Kur, POS: ADV
# Word: gyvena, POS: VERB
# Word: Sigita, POS: PROPN
# Word: Aš, POS: PRON
# Word: ieškau, POS: VERB
# Word: Sigitos, POS: NOUN
# Word: Minutėlę, POS: NOUN
# Word: Atsiprašau, POS: VERB
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: kas, POS: PRON
# Word: Jūs, POS: PRON
# Word: Alio, POS: NOUN
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: esu, POS: AUX
# Word: Jonas, POS: PROPN
# Word: Vasiliauskas, POS: PROPN
# Word: Aš, POS: PRON
# Word: esu, POS: AUX
# Word: iš, POS: ADP
# Word: Lietuvos, POS: PROPN
# Word: Sveiki, POS: ADJ
# Word: atvykę, POS: VERB
# Word: į, POS: ADP
# Word: Vilnių, POS: PROPN
# Word: Jums, POS: PRON
# Word: užsakytas, POS: VERB
# Word: kambarys, POS: NOUN
# Word: viešbutyje, POS: NOUN
# Word: Viešbutis, POS: NOUN
# Word: vadinasi, POS: VERB
# Word: ", POS: PUNCT
# Word: Žaliasis, POS: ADJ
# Word: tiltas, POS: NOUN
# Word: ", POS: PUNCT
# Word: Viešbutis, POS: NOUN
# Word: nedidelis, POS: ADJ
# Word: Jis, POS: PRON
# Word: mažas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: patogus, POS: ADJ
# Word: Kur, POS: ADV
# Word: yra, POS: AUX
# Word: viešbutis, POS: NOUN
# Word: Lengva, POS: ADJ
# Word: surasti, POS: VERB
# Word: ,, POS: PUNCT
# Word: jis, POS: PRON
# Word: netoli, POS: ADV
# Word: Pasukite, POS: VERB
# Word: į, POS: ADP
# Word: Kalvarijos, POS: PROPN
# Word: gatvę, POS: NOUN
# Word: ,, POS: PUNCT
# Word: jis, POS: PRON
# Word: už, POS: ADP
# Word: šimto, POS: NUM
# Word: metrų, POS: NOUN
# Word: dešinėje, POS: NOUN
# Word: Labanaktis, POS: NOUN
# Word: Iki, POS: ADP
# Word: Viešbutyje, POS: NOUN
# Word: Jus, POS: PRON
# Word: sveikina, POS: VERB
# Word: registratorė, POS: NOUN
# Word: Aš, POS: PRON
# Word: Jūsų, POS: PRON
# Word: laukiau, POS: VERB
# Word: Ar, POS: PART
# Word: turite, POS: VERB
# Word: pasą, POS: NOUN
# Word: Jūsų, POS: PRON
# Word: kambario, POS: NOUN
# Word: numeris, POS: NOUN
# Word: septintas, POS: VERB
# Word: Jis, POS: PRON
# Word: antrame, POS: NUM
# Word: aukšte, POS: NOUN
# Word: Jūsų, POS: PRON
# Word: kambarys, POS: NOUN
# Word: Štai, POS: PART
# Word: Jūsų, POS: PRON
# Word: kambarys, POS: NOUN
# Word: Kambarys, POS: NOUN
# Word: puikus, POS: ADJ
# Word: Ant, POS: ADP
# Word: lovos, POS: NOUN
# Word: -, POS: PUNCT
# Word: viena, POS: PRON
# Word: pagalvė, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: norite, POS: VERB
# Word: antrą, POS: NUM
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Užteks, POS: VERB
# Word: vienos, POS: PRON
# Word: Vonia, POS: NOUN
# Word: yra, POS: AUX
# Word: šalia, POS: ADP
# Word: kambario, POS: NOUN
# Word: Ar, POS: PART
# Word: norite, POS: VERB
# Word: išsimaudyti, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: būtų, POS: AUX
# Word: gerai, POS: ADV
# Word: Štai, POS: PART
# Word: muilas, POS: NOUN
# Word: ir, POS: CCONJ
# Word: vonios, POS: NOUN
# Word: rankšluostis, POS: VERB
# Word: Ačiū, POS: PRON
# Word: Rankšluostis, POS: VERB
# Word: didelis, POS: ADJ
# Word: ir, POS: CCONJ
# Word: minkštas, POS: ADJ
# Word: Nuostabu, POS: ADJ
# Word: Viešbučio, POS: NOUN
# Word: registratūroje, POS: NOUN
# Word: Atsiprašau, POS: VERB
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: nepatenkintas, POS: VERB
# Word: kambariu, POS: NOUN
# Word: O, POS: CCONJ
# Word: kas, POS: PRON
# Word: negerai, POS: ADV
# Word: Negaliu, POS: VERB
# Word: miegoti, POS: VERB
# Word: Girdėti, POS: VERB
# Word: triukšmas, POS: NOUN
# Word: gatvėje, POS: NOUN
# Word: Kur, POS: ADV
# Word: yra, POS: AUX
# Word: Jūsų, POS: PRON
# Word: kambarys, POS: NOUN
# Word: Pirmajame, POS: NUM
# Word: aukšte, POS: NOUN
# Word: Mano, POS: PRON
# Word: kambarys, POS: NOUN
# Word: septintas, POS: VERB
# Word: Ar, POS: PART
# Word: norite, POS: VERB
# Word: kambario, POS: NOUN
# Word: penktame, POS: NOUN
# Word: aukšte, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: būtų, POS: AUX
# Word: gerai, POS: ADV
# Word: Ryte, POS: NOUN
# Word: Labas, POS: PROPN
# Word: rytas, POS: PROPN
# Word: Ar, POS: PART
# Word: gerai, POS: ADV
# Word: miegojote, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Puikus, POS: ADJ
# Word: oras, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ar, POS: CCONJ
# Word: ne, POS: PART
# Word: Nustojo, POS: VERB
# Word: lyti, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: puiki, POS: ADJ
# Word: diena, POS: NOUN
# Word: Jau, POS: ADV
# Word: gana, POS: ADV
# Word: šilta, POS: ADJ
# Word: Kiek, POS: ADV
# Word: dabar, POS: ADV
# Word: laiko, POS: NOUN
# Word: Tuoj, POS: ADV
# Word: pažiūrėsiu, POS: VERB
# Word: Tuoj, POS: ADV
# Word: dešimt, POS: PRON
# Word: Pusryčiai, POS: NOUN
# Word: Labas, POS: NOUN
# Word: rytas, POS: PROPN
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: miegojote, POS: VERB
# Word: Labas, POS: PROPN
# Word: rytas, POS: PROPN
# Word: Ką, POS: PRON
# Word: turite, POS: VERB
# Word: pusryčiams, POS: NOUN
# Word: Turime, POS: VERB
# Word: šviežių, POS: NOUN
# Word: bandelių, POS: NOUN
# Word: :, POS: PUNCT
# Word: bandelių, POS: NOUN
# Word: su, POS: ADP
# Word: aguonomis, POS: NOUN
# Word: arba, POS: CCONJ
# Word: minkštų, POS: VERB
# Word: bandelių, POS: NOUN
# Word: su, POS: ADP
# Word: sviestu, POS: VERB
# Word: ,, POS: PUNCT
# Word: medumi, POS: NOUN
# Word: ar, POS: CCONJ
# Word: uogiene, POS: NOUN
# Word: Hm, POS: X
# Word: ,, POS: PUNCT
# Word: kvepia, POS: VERB
# Word: puikiai, POS: ADV
# Word: Norėčiau, POS: VERB
# Word: dviejų, POS: NUM
# Word: Vieną, POS: PRON
# Word: bandelę, POS: NOUN
# Word: su, POS: ADP
# Word: aguonomis, POS: NOUN
# Word: ir, POS: CCONJ
# Word: vieną, POS: PRON
# Word: minkštą, POS: NOUN
# Word: su, POS: ADP
# Word: sviestu, POS: NOUN
# Word: ir, POS: CCONJ
# Word: medumi, POS: NOUN
# Word: Taip, POS: PART
# Word: pat, POS: X
# Word: norėčiau, POS: VERB
# Word: stiklinę, POS: ADJ
# Word: apelsinų, POS: ADJ
# Word: sulčių, POS: NOUN
# Word: ir, POS: CCONJ
# Word: puodelį, POS: NOUN
# Word: kavos, POS: NOUN
# Word: Dar, POS: ADV
# Word: kavos, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Padavėjas, POS: NOUN
# Word: šypsosi, POS: VERB
# Word: Kur, POS: ADV
# Word: Jūs, POS: PRON
# Word: gyvenate, POS: VERB
# Word: Aš, POS: PRON
# Word: gyvenu, POS: VERB
# Word: Toronte, POS: PROPN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: pirmą, POS: NUM
# Word: kartą, POS: NOUN
# Word: Vilniuje, POS: PROPN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: man, POS: PRON
# Word: patinka, POS: VERB
# Word: Vilnius, POS: PROPN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: mane, POS: PRON
# Word: suprantate, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: Jūs, POS: PRON
# Word: puikiai, POS: ADV
# Word: kalbate, POS: VERB
# Word: lietuviškai, POS: ADV
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: daug, POS: ADV
# Word: suprantu, POS: VERB
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: kalbėkite, POS: VERB
# Word: lėčiau, POS: ADV
# Word: prašom, POS: VERB
# Word: Laikrodis, POS: NOUN
# Word: Dabar, POS: ADV
# Word: dešimt, POS: NUM
# Word: valandų, POS: NOUN
# Word: Penkiolika, POS: NUM
# Word: minučių, POS: NOUN
# Word: po, POS: ADP
# Word: dešimtos, POS: NOUN
# Word: Ketvirtis, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Dešimt, POS: NUM
# Word: valandų, POS: NOUN
# Word: trisdešimt, POS: NUM
# Word: minučių, POS: NOUN
# Word: arba, POS: CCONJ
# Word: puse, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Dešimt, POS: NUM
# Word: valandų, POS: NOUN
# Word: keturiasdešimt, POS: NUM
# Word: penkios, POS: NUM
# Word: minutės, POS: NOUN
# Word: arba, POS: CCONJ
# Word: be, POS: ADP
# Word: penkiolikos, POS: NUM
# Word: minučių, POS: NOUN
# Word: vienuolika, POS: PRON
# Word: Pokalbis, POS: NOUN
# Word: telefonu, POS: NOUN
# Word: Sveika, POS: ADJ
# Word: Sigita, POS: PROPN
# Word: ,, POS: PUNCT
# Word: čia, POS: ADV
# Word: Katlyna, POS: PROPN
# Word: Sveika, POS: ADJ
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: sekasi, POS: VERB
# Word: Ačiū, POS: VERB
# Word: ,, POS: PUNCT
# Word: puikiai, POS: ADV
# Word: Aš, POS: PRON
# Word: einu, POS: VERB
# Word: dabar, POS: ADV
# Word: apsipirkti, POS: VERB
# Word: Aš, POS: PRON
# Word: taip, POS: ADV
# Word: pat, POS: X
# Word: Ruošiuosi, POS: VERB
# Word: eiti, POS: VERB
# Word: į, POS: ADP
# Word: turgų, POS: NOUN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: šiandien, POS: ADV
# Word: juk, POS: PART
# Word: turgaus, POS: NOUN
# Word: diena, POS: NOUN
# Word: Tada, POS: ADV
# Word: aš, POS: PRON
# Word: irgi, POS: ADV
# Word: eisiu, POS: VERB
# Word: į, POS: ADP
# Word: turgų, POS: NOUN
# Word: Ar, POS: PART
# Word: susitiksime, POS: VERB
# Word: Ar, POS: PART
# Word: tai, POS: DET
# Word: įmanoma, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: kur, POS: ADV
# Word: galėtumėm, POS: VERB
# Word: susitikti, POS: VERB
# Word: Prie, POS: ADP
# Word: pirmo, POS: NUM
# Word: prekystalio, POS: NOUN
# Word: Kada, POS: ADV
# Word: Tiksliai, POS: ADV
# Word: dešimtą, POS: NOUN
# Word: Ar, POS: PART
# Word: tinka, POS: VERB
# Word: Kiek, POS: ADV
# Word: dabar, POS: ADV
# Word: Greitai, POS: ADV
# Word: dešimt, POS: NUM
# Word: Iki, POS: ADP
# Word: Greitai, POS: ADV
# Word: pasimatysime, POS: VERB
# Word: Turguje, POS: NOUN
# Word: Ach, POS: X
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: puikiai, POS: ADV
# Word: kvepia, POS: VERB
# Word: braškės, POS: NOUN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: braškės, POS: NOUN
# Word: mano, POS: PRON
# Word: mėgstamiausios, POS: ADJ
# Word: uogos, POS: NOUN
# Word: Bet, POS: CCONJ
# Word: Ana, POS: NOUN
# Word: ,, POS: PUNCT
# Word: braškės, POS: NOUN
# Word: ne, POS: PART
# Word: šviežios, POS: ADJ
# Word: Ne, POS: PART
# Word: šviežios, POS: ADJ
# Word: Kaip, POS: ADV
# Word: gaila, POS: ADV
# Word: Prie, POS: ADP
# Word: daržovių, POS: NOUN
# Word: prekystalio, POS: ADJ
# Word: Man, POS: PRON
# Word: prašau, POS: VERB
# Word: ilgą, POS: ADJ
# Word: agurką, POS: NOUN
# Word: Dar, POS: PART
# Word: ką, POS: PRON
# Word: nors, POS: X
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: prašau, POS: VERB
# Word: gražių, POS: ADJ
# Word: salotų, POS: NOUN
# Word: Trys, POS: NUM
# Word: litai, POS: NOUN
# Word: Štai, POS: PART
# Word: dvidešimt, POS: NUM
# Word: litų, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Dešimt, POS: NUM
# Word: litų, POS: NOUN
# Word: ir, POS: CCONJ
# Word: vienas, POS: PRON
# Word: ,, POS: PUNCT
# Word: du, POS: NUM
# Word: ,, POS: PUNCT
# Word: trys, POS: NUM
# Word: ,, POS: PUNCT
# Word: keturi, POS: NUM
# Word: ,, POS: PUNCT
# Word: penki, POS: NUM
# Word: ,, POS: PUNCT
# Word: šeši, POS: NUM
# Word: ,, POS: PUNCT
# Word: septyni, POS: NUM
# Word: litai, POS: NOUN
# Word: grąžos, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Pas, POS: ADP
# Word: Sigitą, POS: PROPN
# Word: Aš, POS: PRON
# Word: alkanas(, POS: ADJ
# Word: -a, POS: NOUN
# Word: ), POS: PUNCT
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: tu, POS: PRON
# Word: Taip, POS: ADV
# Word: Kada, POS: ADV
# Word: priešpiečiai, POS: NOUN
# Word: Už, POS: ADP
# Word: kelių, POS: NUM
# Word: minučių, POS: NOUN
# Word: Saulė, POS: NOUN
# Word: šviečia, POS: VERB
# Word: Galėtumėm, POS: VERB
# Word: valgyti, POS: VERB
# Word: balkone, POS: NOUN
# Word: Puiku, POS: ADJ
# Word: Aš, POS: PRON
# Word: padengsiu, POS: VERB
# Word: stalą, POS: NOUN
# Word: Ką, POS: PRON
# Word: mes, POS: PRON
# Word: valgysim, POS: VERB
# Word: Šeduvos, POS: PROPN
# Word: sūrį, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kiaušinius, POS: NOUN
# Word: ir, POS: CCONJ
# Word: salotas, POS: NOUN
# Word: Gal, POS: PART
# Word: norėtum, POS: VERB
# Word: omleto, POS: PUNCT
# Word: Omleto, POS: PROPN
# Word: Ačiū, POS: VERB
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: nemėgstu, POS: VERB
# Word: Aš, POS: PRON
# Word: dar, POS: ADV
# Word: turiu, POS: VERB
# Word: keletą, POS: PRON
# Word: bandelių, POS: NOUN
# Word: Porą, POS: NOUN
# Word: bandelių, POS: NOUN
# Word: prašom, POS: VERB
# Word: Ar, POS: PART
# Word: galėtumėm, POS: VERB
# Word: šiandien, POS: ADV
# Word: susitikti, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: galim, POS: VERB
# Word: Gal, POS: PART
# Word: 9, POS: NUM
# Word: valandą, POS: NOUN
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: man, POS: PRON
# Word: netinka, POS: VERB
# Word: Aš, POS: PRON
# Word: norėčiau, POS: VERB
# Word: eiti, POS: VERB
# Word: apsipirkti, POS: VERB
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: parduotuvės, POS: NOUN
# Word: dirba, POS: VERB
# Word: nuo, POS: ADP
# Word: 8:30, POS: NUM
# Word: Tada, POS: ADV
# Word: būtų, POS: AUX
# Word: gerai, POS: ADV
# Word: puse, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Puiku, POS: ADJ
# Word: ,, POS: PUNCT
# Word: puse, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Kur, POS: ADV
# Word: mes, POS: PRON
# Word: susitiksime, POS: VERB
# Word: Gal, POS: PART
# Word: prie, POS: ADP
# Word: Hermio, POS: NOUN
# Word: banko, POS: NOUN
# Word: Oi, POS: VERB
# Word: ne, POS: PART
# Word: ,, POS: PUNCT
# Word: ne, POS: PART
# Word: ten, POS: ADV
# Word: Geriau, POS: ADV
# Word: kitoje, POS: PRON
# Word: pusėje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: Neringos, POS: ADJ
# Word: kavinėje, POS: NOUN
# Word: Gerai, POS: ADV
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: būsiu, POS: VERB
# Word: ten, POS: ADV
# Word: puse, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Vyriškų, POS: ADJ
# Word: drabužių, POS: NOUN
# Word: parduotuvėje, POS: NOUN
# Word: Laba, POS: PROPN
# Word: diena, POS: NOUN
# Word: Kuo, POS: PRON
# Word: galiu, POS: VERB
# Word: padėti, POS: VERB
# Word: Norėčiau, POS: VERB
# Word: keletą, POS: PRON
# Word: porų, POS: NOUN
# Word: medvilninių, POS: ADJ
# Word: kojinių, POS: NOUN
# Word: Kokio, POS: DET
# Word: dydžio, POS: NOUN
# Word: Aš, POS: PRON
# Word: nešioju, POS: VERB
# Word: 43, POS: NUM
# Word: dydį, POS: NOUN
# Word: Štai, POS: PART
# Word: šitose, POS: PRON
# Word: yra, POS: VERB
# Word: 70, POS: NUM
# Word: %, POS: X
# Word: medvilnės, POS: NOUN
# Word: ir, POS: CCONJ
# Word: 30, POS: NUM
# Word: %, POS: X
# Word: neilono, POS: PUNCT
# Word: Mes, POS: PRON
# Word: neturime, POS: VERB
# Word: grynai, POS: ADV
# Word: medvilninių, POS: ADJ
# Word: Jos, POS: PRON
# Word: nepraktiškos, POS: ADJ
# Word: Atsiprašome, POS: VERB
# Word: Gaila, POS: ADV
# Word: Viso, POS: DET
# Word: gero, POS: ADV
# Word: Neringos, POS: PROPN
# Word: kavinėje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kavos, POS: NOUN
# Word: užsakymas, POS: NOUN
# Word: Galiu, POS: VERB
# Word: Jus, POS: PRON
# Word: pakviesti, POS: VERB
# Word: puodukui, POS: NOUN
# Word: kavos, POS: NOUN
# Word: Ačiū, POS: VERB
# Word: ,, POS: PUNCT
# Word: Jūs, POS: PRON
# Word: labai, POS: ADV
# Word: maloni, POS: ADJ
# Word: Pyragaičiai, POS: NOUN
# Word: labai, POS: ADV
# Word: skanūs, POS: ADJ
# Word: Norite, POS: VERB
# Word: dar, POS: PART
# Word: gabaliuko, POS: NOUN
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Tik, POS: PART
# Word: juodos, POS: ADJ
# Word: kavos, POS: NOUN
# Word: ,, POS: PUNCT
# Word: prašom, POS: VERB
# Word: Padavėjau, POS: VERB
# Word: ,, POS: PUNCT
# Word: puodelį, POS: NOUN
# Word: juodos, POS: ADJ
# Word: kavos, POS: NOUN
# Word: be, POS: ADP
# Word: grietinėlės, POS: NOUN
# Word: ir, POS: CCONJ
# Word: kavinuką, POS: NOUN
# Word: kavos, POS: NOUN
# Word: prašom, POS: NOUN
# Word: Galite, POS: VERB
# Word: man, POS: PRON
# Word: paduoti, POS: VERB
# Word: cukraus, POS: NOUN
# Word: Prašau, POS: VERB
# Word: Priėmime, POS: NOUN
# Word: Štai, POS: PART
# Word: vynas, POS: NOUN
# Word: Ar, POS: PART
# Word: norėtumėte, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: prašau, POS: VERB
# Word: Ateina, POS: VERB
# Word: mūsų, POS: PRON
# Word: šeimininkė, POS: NOUN
# Word: Laba, POS: PROPN
# Word: diena, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ponia, POS: PROPN
# Word: Becker, POS: PROPN
# Word: Malonu, POS: ADJ
# Word: Jus, POS: PRON
# Word: matyti, POS: VERB
# Word: Labai, POS: ADV
# Word: šilta, POS: ADJ
# Word: šiandien, POS: ADV
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: ne, POS: PART
# Word: tiesa, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: iš, POS: ADV
# Word: tikrųjų, POS: X
# Word: Bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: mėgstu, POS: VERB
# Word: šiltą, POS: ADJ
# Word: orą, POS: NOUN
# Word: Tikrai, POS: ADV
# Word: karšta, POS: ADJ
# Word: šiandien, POS: ADV
# Word: Jus, POS: PRON
# Word: su, POS: ADP
# Word: švarku, POS: NOUN
# Word: ir, POS: CCONJ
# Word: kaklaraiščiu, POS: NOUN
# Word: Galite, POS: VERB
# Word: nusirengti, POS: VERB
# Word: ,, POS: PUNCT
# Word: jei, POS: SCONJ
# Word: norite, POS: VERB
# Word: Universalinėje, POS: ADJ
# Word: parduotuvėje, POS: NOUN
# Word: ;, POS: PUNCT
# Word: ką, POS: PRON
# Word: nors, POS: X
# Word: pasimatuoti, POS: VERB
# Word: Ši, POS: DET
# Word: suknelė, POS: NOUN
# Word: 40, POS: NUM
# Word: dydžio, POS: NOUN
# Word: Ji, POS: PRON
# Word: per, POS: PART
# Word: maža, POS: ADJ
# Word: man, POS: PRON
# Word: Ar, POS: PART
# Word: neturite, POS: VERB
# Word: 42, POS: NUM
# Word: dydžio, POS: NOUN
# Word: Gaila, POS: ADV
# Word: ,, POS: PUNCT
# Word: neturime, POS: VERB
# Word: Bet, POS: CCONJ
# Word: pasimatuokite, POS: VERB
# Word: Gal, POS: PART
# Word: tiks, POS: VERB
# Word: Na, POS: INTJ
# Word: gerai, POS: ADV
# Word: Kur, POS: ADV
# Word: galima, POS: VERB
# Word: pasimatuoti, POS: VERB
# Word: Štai, POS: PART
# Word: ten, POS: ADV
# Word: ,, POS: PUNCT
# Word: prie, POS: ADP
# Word: didelio, POS: ADJ
# Word: veidrodžio, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Viešbutis, POS: NOUN
# Word: Astorija, POS: PROPN
# Word: Užsakyti, POS: VERB
# Word: kambarį, POS: NOUN
# Word: (, POS: PUNCT
# Word: telefonu, POS: NOUN
# Word: ), POS: PUNCT
# Word: Viešbutis, POS: NOUN
# Word: Astorija, POS: PROPN
# Word: ,, POS: PUNCT
# Word: Berlynas, POS: PROPN
# Word: Kuo, POS: PRON
# Word: galiu, POS: VERB
# Word: Jums, POS: PRON
# Word: padėti, POS: VERB
# Word: Ar, POS: PART
# Word: turite, POS: VERB
# Word: laisvų, POS: ADJ
# Word: kambarių, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: turime, POS: VERB
# Word: Kada, POS: ADV
# Word: norėsite, POS: VERB
# Word: Rytoj, POS: PRON
# Word: vakare, POS: NOUN
# Word: iki, POS: ADP
# Word: ketvirtadienio, POS: NOUN
# Word: ,, POS: PUNCT
# Word: vienai, POS: DET
# Word: nakčiai, POS: NOUN
# Word: Taip, POS: PART
# Word: dar, POS: X
# Word: turime, POS: VERB
# Word: laisvų, POS: ADJ
# Word: kambarių, POS: NOUN
# Word: Kokio, POS: DET
# Word: Jūs, POS: PRON
# Word: norėtumėte, POS: VERB
# Word: Dvi, POS: NUM
# Word: vienutes, POS: NOUN
# Word: su, POS: ADP
# Word: voniomis, POS: NOUN
# Word: Dvi, POS: NUM
# Word: vienutes, POS: NOUN
# Word: su, POS: ADP
# Word: voniomis, POS: NOUN
# Word: Jūsų, POS: PRON
# Word: pavardė, POS: NOUN
# Word: Vilsonas, POS: PROPN
# Word: ir, POS: CCONJ
# Word: Holzas, POS: PROPN
# Word: Tai, POS: DET
# Word: ponia, POS: VERB
# Word: Holz, POS: VERB
# Word: ir, POS: PART
# Word: aš, POS: PRON
# Word: Aš, POS: PRON
# Word: užrašiau, POS: VERB
# Word: ,, POS: PUNCT
# Word: ponas, POS: NOUN
# Word: Vilsonai, POS: PROPN
# Word: Prašau, POS: VERB
# Word: rytoj, POS: ADV
# Word: kreiptis, POS: VERB
# Word: į, POS: ADP
# Word: registratūrą, POS: NOUN
# Word: iki, POS: ADP
# Word: 14, POS: NUM
# Word: val, POS: PUNCT
# Word: Kitaip, POS: ADV
# Word: mes, POS: PRON
# Word: negarantuojame, POS: VERB
# Word: Jums, POS: PRON
# Word: kambario, POS: NOUN
# Word: Ačiū, POS: VERB
# Word: ,, POS: PUNCT
# Word: viso, POS: DET
# Word: gero, POS: PRON
# Word: Telegramos, POS: NOUN
# Word: perskaitymas, POS: NOUN
# Word: Čia, POS: ADV
# Word: yra, POS: AUX
# Word: telegrama, POS: NOUN
# Word: Jums, POS: PRON
# Word: Man, POS: PRON
# Word: Keista, POS: ADJ
# Word: Nuo, POS: ADP
# Word: ko, POS: PRON
# Word: Aš, POS: PRON
# Word: nežinau, POS: VERB
# Word: Atidaryk, POS: VERB
# Word: ir, POS: CCONJ
# Word: perskaityk, POS: PROPN
# Word: Atvykstu, POS: VERB
# Word: viena, POS: PRON
# Word: diena, POS: NOUN
# Word: vėliau, POS: ADV
# Word: -, POS: PUNCT
# Word: taškas, POS: NOUN
# Word: -, POS: PUNCT
# Word: pasilik, POS: PUNCT
# Word: Berlyne, POS: PROPN
# Word: -, POS: PUNCT
# Word: taškas, POS: NOUN
# Word: -, POS: PUNCT
# Word: gal, POS: PART
# Word: pasižvalgyk, POS: VERB
# Word: mieste, POS: NOUN
# Word: -, POS: PUNCT
# Word: taškas, POS: NOUN
# Word: -, POS: PUNCT
# Word: Pasimatysime, POS: VERB
# Word: -, POS: PUNCT
# Word: taškas, POS: NOUN
# Word: -, POS: PUNCT
# Word: Peter, POS: X
# Word: H, POS: X
# Word: Taigi, POS: PART
# Word: ,, POS: PUNCT
# Word: pasilieki, POS: VERB
# Word: Na, POS: INTJ
# Word: ,, POS: PUNCT
# Word: žinoma, POS: VERB
# Word: Dar, POS: PART
# Word: viena, POS: PRON
# Word: žinutė, POS: NOUN
# Word: Klausyk, POS: VERB
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: atvykstu, POS: VERB
# Word: ar, POS: CCONJ
# Word: Tu, POS: PRON
# Word: atvyksti, POS: PUNCT
# Word: Savaitgalyje, POS: NOUN
# Word: ar, POS: CCONJ
# Word: penktadienį, POS: NOUN
# Word: Pilyje, POS: NOUN
# Word: ar, POS: CCONJ
# Word: pilies, POS: NOUN
# Word: sode, POS: NOUN
# Word: Kur, POS: ADV
# Word: susitinkame, POS: VERB
# Word: Kas, POS: PRON
# Word: tai, POS: DET
# Word: siunčia, POS: VERB
# Word: Neįsivaizduoju, POS: VERB
# Word: Gal, POS: PART
# Word: dvasia, POS: NOUN
# Word: Labai, POS: ADV
# Word: keista, POS: ADJ
# Word: Kaip, POS: SCONJ
# Word: detektyve, POS: NOUN
# Word: Čia, POS: ADV
# Word: mašinas, POS: NOUN
# Word: statyti, POS: VERB
# Word: draudžiama, POS: VERB
# Word: Aš, POS: PRON
# Word: nežinojau, POS: VERB
# Word: Aš, POS: PRON
# Word: tuoj, POS: ADV
# Word: pat, POS: X
# Word: išvažiuosiu, POS: VERB
# Word: Savaitgaliais, POS: NOUN
# Word: galima, POS: VERB
# Word: O, POS: CCONJ
# Word: kokia, POS: DET
# Word: šiandien, POS: ADV
# Word: diena, POS: NOUN
# Word: Trečiadienis, POS: NOUN
# Word: Gaila, POS: ADV
# Word: Bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: negaliu, POS: VERB
# Word: dvi, POS: NUM
# Word: dienas, POS: NOUN
# Word: laukti, POS: VERB
# Word: Gaila, POS: ADV
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: niekuo, POS: PRON
# Word: negaliu, POS: VERB
# Word: padėti, POS: VERB
# Word: Paklausti, POS: VERB
# Word: apie, POS: ADP
# Word: viešąjį, POS: ADJ
# Word: transportą, POS: NOUN
# Word: Kur, POS: ADV
# Word: Jūs, POS: PRON
# Word: norėtumėte, POS: VERB
# Word: nueiti, POS: VERB
# Word: Į, POS: ADP
# Word: pilį, POS: NOUN
# Word: Metro, POS: NOUN
# Word: ar, POS: CCONJ
# Word: autobusu, POS: NOUN
# Word: O, POS: CCONJ
# Word: kaip, POS: SCONJ
# Word: geriau, POS: ADV
# Word: Metro, POS: NOUN
# Word: -, POS: PUNCT
# Word: greičiau, POS: ADV
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: autobusu, POS: NOUN
# Word: -, POS: PUNCT
# Word: pigiau, POS: ADV
# Word: Tada, POS: ADV
# Word: autobusu, POS: NOUN
# Word: Kuris, POS: DET
# Word: autobusas, POS: NOUN
# Word: 48, POS: NUM
# Word: numeris, POS: NOUN
# Word: važiuoja, POS: VERB
# Word: tiesiai, POS: ADV
# Word: prie, POS: ADP
# Word: pilies, POS: NOUN
# Word: Kur, POS: ADV
# Word: sustojimas, POS: NOUN
# Word: Sustojimas, POS: NOUN
# Word: čia, POS: PART
# Word: pat, POS: X
# Word: ,, POS: PUNCT
# Word: už, POS: ADP
# Word: kampo, POS: NOUN
# Word: ,, POS: PUNCT
# Word: dešinėje, POS: ADJ
# Word: pusėje, POS: NOUN
# Word: Dešinėje, POS: NOUN
# Word: Aš, POS: PRON
# Word: visai, POS: ADV
# Word: užmiršau, POS: VERB
# Word: Didelis, POS: ADJ
# Word: ačiū, POS: PRON
# Word: Nėr, POS: VERB
# Word: už, POS: ADP
# Word: ką, POS: PRON
# Word: Avarija, POS: NOUN
# Word: Kas, POS: PRON
# Word: atsitiko, POS: VERB
# Word: Avarija, POS: NOUN
# Word: Kanto, POS: PROPN
# Word: gatvėje, POS: NOUN
# Word: Kaip, POS: ADV
# Word: tai, POS: DET
# Word: buvo, POS: VERB
# Word: Šviesoforas, POS: NOUN
# Word: kryžkelėje, POS: NOUN
# Word: nedirba, POS: VERB
# Word: Susidūrė, POS: VERB
# Word: trys, POS: NUM
# Word: automobiliai, POS: NOUN
# Word: Ar, POS: PART
# Word: kas, POS: PRON
# Word: nors, POS: X
# Word: sužeistas, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: du, POS: NUM
# Word: vairuotojai, POS: NOUN
# Word: sunkiai, POS: ADV
# Word: sužeisti, POS: VERB
# Word: ,, POS: PUNCT
# Word: ačiū, POS: VERB
# Word: Dievui, POS: NOUN
# Word: -, POS: PUNCT
# Word: kiti, POS: PRON
# Word: nesunkiai, POS: ADV
# Word: Kada, POS: ADV
# Word: tai, POS: DET
# Word: atsitiko, POS: VERB
# Word: Prieš, POS: ADP
# Word: dešimt, POS: NUM
# Word: minučių, POS: NOUN
# Word: Kažkas, POS: PRON
# Word: iškvietė, POS: VERB
# Word: greitąją, POS: ADJ
# Word: Ji, POS: PRON
# Word: greitai, POS: ADV
# Word: atvyks, POS: VERB
# Word: Tikėkimės, POS: NOUN
# Word: Toks, POS: DET
# Word: didelis, POS: ADJ
# Word: judėjimas, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ar, POS: CCONJ
# Word: ne, POS: PART
# Word: Apie, POS: ADP
# Word: nesusipratimus, POS: VERB
# Word: telefonu, POS: NOUN
# Word: Alio, POS: PROPN
# Word: ,, POS: PUNCT
# Word: Sauer, POS: X
# Word: &, POS: X
# Word: Co, POS: PUNCT
# Word: Labas, POS: PROPN
# Word: rytas, POS: PROPN
# Word: Bekerio, POS: PROPN
# Word: mados, POS: NOUN
# Word: Šiandien, POS: ADV
# Word: gavome, POS: VERB
# Word: Jūsų, POS: PRON
# Word: siuntinį, POS: NOUN
# Word: Apie, POS: ADP
# Word: kurį, POS: DET
# Word: siuntinį, POS: NOUN
# Word: Jūs, POS: PRON
# Word: kalbate, POS: VERB
# Word: Siuntinys, POS: NOUN
# Word: su, POS: ADP
# Word: kojinėmis, POS: NOUN
# Word: Prisimenu, POS: VERB
# Word: Gerai, POS: ADV
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: gavote, POS: VERB
# Word: Visai, POS: ADV
# Word: ne, POS: PART
# Word: gerai, POS: ADV
# Word: Jame, POS: PRON
# Word: 300, POS: NUM
# Word: porų, POS: NOUN
# Word: pilkų, POS: NOUN
# Word: kojinių, POS: NOUN
# Word: Teisingai, POS: ADV
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: neteisingai, POS: ADV
# Word: ,, POS: PUNCT
# Word: panele, POS: PROPN
# Word: Ponia, POS: PROPN
# Word: Ponia, POS: PROPN
# Word: Ernst, POS: PROPN
# Word: Ponia, POS: NOUN
# Word: Ernst, POS: X
# Word: ,, POS: PUNCT
# Word: mes, POS: PRON
# Word: iš, POS: ADV
# Word: tikrųjų, POS: X
# Word: neužsakėme, POS: VERB
# Word: 300, POS: NUM
# Word: porų, POS: NOUN
# Word: pilkų, POS: NOUN
# Word: kojinių, POS: NOUN
# Word: Užsakėte, POS: VERB
# Word: Aš, POS: PRON
# Word: matau, POS: VERB
# Word: knygoje, POS: NOUN
# Word: Ponia, POS: NOUN
# Word: Ernst, POS: X
# Word: ,, POS: PUNCT
# Word: kažkas, POS: PRON
# Word: čia, POS: ADV
# Word: negerai, POS: ADV
# Word: Mes, POS: PRON
# Word: užsakėme, POS: VERB
# Word: 30, POS: NUM
# Word: porų, POS: NOUN
# Word: pilkų, POS: NOUN
# Word: kojinių, POS: NOUN
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: ne, POS: PART
# Word: 300, POS: NUM
# Word: Ne, POS: PART
# Word: 300, POS: NUM
# Word: Ach, POS: X
# Word: ,, POS: PUNCT
# Word: išsiųskite, POS: VERB
# Word: mums, POS: PRON
# Word: ,, POS: PUNCT
# Word: jeigu, POS: SCONJ
# Word: Jūs, POS: PRON
# Word: jų, POS: PRON
# Word: nenorite, POS: VERB
# Word: Viso, POS: DET
# Word: gero, POS: ADV
# Word: Aš, POS: PRON
# Word: tiesiog, POS: ADV
# Word: nežinau, POS: VERB
# Word: ,, POS: PUNCT
# Word: ką, POS: PRON
# Word: pasakyti, POS: VERB
# Word: Bet, POS: CCONJ
# Word: ką, POS: PRON
# Word: aš, POS: PRON
# Word: galiu, POS: VERB
# Word: padaryti, POS: VERB
# Word: Susitikimas, POS: NOUN
# Word: lėktuve, POS: NOUN
# Word: Sveika, POS: ADJ
# Word: ,, POS: PUNCT
# Word: ponia, POS: NOUN
# Word: Šmidt, POS: PUNCT
# Word: Koks, POS: DET
# Word: netikėtumas, POS: NOUN
# Word: Jus, POS: PRON
# Word: čia, POS: ADV
# Word: lėktuve, POS: NOUN
# Word: sutikti, POS: VERB
# Word: Tikrai, POS: ADV
# Word: Kaip, POS: ADV
# Word: sekasi, POS: VERB
# Word: Puikiai, POS: ADV
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: Jums, POS: PRON
# Word: Kur, POS: ADV
# Word: Jūs, POS: PRON
# Word: vykstate, POS: VERB
# Word: Ruošiuosi, POS: VERB
# Word: aplankyti, POS: VERB
# Word: savo, POS: PRON
# Word: sūnų, POS: NOUN
# Word: Jis, POS: PRON
# Word: gyvena, POS: VERB
# Word: Šveicarijoje, POS: PROPN
# Word: O, POS: CCONJ
# Word: Jūs, POS: PRON
# Word: Aš, POS: PRON
# Word: vėl, POS: ADV
# Word: komandiruotėje, POS: NOUN
# Word: Aš, POS: PRON
# Word: dažnai, POS: ADV
# Word: skrendu, POS: VERB
# Word: šiuo, POS: DET
# Word: maršrutu, POS: NOUN
# Word: Matau, POS: VERB
# Word: Kaip, POS: ADV
# Word: dažnai, POS: ADV
# Word: Maždaug, POS: ADV
# Word: tris, POS: NUM
# Word: kartus, POS: NOUN
# Word: per, POS: ADP
# Word: mėnesį, POS: NOUN
# Word: O, POS: CCONJ
# Word: aš, POS: PRON
# Word: skrendu, POS: VERB
# Word: šiandien, POS: ADV
# Word: antrą, POS: NUM
# Word: kartą, POS: NOUN
# Word: Ne, POS: PART
# Word: nuostabu, POS: ADJ
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: mes, POS: PRON
# Word: ne, POS: PART
# Word: dažnai, POS: ADV
# Word: susitinkame, POS: VERB
# Word: Pokalbis, POS: NOUN
# Word: apie, POS: ADP
# Word: pomėgius, POS: NOUN
# Word: Kuo, POS: PRON
# Word: Jūs, POS: PRON
# Word: domitės, POS: NOUN
# Word: Kaip, POS: ADV
# Word: čia, POS: ADV
# Word: pasakius, POS: VERB
# Word: Aš, POS: PRON
# Word: domiuosi, POS: VERB
# Word: daugeliu, POS: NOUN
# Word: dalykų, POS: NOUN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: domitės, POS: NOUN
# Word: menu, POS: NOUN
# Word: Žiūrint, POS: ADP
# Word: ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: galvoje, POS: NOUN
# Word: Tapybą, POS: NOUN
# Word: O, POS: CCONJ
# Word: taip, POS: ADV
# Word: Man, POS: PRON
# Word: patinka, POS: VERB
# Word: tapyba, POS: NOUN
# Word: Kokia, POS: DET
# Word: tapybos, POS: NOUN
# Word: rūšimi, POS: NOUN
# Word: Jūs, POS: PRON
# Word: daugiausiai, POS: ADV
# Word: domitės, POS: NOUN
# Word: Ekspresionistai, POS: NOUN
# Word: ,, POS: PUNCT
# Word: pavyzdžiui, POS: NOUN
# Word: tokie, POS: DET
# Word: kaip, POS: SCONJ
# Word: Kandinskis, POS: PROPN
# Word: ir, POS: CCONJ
# Word: Šmidt-Rotlufas, POS: PROPN
# Word: Aš, POS: PRON
# Word: juos, POS: PRON
# Word: abu, POS: NUM
# Word: mėgstu, POS: VERB
# Word: Taigi, POS: PART
# Word: ,, POS: PUNCT
# Word: Jūs, POS: PRON
# Word: domitės, POS: NOUN
# Word: tik, POS: PART
# Word: moderniu, POS: ADJ
# Word: menu, POS: NOUN
# Word: O, POS: CCONJ
# Word: ne, POS: PART
# Word: Man, POS: PRON
# Word: patinka, POS: VERB
# Word: ir, POS: PART
# Word: impresionistai, POS: NOUN
# Word: ,, POS: PUNCT
# Word: nors, POS: SCONJ
# Word: ne, POS: PART
# Word: perdaug, POS: PUNCT
# Word: O, POS: CCONJ
# Word: man, POS: PRON
# Word: visai, POS: ADV
# Word: nepatinka, POS: VERB
# Word: tapyba, POS: NOUN
# Word: Aš, POS: PRON
# Word: domiuosi, POS: VERB
# Word: fotografija, POS: NOUN
# Word: Pokalbis, POS: NOUN
# Word: apie, POS: ADP
# Word: orą, POS: NOUN
# Word: Ar, POS: PART
# Word: žinote, POS: VERB
# Word: ,, POS: PUNCT
# Word: koks, POS: DET
# Word: bus, POS: AUX
# Word: oras, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: atsitiktinai, POS: ADV
# Word: perskaičiau, POS: VERB
# Word: orų, POS: NOUN
# Word: prognozę, POS: NOUN
# Word: Koks, POS: DET
# Word: bus, POS: AUX
# Word: oras, POS: NOUN
# Word: Londone, POS: PROPN
# Word: Bus, POS: AUX
# Word: vėsu, POS: ADJ
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: žada, POS: VERB
# Word: pasitaisyti, POS: VERB
# Word: O, POS: CCONJ
# Word: koks, POS: DET
# Word: bus, POS: AUX
# Word: oras, POS: NOUN
# Word: Berlyne, POS: PROPN
# Word: Ž, POS: PROPN
# Word: ada, POS: NOUN
# Word: būti, POS: AUX
# Word: saulėtas, POS: VERB
# Word: ir, POS: CCONJ
# Word: šiltas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: toks, POS: DET
# Word: kaip, POS: SCONJ
# Word: vakar, POS: PUNCT
# Word: Puiki, POS: ADJ
# Word: vasara, POS: NOUN
# Word: Jūs, POS: PRON
# Word: teisus, POS: PROPN
# Word: Jau, POS: ADV
# Word: net, POS: PART
# Word: dabar, POS: ADV
# Word: šilta, POS: ADJ
# Word: Pagal, POS: ADP
# Word: prognozę, POS: NOUN
# Word: bus, POS: AUX
# Word: šiandien, POS: ADV
# Word: 30, POS: NUM
# Word: o, POS: CCONJ
# Word: šilumos, POS: NOUN
# Word: Ar, POS: PART
# Word: Jums, POS: PRON
# Word: patinka, POS: VERB
# Word: Ar, POS: PART
# Word: patinka, POS: VERB
# Word: Jums, POS: PRON
# Word: Berlynas, POS: PROPN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: labai, POS: ADV
# Word: patinka, POS: VERB
# Word: O, POS: CCONJ
# Word: kas, POS: PRON
# Word: daugiausiai, POS: ADV
# Word: patinka, POS: VERB
# Word: Daugiausiai, POS: ADV
# Word: Nacionalinė, POS: ADJ
# Word: galerija, POS: NOUN
# Word: ir, POS: CCONJ
# Word: Šarlotenburgo, POS: PROPN
# Word: pilis, POS: NOUN
# Word: Taip, POS: PART
# Word: pat, POS: X
# Word: patinka, POS: VERB
# Word: pilies, POS: NOUN
# Word: sodas, POS: NOUN
# Word: Ar, POS: PART
# Word: norėtumėte, POS: VERB
# Word: gyventi, POS: VERB
# Word: Berlyne, POS: PROPN
# Word: Tai, POS: DET
# Word: būtų, POS: AUX
# Word: puiku, POS: ADJ
# Word: Aš, POS: PRON
# Word: geriau, POS: ADV
# Word: kalbėčiau, POS: VERB
# Word: vokiškai, POS: ADV
# Word: Kur, POS: ADV
# Word: Jūs, POS: PRON
# Word: gyvenate, POS: VERB
# Word: Aš, POS: PRON
# Word: gyvenu, POS: VERB
# Word: Londone, POS: NOUN
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: Jūs, POS: PRON
# Word: Aš, POS: PRON
# Word: gyvenu, POS: VERB
# Word: čia, POS: ADV
# Word: Šprimetropolyje, POS: NOUN
# Word: jau, POS: PART
# Word: keturis, POS: NUM
# Word: metus, POS: NOUN
# Word: Esu, POS: AUX
# Word: tikras, POS: X
# Word: berlynietis, POS: NOUN
# Word: Apie, POS: ADP
# Word: mokėjimo, POS: NOUN
# Word: būdus, POS: NOUN
# Word: Tai, POS: DET
# Word: bus, POS: AUX
# Word: 125, POS: NUM
# Word: markės, POS: NOUN
# Word: ir, POS: CCONJ
# Word: 50, POS: NUM
# Word: Gaila, POS: ADV
# Word: ,, POS: PUNCT
# Word: prie, POS: ADP
# Word: savęs, POS: PRON
# Word: aš, POS: PRON
# Word: neturiu, POS: VERB
# Word: tiek, POS: ADV
# Word: daug, POS: ADV
# Word: Tai, POS: DET
# Word: nieko, POS: PRON
# Word: Jūs, POS: PRON
# Word: galite, POS: VERB
# Word: mokėti, POS: VERB
# Word: kreditine, POS: ADJ
# Word: kortele, POS: NOUN
# Word: O, POS: CCONJ
# Word: ar, POS: PART
# Word: galiu, POS: VERB
# Word: čekiais, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: jeigu, POS: SCONJ
# Word: jie, POS: PRON
# Word: galiojantys, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: žinoma, POS: VERB
# Word: Gerai, POS: ADV
# Word: Išrašykite, POS: VERB
# Word: tada, POS: ADV
# Word: čekį, POS: NOUN
# Word: Ciles, POS: VERB
# Word: ir, POS: CCONJ
# Word: Ko, POS: PRON
# Word: vardu, POS: NOUN
# Word: Štai, POS: PART
# Word: čekis, POS: NOUN
# Word: ,, POS: PUNCT
# Word: prašau, POS: VERB
# Word: Ach, POS: X
# Word: ,, POS: PUNCT
# Word: Jūs, POS: PRON
# Word: anglas, POS: PROPN
# Word: Bet, POS: CCONJ
# Word: Jūs, POS: PRON
# Word: kalbate, POS: VERB
# Word: puikiai, POS: ADV
# Word: vokiškai, POS: ADV
# Word: Sveikinu, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Apie, POS: ADP
# Word: dovanas, POS: NOUN
# Word: (, POS: PUNCT
# Word: kokybė, POS: NOUN
# Word: ), POS: PUNCT
# Word: Pažiūrėk, POS: VERB
# Word: ,, POS: PUNCT
# Word: kokią, POS: DET
# Word: dovaną, POS: NOUN
# Word: aš, POS: PRON
# Word: nupirkau, POS: VERB
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: piniginė, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ir, POS: CCONJ
# Word: odinė, POS: ADJ
# Word: Kam, POS: ADV
# Word: tai, POS: DET
# Word: Maksui, POS: PROPN
# Word: ,, POS: PUNCT
# Word: jo, POS: PRON
# Word: gimtadienis, POS: NOUN
# Word: O, POS: CCONJ
# Word: aš, POS: PRON
# Word: nupirkau, POS: VERB
# Word: jam, POS: PRON
# Word: dėklą, POS: NOUN
# Word: akiniams, POS: NOUN
# Word: iš, POS: ADP
# Word: gražios, POS: ADJ
# Word: medžiagos, POS: NOUN
# Word: o, POS: CCONJ
# Word: nuo, POS: ADP
# Word: savo, POS: PRON
# Word: mergaitės, POS: NOUN
# Word: jis, POS: PRON
# Word: gaus, POS: VERB
# Word: tikrą, POS: DET
# Word: sidabrinį, POS: NOUN
# Word: žiedą, POS: NOUN
# Word: Tikrai, POS: ADV
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: tikrą, POS: DET
# Word: sidabrinį, POS: NOUN
# Word: Jam, POS: PRON
# Word: sekasi, POS: VERB
# Word: šiemet, POS: PUNCT
# Word: Apibūdinti, POS: VERB
# Word: asmenį, POS: NOUN
# Word: Ar, POS: PART
# Word: negalėtum, POS: VERB
# Word: 12, POS: NUM
# Word: 57, POS: NUM
# Word: sutikti, POS: VERB
# Word: mano, POS: PRON
# Word: dėdę, POS: NOUN
# Word: Aš, POS: PRON
# Word: neturiu, POS: VERB
# Word: laiko, POS: NOUN
# Word: Turi, POS: VERB
# Word: galvoje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: nuo, POS: ADP
# Word: stoties, POS: NOUN
# Word: Na, POS: INTJ
# Word: gerai, POS: ADV
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: kaip, POS: SCONJ
# Word: jis, POS: PRON
# Word: atrodo, POS: VERB
# Word: Jis, POS: PRON
# Word: labai, POS: ADV
# Word: aukštas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: apie, POS: ADP
# Word: 1,8, POS: NUM
# Word: m, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ir, POS: CCONJ
# Word: pilnas, POS: ADJ
# Word: Ar, POS: PART
# Word: jis, POS: PRON
# Word: nešioja, POS: VERB
# Word: akinius, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: jis, POS: PRON
# Word: visada, POS: ADV
# Word: apsirengęs, POS: VERB
# Word: elegantiškai, POS: ADV
# Word: Dažniausiai, POS: ADV
# Word: tamsiu, POS: ADJ
# Word: kostiumu, POS: NOUN
# Word: ,, POS: PUNCT
# Word: visada, POS: ADV
# Word: su, POS: ADP
# Word: portfeliu, POS: NOUN
# Word: Tokių, POS: DET
# Word: šimtai, POS: NUM
# Word: Koks, POS: DET
# Word: gi, POS: PART
# Word: jo, POS: PRON
# Word: vardas, POS: NOUN
# Word: ir, POS: CCONJ
# Word: pavardė, POS: NOUN
# Word: Henrikas, POS: PROPN
# Word: Mejeris, POS: PROPN
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: ir, POS: PART
# Word: aš, POS: PRON
# Word: Palinkkėimai, POS: NOUN
# Word: pasveikti, POS: VERB
# Word: Ar, POS: PART
# Word: ką, POS: PRON
# Word: nors, POS: X
# Word: šiandien, POS: ADV
# Word: planavai, POS: ADV
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: turiu, POS: VERB
# Word: nueiti, POS: VERB
# Word: į, POS: ADP
# Word: ligoninę, POS: NOUN
# Word: O, POS: CCONJ
# Word: kas, POS: PRON
# Word: atsitiko, POS: VERB
# Word: Mano, POS: PRON
# Word: senelis, POS: NOUN
# Word: ligoninėje, POS: NOUN
# Word: Norėčiau, POS: VERB
# Word: jį, POS: PRON
# Word: aplankyti, POS: VERB
# Word: Tu, POS: PRON
# Word: gi, POS: PART
# Word: žinai, POS: VERB
# Word: ,, POS: PUNCT
# Word: jis, POS: PRON
# Word: buvo, POS: AUX
# Word: papuolęs, POS: VERB
# Word: į, POS: ADP
# Word: avariją, POS: NOUN
# Word: O, POS: CCONJ
# Word: kaip, POS: SCONJ
# Word: jis, POS: PRON
# Word: dabar, POS: ADV
# Word: Ačiū, POS: VERB
# Word: Dievui, POS: NOUN
# Word: ,, POS: PUNCT
# Word: dabar, POS: ADV
# Word: jaučiasi, POS: VERB
# Word: geriau, POS: ADV
# Word: Tai, POS: DET
# Word: buvo, POS: AUX
# Word: automobilio, POS: NOUN
# Word: avarija, POS: NOUN
# Word: ,, POS: PUNCT
# Word: tu, POS: PRON
# Word: žinai, POS: VERB
# Word: Kai, POS: SCONJ
# Word: aš, POS: PRON
# Word: apie, POS: ADP
# Word: tai, POS: DET
# Word: galvoju, POS: VERB
# Word: ,, POS: PUNCT
# Word: man, POS: PRON
# Word: tiesiog, POS: ADV
# Word: bloga, POS: ADJ
# Word: Man, POS: PRON
# Word: gaila, POS: ADV
# Word: Jis, POS: PRON
# Word: norėjo, POS: VERB
# Word: į, POS: ADP
# Word: Ciuriką, POS: NOUN
# Word: skrįsti, POS: VERB
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: ne, POS: PART
# Word: Tiksliai, POS: ADV
# Word: ,, POS: PUNCT
# Word: šiandien, POS: ADV
# Word: Jam, POS: PRON
# Word: tiesiog, POS: ADV
# Word: nepasisekė, POS: VERB
# Word: Linkiu, POS: VERB
# Word: jam, POS: PRON
# Word: kuo, POS: CCONJ
# Word: greičiau, POS: ADV
# Word: pasveikti, POS: VERB
# Word: Ačiū, POS: PRON
# Word: Kol, POS: ADV
# Word: kas, POS: PRON
# Word: Iki, POS: ADP
# Word: Paslaptingas, POS: ADJ
# Word: portfelis, POS: NOUN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: ponas, POS: NOUN
# Word: B, POS: PUNCT
# Word: ,, POS: PUNCT
# Word: Jūsų, POS: PRON
# Word: portfelis, POS: NOUN
# Word: atrodo, POS: VERB
# Word: labai, POS: ADV
# Word: įdomiai, POS: ADV
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: ten, POS: ADV
# Word: turite, POS: VERB
# Word: Aš, POS: PRON
# Word: iš, POS: ADV
# Word: tikrųjų, POS: X
# Word: pats, POS: DET
# Word: nežinau, POS: VERB
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: sakote, POS: VERB
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: pats, POS: DET
# Word: nežinote, POS: VERB
# Word: ,, POS: PUNCT
# Word: ką, POS: PRON
# Word: turite, POS: VERB
# Word: portfelyje, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: girdėjote, POS: VERB
# Word: Ir, POS: CCONJ
# Word: nenorite, POS: VERB
# Word: žinoti, POS: VERB
# Word: Žinoma, POS: VERB
# Word: ,, POS: PUNCT
# Word: noriu, POS: VERB
# Word: Jausčiausi, POS: ADV
# Word: tada, POS: ADV
# Word: geriau, POS: ADV
# Word: Tai, POS: DET
# Word: kodėl, POS: ADV
# Word: tada, POS: ADV
# Word: nepažiūrite, POS: VERB
# Word: Gerai, POS: ADV
# Word: ,, POS: PUNCT
# Word: pažiūrėk, POS: VERB
# Word: pats, POS: DET
# Word: Nieko, POS: PRON
# Word: ,, POS: PUNCT
# Word: tik, POS: PART
# Word: popieriai, POS: NOUN
# Word: Ar, POS: PART
# Word: dabar, POS: ADV
# Word: Jums, POS: PRON
# Word: geriau, POS: ADV
# Word: Vakarėlyje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: apie, POS: ADP
# Word: šeimą, POS: NOUN
# Word: Šimtą, POS: NUM
# Word: metų, POS: NOUN
# Word: nesimatėme, POS: VERB
# Word: Kaip, POS: SCONJ
# Word: Jūsų, POS: PRON
# Word: vaikai, POS: NOUN
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: du, POS: NUM
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: ne, POS: PART
# Word: Taip, POS: ADV
# Word: Nuo, POS: ADP
# Word: to, POS: DET
# Word: laiko, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kai, POS: SCONJ
# Word: buvome, POS: VERB
# Word: susitikę, POS: VERB
# Word: ,, POS: PUNCT
# Word: mano, POS: PRON
# Word: duktė, POS: NOUN
# Word: ištekėjo, POS: VERB
# Word: Jūsų, POS: PRON
# Word: duktė, POS: NOUN
# Word: gydytoja, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ar, POS: CCONJ
# Word: ne, POS: PART
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: mano, POS: PRON
# Word: žmona, POS: NOUN
# Word: yra, POS: AUX
# Word: gydytoja, POS: NOUN
# Word: Mano, POS: PRON
# Word: duktė, POS: NOUN
# Word: dar, POS: ADV
# Word: studijuoja, POS: VERB
# Word: universitete, POS: NOUN
# Word: ,, POS: PUNCT
# Word: taip, POS: PART
# Word: pat, POS: X
# Word: ir, POS: PART
# Word: sūnus, POS: NOUN
# Word: Ką, POS: PRON
# Word: jie, POS: PRON
# Word: studijuoja, POS: VERB
# Word: Abu, POS: NUM
# Word: tą, POS: DET
# Word: patį, POS: DET
# Word: dalyką, POS: NOUN
# Word: Vadybą, POS: NOUN
# Word: O, POS: CCONJ
# Word: Jūsų, POS: PRON
# Word: vaikai, POS: NOUN
# Word: Ką, POS: PRON
# Word: jie, POS: PRON
# Word: veikia, POS: VERB
# Word: Aš, POS: PRON
# Word: neturiu, POS: VERB
# Word: vaikų, POS: NOUN
# Word: Ir, POS: CCONJ
# Word: nesu, POS: VERB
# Word: vedęs, POS: VERB
# Word: Jūs, POS: PRON
# Word: tikriausiai, POS: ADV
# Word: galvojate, POS: VERB
# Word: apie, POS: ADP
# Word: mano, POS: PRON
# Word: seserį, POS: NOUN
# Word: Ji, POS: PRON
# Word: turi, POS: VERB
# Word: du, POS: NUM
# Word: vaikus, POS: NOUN
# Word: Atostogos, POS: NOUN
# Word: Kaip, POS: SCONJ
# Word: Tavo, POS: PRON
# Word: atostogos, POS: NOUN
# Word: Puikiai, POS: ADV
# Word: Mes, POS: PRON
# Word: keliavome, POS: VERB
# Word: po, POS: ADP
# Word: pietinę, POS: ADJ
# Word: Vokietiją, POS: PROPN
# Word: automobiliu, POS: NOUN
# Word: Aš, POS: PRON
# Word: visai, POS: ADV
# Word: nežinau, POS: VERB
# Word: pietinės, POS: ADJ
# Word: Vokietijos, POS: PROPN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: vietos, POS: NOUN
# Word: puikios, POS: ADJ
# Word: Pievos, POS: NOUN
# Word: ,, POS: PUNCT
# Word: miškai, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kalnai, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ir, POS: CCONJ
# Word: ežerai, POS: NOUN
# Word: Mums, POS: PRON
# Word: labai, POS: ADV
# Word: patiko, POS: VERB
# Word: O, POS: CCONJ
# Word: koks, POS: DET
# Word: buvo, POS: AUX
# Word: oras, POS: NOUN
# Word: Septynias, POS: NUM
# Word: dienas, POS: NOUN
# Word: lijo, POS: VERB
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: tris, POS: NUM
# Word: -, POS: PUNCT
# Word: švietė, POS: NOUN
# Word: saulė, POS: NOUN
# Word: Iškylos, POS: NOUN
# Word: planavimas, POS: NOUN
# Word: Pasiūlymai, POS: NOUN
# Word: Ar, POS: PART
# Word: Tu, POS: PRON
# Word: jau, POS: PART
# Word: alkanas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: dar, POS: PART
# Word: ne, POS: PART
# Word: Aš, POS: PRON
# Word: alkanas, POS: NOUN
# Word: ir, POS: CCONJ
# Word: ištroškęs, POS: VERB
# Word: Ar, POS: PART
# Word: jau, POS: PART
# Word: valgysime, POS: VERB
# Word: Tai, POS: DET
# Word: puiki, POS: ADJ
# Word: mintis, POS: NOUN
# Word: Kur, POS: ADV
# Word: bus, POS: AUX
# Word: mūsų, POS: PRON
# Word: piknikas, POS: NOUN
# Word: Siūlau, POS: VERB
# Word: pilies, POS: NOUN
# Word: sode, POS: NOUN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: mes, POS: PRON
# Word: galime, POS: VERB
# Word: eiti, POS: VERB
# Word: į, POS: ADP
# Word: vidų, POS: NOUN
# Word: ir, POS: CCONJ
# Word: apžiūrėti, POS: VERB
# Word: pilį, POS: NOUN
# Word: Aš, POS: PRON
# Word: norėčiau, POS: VERB
# Word: pamatyti, POS: VERB
# Word: porceliano, POS: NOUN
# Word: kolekciją, POS: NOUN
# Word: Ji, POS: PRON
# Word: gana, POS: ADV
# Word: garsi, POS: ADJ
# Word: Visi, POS: DET
# Word: daiktai, POS: NOUN
# Word: originalūs, POS: ADJ
# Word: ,, POS: PUNCT
# Word: iš, POS: ADP
# Word: 18, POS: NUM
# Word: amžiaus, POS: NOUN
# Word: Aš, POS: PRON
# Word: girdėjau, POS: VERB
# Word: apie, POS: ADP
# Word: tai, POS: DET
# Word: Tikiuosi, POS: VERB
# Word: ,, POS: PUNCT
# Word: mes, POS: PRON
# Word: jų, POS: PRON
# Word: nesudaužysime, POS: VERB
# Word: Nesijaudink, POS: VERB
# Word: Jie, POS: PRON
# Word: visi, POS: DET
# Word: po, POS: ADP
# Word: stiklu, POS: NOUN
# Word: Vėlavimas, POS: NOUN
# Word: į, POS: ADP
# Word: susitikimą, POS: NOUN
# Word: Jau, POS: ADV
# Word: 20, POS: NUM
# Word: minučių, POS: NOUN
# Word: po, POS: ADP
# Word: dvyliktos, POS: NOUN
# Word: Aš, POS: PRON
# Word: Jūsų, POS: PRON
# Word: laukiau, POS: VERB
# Word: dvyliktą, POS: PROPN
# Word: Bet, POS: CCONJ
# Word: Jūs, POS: PRON
# Word: gi, POS: PART
# Word: uždusęs, POS: VERB
# Word: Atsiprašau, POS: VERB
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: man, POS: PRON
# Word: labai, POS: ADV
# Word: nesisekė, POS: VERB
# Word: Nesėkminga, POS: ADJ
# Word: diena, POS: NOUN
# Word: Viskas, POS: PRON
# Word: buvo, POS: AUX
# Word: blogai, POS: ADV
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: galvoje, POS: NOUN
# Word: Nagi, POS: PROPN
# Word: ,, POS: PUNCT
# Word: traukinys, POS: NOUN
# Word: vėlavo, POS: VERB
# Word: Po, POS: ADP
# Word: to, POS: X
# Word: negalėjau, POS: VERB
# Word: rasti, POS: VERB
# Word: taksi, POS: NOUN
# Word: ,, POS: PUNCT
# Word: be, POS: ADP
# Word: to, POS: DET
# Word: čia, POS: ADV
# Word: ir, POS: CCONJ
# Word: liftas, POS: VERB
# Word: nedirba, POS: VERB
# Word: Tikrai, POS: ADV
# Word: blogai, POS: ADV
# Word: Bet, POS: CCONJ
# Word: pirmiausia, POS: ADV
# Word: atgaukite, POS: VERB
# Word: kvapą, POS: NOUN
# Word: Atsisėskite, POS: VERB
# Word: Nieko, POS: PRON
# Word: nuostabaus, POS: NOUN
# Word: ,, POS: PUNCT
# Word: šiandien, POS: ADV
# Word: vasario, POS: NOUN
# Word: 13, POS: NUM
# Word: diena, POS: NOUN
# Word: Išreikšti, POS: VERB
# Word: nustebimą, POS: NOUN
# Word: ir, POS: CCONJ
# Word: netikėjimą, POS: NOUN
# Word: Turiu, POS: VERB
# Word: Tau, POS: PRON
# Word: siurprizą, POS: NOUN
# Word: Kas, POS: PRON
# Word: tai, POS: DET
# Word: ,, POS: PUNCT
# Word: pasakyk, POS: PRON
# Word: Spėk, POS: PROPN
# Word: Kas, POS: PRON
# Word: tai, POS: DET
# Word: galėtų, POS: VERB
# Word: būti, POS: AUX
# Word: Neturiu, POS: VERB
# Word: supratimo, POS: NOUN
# Word: Įsivaizduokite, POS: VERB
# Word: ,, POS: PUNCT
# Word: išlošėte, POS: VERB
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: galvoje, POS: NOUN
# Word: Aš, POS: PRON
# Word: gi, POS: PART
# Word: pasakiau, POS: VERB
# Word: Jūs, POS: PRON
# Word: laimėjote, POS: VERB
# Word: krūvą, POS: NOUN
# Word: pinigų, POS: NOUN
# Word: Kas, POS: PRON
# Word: Aš, POS: PRON
# Word: Iš, POS: ADV
# Word: tikrųjų, POS: X
# Word: Kaip, POS: ADV
# Word: Aš, POS: PRON
# Word: nežinau, POS: VERB
# Word: ,, POS: PUNCT
# Word: ką, POS: PRON
# Word: ir, POS: PART
# Word: sakyti, POS: VERB
# Word: Turime, POS: VERB
# Word: išgerti, POS: VERB
# Word: Žinoma, POS: VERB
# Word: Aš, POS: PRON
# Word: moku, POS: VERB
# Word: Paslaptis, POS: NOUN
# Word: Pasakykite, POS: VERB
# Word: prašom, POS: VERB
# Word: ,, POS: PUNCT
# Word: inspektoriau, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kas, POS: PRON
# Word: čia, POS: ADV
# Word: per, POS: ADP
# Word: paslaptis, POS: NOUN
# Word: Aš, POS: PRON
# Word: galiu, POS: VERB
# Word: pasakyti, POS: VERB
# Word: ,, POS: PUNCT
# Word: jam, POS: PRON
# Word: nusišypsojo, POS: VERB
# Word: laimė, POS: NOUN
# Word: Ir, POS: CCONJ
# Word: jis, POS: PRON
# Word: netiki, POS: VERB
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: galvoje, POS: NOUN
# Word: Jis, POS: PRON
# Word: negali, POS: VERB
# Word: patikėti, POS: VERB
# Word: Ar, POS: PART
# Word: jis, POS: PRON
# Word: tikrai, POS: ADV
# Word: laimėjo, POS: VERB
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: tikras, POS: ADJ
# Word: ,, POS: PUNCT
# Word: tai, POS: PART
# Word: tiesa, POS: NOUN
# Word: Nėra, POS: VERB
# Word: jokios, POS: DET
# Word: abejonės, POS: NOUN
# Word: Ką, POS: PRON
# Word: visa, POS: DET
# Word: tai, POS: X
# Word: reiškia, POS: VERB
# Word: Aš, POS: PRON
# Word: tikrai, POS: ADV
# Word: netikiu, POS: VERB
# Word: Tai, POS: DET
# Word: būtų, POS: AUX
# Word: per, POS: PART
# Word: daug, POS: ADV
# Word: gerai, POS: ADV
# Word: Du, POS: NUM
# Word: draugai, POS: NOUN
# Word: atostogauja, POS: VERB
# Word: Aš, POS: PRON
# Word: turiu, POS: VERB
# Word: nueiti, POS: VERB
# Word: į, POS: ADP
# Word: banką, POS: NOUN
# Word: ir, POS: CCONJ
# Word: pakeisti, POS: VERB
# Word: pinigus, POS: NOUN
# Word: Eikime, POS: VERB
# Word: kartu, POS: ADV
# Word: Man, POS: PRON
# Word: taip, POS: PART
# Word: pat, POS: X
# Word: reikia, POS: VERB
# Word: pinigų, POS: NOUN
# Word: Koks, POS: DET
# Word: kursas, POS: NOUN
# Word: šiandien, POS: ADV
# Word: Ne, POS: PART
# Word: toks, POS: DET
# Word: jau, POS: PART
# Word: geras, POS: ADJ
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: nebeturiu, POS: VERB
# Word: grynųjų, POS: ADJ
# Word: Tik, POS: PART
# Word: kelioninius, POS: ADJ
# Word: čekius, POS: NOUN
# Word: Restorane, POS: NOUN
# Word: ,, POS: PUNCT
# Word: priešais, POS: ADP
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: mokėjau, POS: VERB
# Word: kreditine, POS: ADJ
# Word: kortele, POS: NOUN
# Word: Ar, POS: PART
# Word: galima, POS: VERB
# Word: Kaip, POS: SCONJ
# Word: ten, POS: ADV
# Word: valgis, POS: NOUN
# Word: Man, POS: PRON
# Word: patiko, POS: VERB
# Word: Virėjas, POS: NOUN
# Word: moka, POS: VERB
# Word: virti, POS: VERB
# Word: Banke, POS: NOUN
# Word: Iškeiskite, POS: VERB
# Word: prašom, POS: VERB
# Word: 500, POS: NUM
# Word: markių, POS: NOUN
# Word: į, POS: ADP
# Word: šveicariškus, POS: ADJ
# Word: frankus, POS: NOUN
# Word: Eikite, POS: VERB
# Word: prašom, POS: VERB
# Word: prie, POS: ADP
# Word: užsienio, POS: NOUN
# Word: valiutos, POS: NOUN
# Word: keitimo, POS: NOUN
# Word: langelio, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Prie, POS: ADP
# Word: užsienio, POS: NOUN
# Word: valiutos, POS: NOUN
# Word: keitimo, POS: NOUN
# Word: langelio, POS: NOUN
# Word: Norėčiau, POS: VERB
# Word: šveicariškų, POS: ADJ
# Word: frankų, POS: NOUN
# Word: už, POS: ADP
# Word: 500, POS: NUM
# Word: markių, POS: NOUN
# Word: Prašom, POS: VERB
# Word: Štai, POS: PART
# Word: Jūsų, POS: PRON
# Word: pinigai, POS: NOUN
# Word: ir, POS: CCONJ
# Word: kvitas, POS: NOUN
# Word: Duokite, POS: VERB
# Word: man, POS: PRON
# Word: prašom, POS: VERB
# Word: dar, POS: PART
# Word: Austrijos, POS: PROPN
# Word: šilingų, POS: ADJ
# Word: už, POS: ADP
# Word: 1000, POS: NUM
# Word: markių, POS: NOUN
# Word: Grynais, POS: NOUN
# Word: ar, POS: CCONJ
# Word: kelioniniais, POS: ADJ
# Word: čekiais, POS: NOUN
# Word: Grynais, POS: NOUN
# Word: prašom, POS: VERB
# Word: Gatvėje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: prašant, POS: VERB
# Word: pagalbos, POS: NOUN
# Word: Sveiki, POS: ADJ
# Word: p, POS: X
# Word: Becker, POS: PROPN
# Word: Kaip, POS: ADV
# Word: laikotės, POS: NOUN
# Word: Ahiū, POS: PROPN
# Word: Gerai, POS: ADV
# Word: O, POS: CCONJ
# Word: kaip, POS: SCONJ
# Word: Jūs, POS: PRON
# Word: Taip, POS: ADV
# Word: sau, POS: PRON
# Word: O, POS: CCONJ
# Word: brangioji, POS: ADJ
# Word: ,, POS: PUNCT
# Word: kas, POS: PRON
# Word: yra, POS: VERB
# Word: Mano, POS: PRON
# Word: kreditinė, POS: ADJ
# Word: kortelė, POS: NOUN
# Word: dingo, POS: PUNCT
# Word: Aš, POS: PRON
# Word: niekur, POS: PRON
# Word: negaliu, POS: VERB
# Word: jos, POS: PRON
# Word: rasti, POS: VERB
# Word: Kada, POS: ADV
# Word: paskutinį, POS: ADJ
# Word: kartą, POS: NOUN
# Word: ją, POS: PRON
# Word: turėjote, POS: VERB
# Word: Dar, POS: ADV
# Word: vakar, POS: PROPN
# Word: Aš, POS: PRON
# Word: mokkjau, POS: VERB
# Word: už, POS: ADP
# Word: kažką, POS: PRON
# Word: kortele, POS: NOUN
# Word: Eikite, POS: VERB
# Word: tuoj, POS: ADV
# Word: pat, POS: X
# Word: į, POS: ADP
# Word: banką, POS: NOUN
# Word: Eikime, POS: VERB
# Word: kartu, POS: ADV
# Word: ,, POS: PUNCT
# Word: prašau, POS: VERB
# Word: Man, POS: PRON
# Word: labai, POS: ADV
# Word: skauda, POS: VERB
# Word: galvą, POS: NOUN
# Word: Žinoma, POS: VERB
# Word: ,, POS: PUNCT
# Word: gerai, POS: ADV
# Word: Mes, POS: PRON
# Word: užeisime, POS: VERB
# Word: į, POS: ADP
# Word: kavinę, POS: NOUN
# Word: ir, POS: CCONJ
# Word: išgersime, POS: VERB
# Word: puoduką, POS: NOUN
# Word: kavos, POS: NOUN
# Word: Aš, POS: PRON
# Word: turiu, POS: VERB
# Word: aspirino, POS: VERB
# Word: tabletę, POS: NOUN
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: kavinėje, POS: NOUN
# Word: gausime, POS: VERB
# Word: vandens, POS: NOUN
# Word: Planai, POS: NOUN
# Word: vakarui, POS: NOUN
# Word: Ką, POS: PRON
# Word: mes, POS: PRON
# Word: darysime, POS: VERB
# Word: šį, POS: DET
# Word: vakarą, POS: NOUN
# Word: Gal, POS: PART
# Word: eisime, POS: VERB
# Word: į, POS: ADP
# Word: kiną, POS: NOUN
# Word: ar, POS: CCONJ
# Word: teatrą, POS: NOUN
# Word: Galėtumėm, POS: VERB
# Word: dar, POS: PART
# Word: gauti, POS: VERB
# Word: bilietus, POS: NOUN
# Word: Galėtumėm, POS: VERB
# Word: ir, POS: CCONJ
# Word: pašokti, POS: VERB
# Word: nueiti, POS: VERB
# Word: Aš, POS: PRON
# Word: mėgstu, POS: VERB
# Word: viską, POS: PRON
# Word: ,, POS: PUNCT
# Word: ir, POS: CCONJ
# Word: baletą, POS: NOUN
# Word: ir, POS: CCONJ
# Word: teatrą, POS: NOUN
# Word: Aš, POS: PRON
# Word: mėgstu, POS: VERB
# Word: ir, POS: CCONJ
# Word: kiną, POS: NOUN
# Word: ;, POS: PUNCT
# Word: sugalvok, POS: VERB
# Word: ,, POS: PUNCT
# Word: ką, POS: PRON
# Word: mes, POS: PRON
# Word: darysime, POS: VERB
# Word: Aš, POS: PRON
# Word: tiesiog, POS: ADV
# Word: norėčiau, POS: VERB
# Word: kur, POS: ADV
# Word: nors, POS: X
# Word: išeiti, POS: VERB
# Word: Piteris, POS: PROPN
# Word: prisimena, POS: VERB
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: sunku, POS: ADJ
# Word: prie, POS: ADP
# Word: kasos, POS: NOUN
# Word: Bet, POS: CCONJ
# Word: jis, POS: PRON
# Word: negali, POS: VERB
# Word: pasiūlyti, POS: VERB
# Word: televizijos, POS: NOUN
# Word: Jie, POS: PRON
# Word: pasiskolina, POS: VERB
# Word: laikraštį, POS: NOUN
# Word: iš, POS: ADP
# Word: vyriškio, POS: ADJ
# Word: prie, POS: ADP
# Word: gretimo, POS: NOUN
# Word: staliuko, POS: NOUN
# Word: ir, POS: CCONJ
# Word: žiūri, POS: VERB
# Word: teatrų, POS: NOUN
# Word: programą, POS: NOUN
# Word: Jie, POS: PRON
# Word: neranda, POS: VERB
# Word: nieko, POS: PRON
# Word: tinkamo, POS: ADJ
# Word: ir, POS: CCONJ
# Word: nusprendžia, POS: VERB
# Word: nueiti, POS: VERB
# Word: į, POS: ADP
# Word: restoraną, POS: NOUN
# Word: Žinoma, POS: VERB
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: jus, POS: PRON
# Word: kviečiu, POS: VERB
# Word: Aš, POS: PRON
# Word: žinau, POS: VERB
# Word: gerą, POS: ADJ
# Word: restoraną, POS: NOUN
# Word: Jis, POS: PRON
# Word: nedidelis, POS: ADJ
# Word: ir, POS: CCONJ
# Word: nebrangus, POS: ADJ
# Word: Aptarnavimas, POS: NOUN
# Word: geras, POS: ADJ
# Word: ir, POS: CCONJ
# Word: maistas, POS: NOUN
# Word: puikus, POS: ADJ
# Word: O, POS: CCONJ
# Word: tai, POS: DET
# Word: svarbiausia, POS: ADJ
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: ne, POS: PART
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Ap, POS: X
# Word: galiu, POS: VERB
# Word: apsivilkti, POS: VERB
# Word: marškinius, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kuriuos, POS: DET
# Word: tik, POS: PART
# Word: ką, POS: PRON
# Word: nusipirkau, POS: VERB
# Word: ir, POS: PART
# Word: kaklaraištį, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kurį, POS: DET
# Word: tu, POS: PRON
# Word: man, POS: PRON
# Word: padovanojai, POS: ADV
# Word: Mes, POS: PRON
# Word: turėtumėm, POS: VERB
# Word: jau, POS: PART
# Word: eiti, POS: VERB
# Word: Parduotuvės, POS: NOUN
# Word: užsidaro, POS: VERB
# Word: 6-tą, POS: NOUN
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: aš, POS: PRON
# Word: dar, POS: PART
# Word: noriu, POS: VERB
# Word: ką, POS: PRON
# Word: nors, POS: X
# Word: nusipirkti, POS: VERB
# Word: Padavėjau, POS: VERB
# Word: ,, POS: PUNCT
# Word: prašom, POS: VERB
# Word: sąskaitą, POS: NOUN
# Word: Mažas, POS: ADJ
# Word: kavinukas, POS: NOUN
# Word: kavos, POS: NOUN
# Word: ,, POS: PUNCT
# Word: arbata, POS: NOUN
# Word: su, POS: ADP
# Word: citrina, POS: NOUN
# Word: ir, POS: CCONJ
# Word: 2, POS: NUM
# Word: gabaliukai, POS: NOUN
# Word: pyrago, POS: NOUN
# Word: ;, POS: PUNCT
# Word: už, POS: ADP
# Word: visa, POS: PRON
# Word: tai, POS: X
# Word: 9, POS: NUM
# Word: markės, POS: NOUN
# Word: 70, POS: NUM
# Word: Štai, POS: PART
# Word: Jūsų, POS: PRON
# Word: sąskaita, POS: NOUN
# Word: Ar, POS: PART
# Word: aš, POS: PRON
# Word: turiu, POS: VERB
# Word: duoti, POS: VERB
# Word: arbatpinigių, POS: ADJ
# Word: Tiktai, POS: PART
# Word: 30, POS: NUM
# Word: pfenigių, POS: NOUN
# Word: ,, POS: PUNCT
# Word: jeigu, POS: SCONJ
# Word: nori, POS: VERB
# Word: Vokietijoje, POS: PROPN
# Word: aptarnavimas, POS: NOUN
# Word: visada, POS: ADV
# Word: įjungtas, POS: VERB
# Word: Išaiškinti, POS: VERB
# Word: nesusipratimą, POS: NOUN
# Word: (, POS: PUNCT
# Word: blogas, POS: ADJ
# Word: adresas, POS: NOUN
# Word: ), POS: PUNCT
# Word: Labas, POS: PROPN
# Word: rytas, POS: PROPN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: iš, POS: ADP
# Word: ekspreso, POS: NOUN
# Word: kurjerių, POS: NOUN
# Word: tarnybos, POS: NOUN
# Word: Taip, POS: ADV
# Word: Mes, POS: PRON
# Word: laukėme, POS: VERB
# Word: Jūsų, POS: PRON
# Word: Prašom, POS: VERB
# Word: įeiti, POS: VERB
# Word: Ačiū, POS: PRON
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: laukėte, POS: VERB
# Word: ilgai, POS: ADV
# Word: Nieko, POS: PRON
# Word: Kur, POS: ADV
# Word: paketas, POS: NOUN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: jį, POS: PRON
# Word: Žinoma, POS: VERB
# Word: Štai, POS: PART
# Word: ,, POS: PUNCT
# Word: abu, POS: NUM
# Word: Šmidto, POS: NOUN
# Word: vardu, POS: NOUN
# Word: Šmidto, POS: NOUN
# Word: Mano, POS: PRON
# Word: vardas, POS: NOUN
# Word: Šulz, POS: PROPN
# Word: ,, POS: PUNCT
# Word: Elvyra, POS: PROPN
# Word: Šulz, POS: PROPN
# Word: Tai, POS: DET
# Word: kažkas, POS: PRON
# Word: negerai, POS: ADV
# Word: Bet, POS: CCONJ
# Word: čia, POS: ADV
# Word: parašyta, POS: VERB
# Word: :, POS: PUNCT
# Word: Šmidt, POS: PROPN
# Word: ,, POS: PUNCT
# Word: Bahnhof, POS: X
# Word: Street, POS: X
# Word: 12, POS: NUM
# Word: ,, POS: PUNCT
# Word: trečias, POS: NUM
# Word: aukštas, POS: ADJ
# Word: Taip, POS: ADV
# Word: adresas, POS: NOUN
# Word: teisingas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: mes, POS: PRON
# Word: esame, POS: VERB
# Word: ketvirtame, POS: ADJ
# Word: aukšte, POS: NOUN
# Word: Šmidtai, POS: ADV
# Word: gyvena, POS: VERB
# Word: trečiajame, POS: NUM
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: atsiprašau, POS: VERB
# Word: Viso, POS: DET
# Word: gero, POS: ADV
# Word: Kas, POS: PRON
# Word: gi, POS: PART
# Word: po, POS: ADP
# Word: galais, POS: NOUN
# Word: čia, POS: ADV
# Word: dedasi, POS: VERB
# Word: Ir, POS: CCONJ
# Word: dar, POS: PART
# Word: ekspreso, POS: NOUN
# Word: kurjeriai, POS: NOUN
# Word: Lėktuvo, POS: NOUN
# Word: katastrofa, POS: NOUN
# Word: Vilniuje, POS: PROPN
# Word: –, POS: PUNCT
# Word: kas, POS: PRON
# Word: žinoma, POS: VERB
# Word: apie, POS: ADP
# Word: įvykį, POS: NOUN

# %%
# Counting the frequency of each POS tag
pos_counts = Counter(pos_tags)

# Creating a DataFrame with POS tags and their frequencies
df = pd.DataFrame(pos_counts.items(), columns = ["POS", "Frequency"])

# Sorting the DataFrame by frequency
df = df.sort_values(by = "Frequency", ascending = False)

# Plotting the bar chart
plt.figure(figsize = (10, 6))  # Set the figure size
ax = sns.barplot(x = "Frequency", y = "POS", data=df, palette = "viridis")

# Add labels and title
plt.xlabel("Frequency")
plt.ylabel("Part-of-Speech (POS) Tags")
plt.title("Frequency of POS Tags in Lithuanian Sentences (Original Dataset)")

# Adding values on the columns
for i, v in enumerate(df["Frequency"]):
    ax.text(v + 0.1, i, str(v), color='black', va='center', fontsize=12)
    
# Saving the graph
plt.savefig('pos_tag_frequency_plot_original.png', dpi=300, bbox_inches='tight')

# Showing the plot
plt.show()
# Out:
# /var/folders/8n/bffnmy712gb5xcnz6597rjb80000gn/T/ipykernel_75404/2182648570.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = "Frequency", y = "POS", data=df, palette = "viridis")

# %%
# POS tag counting for each sentence
sentence_pos_counts = []

# POS tagging for each sentence
for sentence in all_sentences:
    # Process the sentence using the Stanza pipeline
    doc = nlp(sentence)
    
    # Counting POS tags for this sentence
    pos_counts = Counter(word.upos for sent in doc.sentences for word in sent.words)
    sentence_pos_counts.append(pos_counts)

# Aggregating POS counts across all sentences
total_pos_counts = Counter()
for pos_counts in sentence_pos_counts:
    total_pos_counts.update(pos_counts)

# Calculating the average number of each POS tag per sentence
average_pos_counts = {tag: total / len(all_sentences) for tag, total in total_pos_counts.items()}

# Displaying the results
print("Average number of each POS tag per sentence:")
for tag, avg in average_pos_counts.items():
    print(f"{tag}: {avg:.3f}")
# Out:
# Average number of each POS tag per sentence:
# PART: 0.197
# NOUN: 0.839
# ADV: 0.396
# VERB: 0.704
# PROPN: 0.121
# PRON: 0.543
# PUNCT: 0.364
# CCONJ: 0.187
# AUX: 0.043
# ADP: 0.151
# ADJ: 0.172
# NUM: 0.129
# SCONJ: 0.053
# X: 0.065
# DET: 0.101
# INTJ: 0.005

# %%
# Vocabulary size & the most frequent words
# Tokenizing the words (+ lowercasing them)
words = []
for sentence in all_sentences:
    words.extend(re.findall(r'\b\w+\b', sentence.lower()))

# Counting the frequency of each word
word_counts = Counter(words)

# Words that appear only once
words_once = [word for word, count in word_counts.items() if count == 1]

# Words that appear more than once and their frequencies
words_more_than_once = {word: count for word, count in word_counts.items() if count > 1}

# Getting the most frequent 30 words
most_common_words = word_counts.most_common(30)

# Separating the words and their frequencies
words, frequencies = zip(*most_common_words)

print(f"Vocabulary size (original dataset): {len(word_counts)}")
print(f"Number of words that appear only once (original dataset): {len(words_once)}")
print(f"Words that appear more than once and their frequencies (original dataset): {words_more_than_once}")

# Plotting the bar chart with the "viridis" color palette
plt.figure(figsize=(10, 6))
sns.barplot(x=frequencies, y=words, palette="viridis")

# Adding labels and title
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title('Top 30 Most Frequent Words (Original Dataset)')

# Adding values on the columns
for i, v in enumerate(frequencies):
    plt.text(v + 0.1, i, str(v), color='black', va='center', fontsize=12)

# Saving the graph
plt.savefig('top_30_most_frequent_words_plot_original.png', dpi=300, bbox_inches='tight')

# Showing the plot
plt.show()
# Out:
# Vocabulary size (original dataset): 994
# Number of words that appear only once (original dataset): 674
# Words that appear more than once and their frequencies (original dataset): {'štai': 11, 'adresas': 3, 'kur': 15, 'gyvena': 3, 'sigita': 2, 'aš': 70, 'atsiprašau': 4, 'o': 39, 'kas': 15, 'jūs': 37, 'alio': 2, 'esu': 3, 'iš': 9, 'sveiki': 2, 'į': 17, 'jums': 8, 'kambarys': 6, 'viešbutyje': 2, 'viešbutis': 5, 'nedidelis': 2, 'jis': 18, 'mažas': 2, 'bet': 19, 'yra': 7, 'už': 8, 'dešinėje': 3, 'iki': 5, 'jus': 6, 'jūsų': 15, 'laukiau': 2, 'ar': 49, 'turite': 11, 'kambario': 4, 'numeris': 2, 'septintas': 2, 'aukšte': 4, 'puikus': 3, 'viena': 3, 'norite': 5, 'antrą': 2, 'ne': 25, 'ačiū': 20, 'taip': 36, 'būtų': 5, 'gerai': 14, 'ir': 47, 'rankšluostis': 2, 'didelis': 3, 'nuostabu': 2, 'negerai': 3, 'negaliu': 4, 'gatvėje': 3, 'mano': 10, 'labas': 5, 'rytas': 5, 'miegojote': 2, 'oras': 5, 'puiki': 3, 'diena': 8, 'jau': 8, 'gana': 2, 'šilta': 3, 'kiek': 2, 'dabar': 8, 'laiko': 3, 'tuoj': 4, 'dešimt': 7, 'kaip': 23, 'ką': 23, 'turime': 4, 'bandelių': 5, 'su': 10, 'aguonomis': 2, 'arba': 3, 'sviestu': 2, 'medumi': 2, 'kvepia': 2, 'puikiai': 7, 'norėčiau': 8, 'vieną': 2, 'pat': 8, 'puodelį': 2, 'kavos': 9, 'dar': 13, 'gyvenate': 2, 'gyvenu': 3, 'kartą': 3, 'vilniuje': 2, 'man': 17, 'patinka': 8, 'kalbate': 3, 'daug': 3, 'prašom': 12, 'valandų': 3, 'minučių': 6, 'po': 6, 'vienuoliktos': 5, 'puse': 4, 'be': 3, 'pokalbis': 3, 'telefonu': 3, 'sveika': 3, 'čia': 12, 'sekasi': 3, 'apsipirkti': 2, 'ruošiuosi': 2, 'eiti': 4, 'turgų': 2, 'šiandien': 12, 'tada': 6, 'susitiksime': 2, 'tai': 22, 'galėtumėm': 5, 'susitikti': 2, 'prie': 10, 'prekystalio': 2, 'kada': 5, 'tiksliai': 2, 'greitai': 3, 'pasimatysime': 2, 'ach': 3, 'braškės': 3, 'šviežios': 2, 'gaila': 7, 'prašau': 7, 'nors': 7, 'trys': 3, 'litai': 2, 'litų': 2, 'du': 5, 'alkanas': 3, 'tu': 6, 'saulė': 2, 'puiku': 3, 'mes': 16, 'gal': 7, 'omleto': 2, 'turiu': 6, 'keletą': 2, '9': 2, 'parduotuvės': 2, 'nuo': 5, '8': 2, '30': 5, 'ten': 5, 'geriau': 6, 'pusėje': 2, 'neringos': 2, 'kavinėje': 3, 'parduotuvėje': 2, 'laba': 2, 'kuo': 4, 'galiu': 7, 'padėti': 3, 'porų': 4, 'medvilninių': 2, 'kojinių': 4, 'kokio': 2, 'dydžio': 3, '70': 2, 'neturime': 2, 'jos': 2, 'viso': 4, 'gero': 4, 'labai': 10, 'tik': 5, 'juodos': 2, 'padavėjau': 2, 'galite': 3, 'norėtumėte': 4, 'mūsų': 2, 'ponia': 7, 'becker': 2, 'tiesa': 2, 'tikrųjų': 4, 'mėgstu': 4, 'orą': 2, 'tikrai': 6, 'pasimatuoti': 2, 'ji': 4, 'per': 4, 'na': 3, 'galima': 3, 'astorija': 2, 'berlynas': 2, 'laisvų': 2, 'kambarių': 2, 'rytoj': 2, 'dvi': 3, 'vienutes': 2, 'voniomis': 2, 'pavardė': 2, 'ponas': 2, 'keista': 2, 'ko': 2, 'nežinau': 5, 'atvykstu': 2, 'taškas': 4, 'berlyne': 3, 'taigi': 2, 'žinoma': 8, 'pilies': 4, 'sode': 2, 'susitinkame': 2, 'kokia': 2, 'dienas': 2, 'apie': 13, 'nueiti': 5, 'pilį': 2, 'metro': 2, 'autobusu': 3, 'greičiau': 2, 'sustojimas': 2, 'visai': 4, 'avarija': 3, 'atsitiko': 3, 'buvo': 5, 'nedirba': 2, 'dievui': 2, 'kažkas': 3, 'toks': 3, 'siuntinį': 2, 'kurį': 2, 'kad': 3, '300': 4, 'pilkų': 3, 'ernst': 3, 'matau': 2, 'mums': 2, 'jeigu': 3, 'jų': 2, 'nenorite': 2, 'tiesiog': 4, 'pasakyti': 2, 'lėktuve': 2, 'šmidt': 3, 'koks': 7, 'sutikti': 2, 'aplankyti': 2, 'savo': 2, 'dažnai': 3, 'skrendu': 2, 'tris': 2, 'domitės': 4, 'domiuosi': 2, 'menu': 2, 'galvoje': 5, 'tapyba': 2, 'daugiausiai': 3, 'abu': 3, 'bus': 7, 'prognozę': 2, 'londone': 2, 'būti': 2, 'vakar': 2, 'vokiškai': 2, 'tikras': 2, 'markės': 2, 'neturiu': 4, 'nieko': 5, 'kreditine': 2, 'kortele': 3, 'čekiais': 2, 'jie': 6, 'vardu': 2, 'pažiūrėk': 2, 'nupirkau': 2, 'jo': 2, 'jam': 5, 'tikrą': 2, 'sidabrinį': 2, '12': 2, 'turi': 2, 'atrodo': 2, 'aukštas': 2, 'visada': 3, 'gi': 5, 'vardas': 2, 'pasveikti': 2, 'jį': 2, 'žinai': 2, 'kai': 2, 'portfelis': 2, 'pats': 3, 'noriu': 2, 'vaikai': 2, 'to': 3, 'duktė': 3, 'gydytoja': 2, 'studijuoja': 2, 'tą': 2, 'atostogos': 2, 'patiko': 2, 'visi': 2, 'blogai': 2, 'rasti': 2, 'pinigų': 2, 'paslaptis': 2, 'negali': 2, 'visa': 2, 'banką': 2, 'eikime': 2, 'kartu': 2, 'geras': 2, '500': 2, 'markių': 3, 'eikite': 2, 'užsienio': 2, 'valiu ...
# /var/folders/8n/bffnmy712gb5xcnz6597rjb80000gn/T/ipykernel_75404/317885036.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequencies, y=words, palette="viridis")

# %%
# Vocabulary size & the most frequent words (NO STOPWORDS)
# Loading stopwords from the text file
with open('/Users/urtejakubauskaite/nltk_data/corpora/stopwords/lithuanian.txt', 'r', encoding='utf-8') as f:
    stop_words = set(f.read().splitlines())

# Tokenizing the words (+ lowercasing them) while excluding stopwords
words = []
for sentence in all_sentences:
    words.extend([word for word in re.findall(r'\b\w+\b', sentence.lower()) if word not in stop_words])

# Counting the frequency of each word
word_counts = Counter(words)

# Words that appear only once
words_once = [word for word, count in word_counts.items() if count == 1]

# Words that appear more than once and their frequencies
words_more_than_once = {word: count for word, count in word_counts.items() if count > 1}

# Getting the most frequent 30 words
most_common_words = word_counts.most_common(30)

# Separating the words and their frequencies
words, frequencies = zip(*most_common_words)

print(f"Vocabulary size (excluding stopwords): {len(word_counts)}")
print(f"Number of words that appear only once (excluding stopwords): {len(words_once)}")
print(f"Words that appear more than once and their frequencies (excluding stopwords): {words_more_than_once}")

# Plotting the bar chart with the "viridis" color palette
plt.figure(figsize=(10, 6))
sns.barplot(x=frequencies, y=words, palette="viridis")

# Adding labels and title
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title('Top 30 Most Frequent Words (Excluding Stopwords)')

# Adding values on the columns
for i, v in enumerate(frequencies):
    plt.text(v + 0.1, i, str(v), color='black', va='center', fontsize=12)

# Saving the graph
plt.savefig('top_30_most_frequent_words_plot_excluding_stopwords.png', dpi=300, bbox_inches='tight')

# Showing the plot
plt.show()
# Out:
# Vocabulary size (excluding stopwords): 906
# Number of words that appear only once (excluding stopwords): 645
# Words that appear more than once and their frequencies (excluding stopwords): {'adresas': 3, 'gyvena': 3, 'sigita': 2, 'atsiprašau': 4, 'alio': 2, 'esu': 3, 'sveiki': 2, 'kambarys': 6, 'viešbutyje': 2, 'viešbutis': 5, 'nedidelis': 2, 'mažas': 2, 'yra': 7, 'dešinėje': 3, 'laukiau': 2, 'turite': 11, 'kambario': 4, 'numeris': 2, 'septintas': 2, 'aukšte': 4, 'puikus': 3, 'viena': 3, 'norite': 5, 'antrą': 2, 'ačiū': 20, 'būtų': 5, 'gerai': 14, 'rankšluostis': 2, 'didelis': 3, 'nuostabu': 2, 'negerai': 3, 'negaliu': 4, 'gatvėje': 3, 'labas': 5, 'rytas': 5, 'miegojote': 2, 'oras': 5, 'puiki': 3, 'diena': 8, 'jau': 8, 'šilta': 3, 'dabar': 8, 'laiko': 3, 'tuoj': 4, 'dešimt': 7, 'ką': 23, 'turime': 4, 'bandelių': 5, 'aguonomis': 2, 'sviestu': 2, 'medumi': 2, 'kvepia': 2, 'puikiai': 7, 'norėčiau': 8, 'vieną': 2, 'puodelį': 2, 'kavos': 9, 'gyvenate': 2, 'gyvenu': 3, 'kartą': 3, 'vilniuje': 2, 'patinka': 8, 'kalbate': 3, 'daug': 3, 'prašom': 12, 'valandų': 3, 'minučių': 6, 'vienuoliktos': 5, 'puse': 4, 'pokalbis': 3, 'telefonu': 3, 'sveika': 3, 'čia': 12, 'sekasi': 3, 'apsipirkti': 2, 'ruošiuosi': 2, 'eiti': 4, 'turgų': 2, 'šiandien': 12, 'tada': 6, 'susitiksime': 2, 'galėtumėm': 5, 'susitikti': 2, 'prekystalio': 2, 'tiksliai': 2, 'greitai': 3, 'pasimatysime': 2, 'ach': 3, 'braškės': 3, 'šviežios': 2, 'gaila': 7, 'prašau': 7, 'trys': 3, 'litai': 2, 'litų': 2, 'du': 5, 'alkanas': 3, 'saulė': 2, 'puiku': 3, 'omleto': 2, 'turiu': 6, 'keletą': 2, '9': 2, 'parduotuvės': 2, '8': 2, '30': 5, 'ten': 5, 'geriau': 6, 'pusėje': 2, 'neringos': 2, 'kavinėje': 3, 'parduotuvėje': 2, 'laba': 2, 'kuo': 4, 'galiu': 7, 'padėti': 3, 'porų': 4, 'medvilninių': 2, 'kojinių': 4, 'kokio': 2, 'dydžio': 3, '70': 2, 'neturime': 2, 'jos': 2, 'viso': 4, 'gero': 4, 'labai': 10, 'juodos': 2, 'padavėjau': 2, 'galite': 3, 'norėtumėte': 4, 'ponia': 7, 'becker': 2, 'tiesa': 2, 'tikrųjų': 4, 'mėgstu': 4, 'orą': 2, 'tikrai': 6, 'pasimatuoti': 2, 'galima': 3, 'astorija': 2, 'berlynas': 2, 'laisvų': 2, 'kambarių': 2, 'rytoj': 2, 'dvi': 3, 'vienutes': 2, 'voniomis': 2, 'pavardė': 2, 'ponas': 2, 'keista': 2, 'ko': 2, 'nežinau': 5, 'atvykstu': 2, 'taškas': 4, 'berlyne': 3, 'žinoma': 8, 'pilies': 4, 'sode': 2, 'susitinkame': 2, 'dienas': 2, 'nueiti': 5, 'pilį': 2, 'metro': 2, 'autobusu': 3, 'greičiau': 2, 'sustojimas': 2, 'visai': 4, 'avarija': 3, 'atsitiko': 3, 'buvo': 5, 'nedirba': 2, 'dievui': 2, 'siuntinį': 2, 'kurį': 2, '300': 4, 'pilkų': 3, 'ernst': 3, 'matau': 2, 'jų': 2, 'nenorite': 2, 'pasakyti': 2, 'lėktuve': 2, 'šmidt': 3, 'sutikti': 2, 'aplankyti': 2, 'dažnai': 3, 'skrendu': 2, 'tris': 2, 'domitės': 4, 'domiuosi': 2, 'menu': 2, 'galvoje': 5, 'tapyba': 2, 'daugiausiai': 3, 'bus': 7, 'prognozę': 2, 'londone': 2, 'būti': 2, 'vakar': 2, 'vokiškai': 2, 'tikras': 2, 'markės': 2, 'neturiu': 4, 'nieko': 5, 'kreditine': 2, 'kortele': 3, 'čekiais': 2, 'jie': 6, 'vardu': 2, 'pažiūrėk': 2, 'nupirkau': 2, 'jo': 2, 'jam': 5, 'tikrą': 2, 'sidabrinį': 2, '12': 2, 'turi': 2, 'atrodo': 2, 'aukštas': 2, 'visada': 3, 'vardas': 2, 'pasveikti': 2, 'jį': 2, 'žinai': 2, 'portfelis': 2, 'noriu': 2, 'vaikai': 2, 'to': 3, 'duktė': 3, 'gydytoja': 2, 'studijuoja': 2, 'tą': 2, 'atostogos': 2, 'patiko': 2, 'visi': 2, 'blogai': 2, 'rasti': 2, 'pinigų': 2, 'paslaptis': 2, 'negali': 2, 'banką': 2, 'eikime': 2, 'kartu': 2, 'geras': 2, '500': 2, 'markių': 3, 'eikite': 2, 'užsienio': 2, 'valiutos': 2, 'keitimo': 2, 'langelio': 2, 'grynais': 2, 'darysime': 2, 'kiną': 2, 'teatrą': 2, 'restoraną': 2, 'aptarnavimas': 2, 'ekspreso': 2, 'šmidto': 2, 'šulz': 2}
# /var/folders/8n/bffnmy712gb5xcnz6597rjb80000gn/T/ipykernel_75404/3127959804.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequencies, y=words, palette="viridis")

# %% [markdown]
# # New Dataset

# %%
# Adding additional data
file_path = 'train-00000-of-00001.csv'
data = pd.read_csv(file_path)

# Data to be added
new_data = [['Airplane disaster in Vilnius - what is known about the event?', 
             'Lėktuvo katastrofa Vilniuje – kas žinoma apie įvykį?'],
            ['On Monday morning a plane crash occurred in the capital - in Liepkalnis, near Vilnius Airport, a cargo aircraft "Boeing 737" crashed.', 
             'Pirmadienio rytą sostinėje įvyko lėktuvo katastrofa – Liepkalnyje, netoli Vilniaus oro uosto, nukrito krovininis orlaivis „Boeing 737“.'],
            ['One person was killed in the incident, three were injured, one of them is a Lithuanian.',
             'Per įvykį vienas žmogus žuvo, trys sužeisti, vienas iš jų yra lietuvis.'],
            ['On Monday at 5.28 am received information that a cargo plane crashed in Liepkalnis near the house.',
             'Pirmadienį 5.28 val. ryto gauta informacija, kad krovininis lėktuvas nukrito Liepkalnyje šalia namo.'],
            ['Commercial aircraft flew to Vilnius from Leipzig, Germany.',
             'Krovininis lėktuvas į Vilnių skrido iš Leipcigo, Vokietijos.'],
            ['Before the flight to Vilnius, the plane stood unused for two days, November 23-24, at Leipzig Airport.',
             'Prieš skrydį į Vilnių lėktuvas dvi dienas, lapkričio 23–24 d., Leipcigo oro uoste stovėjo nenaudojamas, nors įprastai orlaiviu buvo skraidoma kasdien.'],
            ['Airplane crashed in Liepkalnis, at the intersection of Žirniai and Liepkalnis streets.',
             'Lėktuvas nukrito Liepkalnyje, ties Žirnių ir Liepkalnio gatvėmis.'],
            ['Company DHL\'s commissioned flights were performed by an aircraft belonging to Spanish airlines "Swiftair".',
             'Bendrovės DHL užsakomuosius skrydžius vykdė lėktuvas, priklausęs Ispanijos oro linijoms „Swiftair“.'],
            ['In the internet, when the pilot\'s and flight commander\'s voice recording appeared, it was noticed that the conversation was completely routine, no signs of panic were recorded.',
             'Internete pasirodžius pilotų ir skrydžio vadovo garso įrašui, pastebėta, kad pokalbis buvo visiškai rutininis, nefiksuota jokių nerimo ženklų.'],
            ['DHL informed that due to the plane crash an investigation has been started.',
             'DHL informavo, kad dėl lėktuvo katastrofos pradėtas tyrimas.'],
            ['An incident occurred in the place where it was seen that the aircraft\'s landing gear touched down more than 100 meters away.',
             'Incidento vietoje buvo matyti, kad orlaivio nuolaužos pažiro net 100 m atstumu.'],
            ['Medical staff arrived on the scene within six minutes.',
             'Medikai į įvykio vietą atvyko per 6 minutes.'],
            ['The head of the Vilnius Emergency Medical Assistance Brigade Service Igoris Lukaševas told LRT Radio that the most serious conditions among the wounded crew members are a 54 and 40-year-old people.',
             'Vilniaus greitosios medicinos pagalbos Išvažiuojamųjų brigadų tarnybos vadovas Igoris Lukaševas LRT RADIJUI teigė, kad iš sužeistų įgulos narių sunkiausia būklė – 54 ir 40 metų asmenų.'],
            ['One of them was at least for a time conscious, spoke English.',
             'Vienas jų bent kurį laiką buvo sąmoningas, kalbėjo angliškai.'],
            ['During flight, they were in the pilot\'s cabin.',
             'Skrydžio metu jie buvo piloto kabinoje.'],
            ['Survived a 34-year-old crew member of Lithuanian nationality at the time of misfortune was in the aircraft cabin, his injuries were lighter.',
             'Išgyvenęs 34 metų amžiaus įgulos narys lietuvis nelaimės metu buvo orlaivio salone, jo sužalojimai lengvesni.'],
            ['The Mayor of Vilnius Valdas Benkunskas informed that a state of local extreme emergency would be declared in the disaster area, which would help to take care of residents, manage the territory and provide assistance.',
             'Vilniaus meras Valdas Benkunskas informavo, kad katastrofos teritorijoje bus paskelbta lokali ekstremalioji situacija, tai padės pasirūpinti gyventojais, teritorijos tvarkymu, pagalbos teikimu.'],
            ['According to the mayor, the health of people affected by air and water pollution is not a problem.',
             'Pasak mero, pavojaus žmonių sveikatai dėl oro, vandens užterštumo nėra.'],
            ['Police department together with the General Prosecutor\'s Office started an investigation into the circumstances of the incident to clarify them.',
             'Policijos departamentas kartu su Generaline prokuratūra pradėjo ikiteisminį tyrimą įvykio aplinkybėms išsiaiškinti.'],
            ['We are investigating all possible causes of the accident.',
             'Tiriamos visos galimos avarijos priežastys.'],
            ['The version of terrorism was not excluded, as on June 19, packages were sent from Lithuania via DHL Lietuva that exploded themselves and caused fires in logistics centers in Leipzig and Birmingham.',
             'Terorizmo versija neatmetama, nes liepos 19 d. iš Lietuvos per „DHL Lietuva“ buvo išsiųsti savaime užsidegantys siuntiniai, jie sukėlė gaisrus logistikos centruose Leipcige ir Birmingame.'],
            ['Only by chance, a cargo in Leipzig was not loaded into the aircraft.',
             'Tik per atsitiktinumą krovinys Leipcige tuomet nebuvo pakrautas į orlaivį.'],
            ['There was no indication that the DHL cargo plane crash in Lithuania could be linked to a warning issued by German authorities over the summer about packages carried on planes with explosive devices.',
             'Visgi pirmadienį popiet Vokietijos vidaus reikalų ministerijos atstovas, kurį citavo „Reuters“, teigė, kad nėra jokių požymių, kad DHL krovininio lėktuvo katastrofa Lietuvoje gali būti susijusi su Vokietijos valdžios institucijų vasarą paskelbtu įspėjimu apie lėktuvais skraidintus paketus su padegamaisiais įtaisais.'],
            ['The lecturer of the Antanas Gustaitis Aviation Institute at Vilnius Gediminas Technical University (VILNIUS TECH) Vincas Šnirpūnas told LRT.lt that there may be more than one reason for such events.',
             'Vilniaus Gedimino technikos universiteto (VILNIUS TECH) Antano Gustaičio aviacijos instituto lektorius Vincas Šnirpūnas LRT.lt teigė, kad tokių įvykių priežasčių gali būti ne viena.'],
            ['However, as he says, in any case it is usually related to human error.',
             'Anot jo, vis dėlto dažniausiai tai susiję su žmogiška klaida.']]

new_df = pd.DataFrame(new_data, columns = ['en', 'lt'])
df = pd.concat([data, new_df], ignore_index = True)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.insert(0, 'line_count', range(1, len(df) + 1))
df.to_csv(file_path, index = False)

# %%
# Selecting only the newly added data
subset_sentences = sentences[500:]

# Getting a list of sentences from these lines
subset_all_sentences = split_and_count(subset_sentences)

# Counting words in each sentence from the selected subset
sentence_lengths = [len(sentence.split()) for sentence in subset_all_sentences]

# Computing the average sentence length for the subset
average_length = sum(sentence_lengths) / len(sentence_lengths) if sentence_lengths else 0

print(f"Average sentence length for newly added dataset is {average_length:.2f} words.")
# Out:
# Average sentence length for newly added dataset is 11.89 words.

# %%
# Tokenizing each sentence and counting the tokens
sentence_lengths = [len(word_tokenize(sentence)) for sentence in subset_all_sentences]

# Computing the average token count per sentence
average_tokens = sum(sentence_lengths) / len(sentence_lengths) if sentence_lengths else 0

print(f"Average token count per sentence for the original dataset is {average_tokens:.2f} tokens.")
# Out:
# Average token count per sentence for the original dataset is 13.25 tokens.

# %%
# Vocabulary size & the most frequent words
# Tokenizing the words (+ lowercasing them)
words = []
for sentence in subset_all_sentences:
    words.extend(re.findall(r'\b\w+\b', sentence.lower()))

# Counting the frequency of each word
word_counts = Counter(words)

# Words that appear only once
words_once = [word for word, count in word_counts.items() if count == 1]

# Words that appear more than once and their frequencies
words_more_than_once = {word: count for word, count in word_counts.items() if count > 1}

# Getting the most frequent 30 words
most_common_words = word_counts.most_common(30)

# Separating the words and their frequencies
words, frequencies = zip(*most_common_words)

print(f"Vocabulary size (new dataset): {len(word_counts)}")
print(f"Number of words that appear only once (new dataset) (new dataset): {len(words_once)}")
print(f"Words that appear more than once and their frequencies (new dataset): {words_more_than_once}")

# Plotting the bar chart with the "viridis" color palette
plt.figure(figsize=(10, 6))
sns.barplot(x=frequencies, y=words, palette="viridis")

# Adding labels and title
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title('Top 30 Most Frequent Words (New Dataset)')

# Adding values on the columns
for i, v in enumerate(frequencies):
    plt.text(v + 0.1, i, str(v), color='black', va='center', fontsize=12)

# Saving the graph
plt.savefig('top_30_most_frequent_words_plot_new.png', dpi=300, bbox_inches='tight')

# Showing the plot
plt.show()
# Out:
# Vocabulary size (new dataset): 256
# Number of words that appear only once (new dataset) (new dataset): 212
# Words that appear more than once and their frequencies (new dataset): {'per': 4, 'vienas': 3, 'iš': 4, 'jų': 2, 'lietuvis': 2, 'pirmadienį': 2, 'kad': 9, 'krovininis': 2, 'lėktuvas': 5, 'nukrito': 2, 'liepkalnyje': 2, 'į': 4, 'vilnių': 2, 'leipcigo': 2, 'vokietijos': 3, 'd': 2, 'oro': 3, 'buvo': 7, 'ir': 4, 'dhl': 4, 'skrydžio': 2, 'jokių': 2, 'informavo': 2, 'dėl': 2, 'lėktuvo': 2, 'katastrofos': 2, 'orlaivio': 2, 'įvykio': 2, 'vilniaus': 3, 'pagalbos': 2, 'lrt': 2, 'teigė': 3, 'įgulos': 2, 'metų': 2, 'kurį': 2, 'metu': 2, 'jie': 2, 'jo': 2, 'tai': 2, 'nėra': 2, 'su': 4, 'leipcige': 2, 'gali': 2, 'būti': 2}
# /var/folders/8n/bffnmy712gb5xcnz6597rjb80000gn/T/ipykernel_75404/135893520.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequencies, y=words, palette="viridis")

# %%
# Vocabulary size & the most frequent words (NO STOPWORDS)
# Loading stopwords from the text file
with open('/Users/urtejakubauskaite/nltk_data/corpora/stopwords/lithuanian.txt', 'r', encoding='utf-8') as f:
    stop_words = set(f.read().splitlines())
    
# Tokenizing the words (+ lowercasing them) while excluding stopwords
words = []
for sentence in subset_all_sentences:
    words.extend([word for word in re.findall(r'\b\w+\b', sentence.lower()) if word not in stop_words])
    
# Counting the frequency of each word
word_counts = Counter(words)

# Words that appear only once
words_once = [word for word, count in word_counts.items() if count == 1]

# Words that appear more than once and their frequencies
words_more_than_once = {word: count for word, count in word_counts.items() if count > 1}

# Getting the most frequent 30 words
most_common_words = word_counts.most_common(30)

# Separating the words and their frequencies
words, frequencies = zip(*most_common_words)

print(f"Vocabulary size (excluding stopwords, new dataset): {len(word_counts)}")
print(f"Number of words that appear only once (excluding stopwords, new dataset) (new dataset): {len(words_once)}")
print(f"Words that appear more than once and their frequencies (excluding stopwords, new dataset): {words_more_than_once}")

# Plotting the bar chart with the "viridis" color palette
plt.figure(figsize=(10, 6))
sns.barplot(x=frequencies, y=words, palette="viridis")

# Adding labels and title
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title('Top 30 Most Frequent Words (New Dataset)')

# Adding values on the columns
for i, v in enumerate(frequencies):
    plt.text(v + 0.1, i, str(v), color='black', va='center', fontsize=12)

# Saving the graph
plt.savefig('top_30_most_frequent_words_plot_excluding_stopwords_new.png', dpi=300, bbox_inches='tight')

# Showing the plot
plt.show()
# Out:
# Vocabulary size (excluding stopwords, new dataset): 232
# Number of words that appear only once (excluding stopwords, new dataset) (new dataset): 197
# Words that appear more than once and their frequencies (excluding stopwords, new dataset): {'jų': 2, 'lietuvis': 2, 'pirmadienį': 2, 'krovininis': 2, 'lėktuvas': 5, 'nukrito': 2, 'liepkalnyje': 2, 'vilnių': 2, 'leipcigo': 2, 'vokietijos': 3, 'd': 2, 'oro': 3, 'buvo': 7, 'dhl': 4, 'skrydžio': 2, 'jokių': 2, 'informavo': 2, 'lėktuvo': 2, 'katastrofos': 2, 'orlaivio': 2, 'įvykio': 2, 'vilniaus': 3, 'pagalbos': 2, 'lrt': 2, 'teigė': 3, 'įgulos': 2, 'metų': 2, 'kurį': 2, 'metu': 2, 'jie': 2, 'jo': 2, 'nėra': 2, 'leipcige': 2, 'gali': 2, 'būti': 2}
# /var/folders/8n/bffnmy712gb5xcnz6597rjb80000gn/T/ipykernel_75404/3982092430.py:32: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=frequencies, y=words, palette="viridis")

# %%
# POS tag counting for each sentence
sentence_pos_counts = []

# POS tagging for each sentence
for sentence in subset_all_sentences:
    # Process the sentence using the Stanza pipeline
    doc = nlp(sentence)
    
    # Count POS tags for this sentence
    pos_counts = Counter(word.upos for sent in doc.sentences for word in sent.words)
    sentence_pos_counts.append(pos_counts)

# Aggregating POS counts across all sentences
total_pos_counts = Counter()
for pos_counts in sentence_pos_counts:
    total_pos_counts.update(pos_counts)

# Calculating the average number of each POS tag per sentence
average_pos_counts = {tag: total / len(subset_all_sentences) for tag, total in total_pos_counts.items()}

# Displaying the results
print("Average number of each POS tag per sentence (new dataset):")
for tag, avg in average_pos_counts.items():
    print(f"{tag}: {avg:.3f}")
# Out:
# Average number of each POS tag per sentence (new dataset):
# ADP: 0.857
# NOUN: 4.643
# PRON: 0.321
# VERB: 1.821
# PUNCT: 1.429
# NUM: 0.429
# AUX: 0.393
# SCONJ: 0.393
# ADJ: 0.464
# PROPN: 1.071
# X: 0.393
# ADV: 0.357
# CCONJ: 0.179
# DET: 0.286
# PART: 0.143
# SYM: 0.036

# %% [markdown]
# # Combined Dataset

# %%
# Getting a list of sentences
combined_sentences = split_and_count(sentences)

# Counting words in each sentence from the whole set
sentence_lengths = [len(sentence.split()) for sentence in combined_sentences]

# Computing the average sentence length for the whole set
average_length = sum(sentence_lengths) / len(sentence_lengths) if sentence_lengths else 0

print(f"Average sentence length for the whole dataset is {average_length:.2f} words.")
# Out:
# Average sentence length for the whole dataset is 4.12 words.

# %%
# Counting tokens in each sentence from the whole set
sentence_lengths = [len(word_tokenize(sentence)) for sentence in combined_sentences]

# Computing the average sentence length for the whole set
average_length = sum(sentence_lengths) / len(sentence_lengths) if sentence_lengths else 0

print(f"Average sentence length for the whole dataset is {average_length:.2f} tokens.")
# Out:
# Average sentence length for the whole dataset is 4.50 tokens.

# %%
# POS tagging
pos_tags = []
for sentence in combined_sentences:
    doc = nlp(sentence)
    for sentence in doc.sentences:
        for word in sentence.words:
            print(f"Word: {word.text}, POS: {word.upos}")
            pos_tags.append(word.upos)
            # Counting the frequency of each POS tag
pos_counts = Counter(pos_tags)
# Out:
# Word: Sutikimas, POS: NOUN
# Word: Vilniuje, POS: PROPN
# Word: Štai, POS: PART
# Word: adresas, POS: NOUN
# Word: Kur, POS: ADV
# Word: gyvena, POS: VERB
# Word: Sigita, POS: PROPN
# Word: Aš, POS: PRON
# Word: ieškau, POS: VERB
# Word: Sigitos, POS: NOUN
# Word: Minutėlę, POS: NOUN
# Word: Atsiprašau, POS: VERB
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: kas, POS: PRON
# Word: Jūs, POS: PRON
# Word: Alio, POS: NOUN
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: esu, POS: AUX
# Word: Jonas, POS: PROPN
# Word: Vasiliauskas, POS: PROPN
# Word: Aš, POS: PRON
# Word: esu, POS: AUX
# Word: iš, POS: ADP
# Word: Lietuvos, POS: PROPN
# Word: Sveiki, POS: ADJ
# Word: atvykę, POS: VERB
# Word: į, POS: ADP
# Word: Vilnių, POS: PROPN
# Word: Jums, POS: PRON
# Word: užsakytas, POS: VERB
# Word: kambarys, POS: NOUN
# Word: viešbutyje, POS: NOUN
# Word: Viešbutis, POS: NOUN
# Word: vadinasi, POS: VERB
# Word: ", POS: PUNCT
# Word: Žaliasis, POS: ADJ
# Word: tiltas, POS: NOUN
# Word: ", POS: PUNCT
# Word: Viešbutis, POS: NOUN
# Word: nedidelis, POS: ADJ
# Word: Jis, POS: PRON
# Word: mažas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: patogus, POS: ADJ
# Word: Kur, POS: ADV
# Word: yra, POS: AUX
# Word: viešbutis, POS: NOUN
# Word: Lengva, POS: ADJ
# Word: surasti, POS: VERB
# Word: ,, POS: PUNCT
# Word: jis, POS: PRON
# Word: netoli, POS: ADV
# Word: Pasukite, POS: VERB
# Word: į, POS: ADP
# Word: Kalvarijos, POS: PROPN
# Word: gatvę, POS: NOUN
# Word: ,, POS: PUNCT
# Word: jis, POS: PRON
# Word: už, POS: ADP
# Word: šimto, POS: NUM
# Word: metrų, POS: NOUN
# Word: dešinėje, POS: NOUN
# Word: Labanaktis, POS: NOUN
# Word: Iki, POS: ADP
# Word: Viešbutyje, POS: NOUN
# Word: Jus, POS: PRON
# Word: sveikina, POS: VERB
# Word: registratorė, POS: NOUN
# Word: Aš, POS: PRON
# Word: Jūsų, POS: PRON
# Word: laukiau, POS: VERB
# Word: Ar, POS: PART
# Word: turite, POS: VERB
# Word: pasą, POS: NOUN
# Word: Jūsų, POS: PRON
# Word: kambario, POS: NOUN
# Word: numeris, POS: NOUN
# Word: septintas, POS: VERB
# Word: Jis, POS: PRON
# Word: antrame, POS: NUM
# Word: aukšte, POS: NOUN
# Word: Jūsų, POS: PRON
# Word: kambarys, POS: NOUN
# Word: Štai, POS: PART
# Word: Jūsų, POS: PRON
# Word: kambarys, POS: NOUN
# Word: Kambarys, POS: NOUN
# Word: puikus, POS: ADJ
# Word: Ant, POS: ADP
# Word: lovos, POS: NOUN
# Word: -, POS: PUNCT
# Word: viena, POS: PRON
# Word: pagalvė, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: norite, POS: VERB
# Word: antrą, POS: NUM
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Užteks, POS: VERB
# Word: vienos, POS: PRON
# Word: Vonia, POS: NOUN
# Word: yra, POS: AUX
# Word: šalia, POS: ADP
# Word: kambario, POS: NOUN
# Word: Ar, POS: PART
# Word: norite, POS: VERB
# Word: išsimaudyti, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: būtų, POS: AUX
# Word: gerai, POS: ADV
# Word: Štai, POS: PART
# Word: muilas, POS: NOUN
# Word: ir, POS: CCONJ
# Word: vonios, POS: NOUN
# Word: rankšluostis, POS: VERB
# Word: Ačiū, POS: PRON
# Word: Rankšluostis, POS: VERB
# Word: didelis, POS: ADJ
# Word: ir, POS: CCONJ
# Word: minkštas, POS: ADJ
# Word: Nuostabu, POS: ADJ
# Word: Viešbučio, POS: NOUN
# Word: registratūroje, POS: NOUN
# Word: Atsiprašau, POS: VERB
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: nepatenkintas, POS: VERB
# Word: kambariu, POS: NOUN
# Word: O, POS: CCONJ
# Word: kas, POS: PRON
# Word: negerai, POS: ADV
# Word: Negaliu, POS: VERB
# Word: miegoti, POS: VERB
# Word: Girdėti, POS: VERB
# Word: triukšmas, POS: NOUN
# Word: gatvėje, POS: NOUN
# Word: Kur, POS: ADV
# Word: yra, POS: AUX
# Word: Jūsų, POS: PRON
# Word: kambarys, POS: NOUN
# Word: Pirmajame, POS: NUM
# Word: aukšte, POS: NOUN
# Word: Mano, POS: PRON
# Word: kambarys, POS: NOUN
# Word: septintas, POS: VERB
# Word: Ar, POS: PART
# Word: norite, POS: VERB
# Word: kambario, POS: NOUN
# Word: penktame, POS: NOUN
# Word: aukšte, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: būtų, POS: AUX
# Word: gerai, POS: ADV
# Word: Ryte, POS: NOUN
# Word: Labas, POS: PROPN
# Word: rytas, POS: PROPN
# Word: Ar, POS: PART
# Word: gerai, POS: ADV
# Word: miegojote, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Puikus, POS: ADJ
# Word: oras, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ar, POS: CCONJ
# Word: ne, POS: PART
# Word: Nustojo, POS: VERB
# Word: lyti, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: puiki, POS: ADJ
# Word: diena, POS: NOUN
# Word: Jau, POS: ADV
# Word: gana, POS: ADV
# Word: šilta, POS: ADJ
# Word: Kiek, POS: ADV
# Word: dabar, POS: ADV
# Word: laiko, POS: NOUN
# Word: Tuoj, POS: ADV
# Word: pažiūrėsiu, POS: VERB
# Word: Tuoj, POS: ADV
# Word: dešimt, POS: PRON
# Word: Pusryčiai, POS: NOUN
# Word: Labas, POS: NOUN
# Word: rytas, POS: PROPN
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: miegojote, POS: VERB
# Word: Labas, POS: PROPN
# Word: rytas, POS: PROPN
# Word: Ką, POS: PRON
# Word: turite, POS: VERB
# Word: pusryčiams, POS: NOUN
# Word: Turime, POS: VERB
# Word: šviežių, POS: NOUN
# Word: bandelių, POS: NOUN
# Word: :, POS: PUNCT
# Word: bandelių, POS: NOUN
# Word: su, POS: ADP
# Word: aguonomis, POS: NOUN
# Word: arba, POS: CCONJ
# Word: minkštų, POS: VERB
# Word: bandelių, POS: NOUN
# Word: su, POS: ADP
# Word: sviestu, POS: VERB
# Word: ,, POS: PUNCT
# Word: medumi, POS: NOUN
# Word: ar, POS: CCONJ
# Word: uogiene, POS: NOUN
# Word: Hm, POS: X
# Word: ,, POS: PUNCT
# Word: kvepia, POS: VERB
# Word: puikiai, POS: ADV
# Word: Norėčiau, POS: VERB
# Word: dviejų, POS: NUM
# Word: Vieną, POS: PRON
# Word: bandelę, POS: NOUN
# Word: su, POS: ADP
# Word: aguonomis, POS: NOUN
# Word: ir, POS: CCONJ
# Word: vieną, POS: PRON
# Word: minkštą, POS: NOUN
# Word: su, POS: ADP
# Word: sviestu, POS: NOUN
# Word: ir, POS: CCONJ
# Word: medumi, POS: NOUN
# Word: Taip, POS: PART
# Word: pat, POS: X
# Word: norėčiau, POS: VERB
# Word: stiklinę, POS: ADJ
# Word: apelsinų, POS: ADJ
# Word: sulčių, POS: NOUN
# Word: ir, POS: CCONJ
# Word: puodelį, POS: NOUN
# Word: kavos, POS: NOUN
# Word: Dar, POS: ADV
# Word: kavos, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Padavėjas, POS: NOUN
# Word: šypsosi, POS: VERB
# Word: Kur, POS: ADV
# Word: Jūs, POS: PRON
# Word: gyvenate, POS: VERB
# Word: Aš, POS: PRON
# Word: gyvenu, POS: VERB
# Word: Toronte, POS: PROPN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: pirmą, POS: NUM
# Word: kartą, POS: NOUN
# Word: Vilniuje, POS: PROPN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: man, POS: PRON
# Word: patinka, POS: VERB
# Word: Vilnius, POS: PROPN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: mane, POS: PRON
# Word: suprantate, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: Jūs, POS: PRON
# Word: puikiai, POS: ADV
# Word: kalbate, POS: VERB
# Word: lietuviškai, POS: ADV
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: daug, POS: ADV
# Word: suprantu, POS: VERB
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: kalbėkite, POS: VERB
# Word: lėčiau, POS: ADV
# Word: prašom, POS: VERB
# Word: Laikrodis, POS: NOUN
# Word: Dabar, POS: ADV
# Word: dešimt, POS: NUM
# Word: valandų, POS: NOUN
# Word: Penkiolika, POS: NUM
# Word: minučių, POS: NOUN
# Word: po, POS: ADP
# Word: dešimtos, POS: NOUN
# Word: Ketvirtis, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Dešimt, POS: NUM
# Word: valandų, POS: NOUN
# Word: trisdešimt, POS: NUM
# Word: minučių, POS: NOUN
# Word: arba, POS: CCONJ
# Word: puse, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Dešimt, POS: NUM
# Word: valandų, POS: NOUN
# Word: keturiasdešimt, POS: NUM
# Word: penkios, POS: NUM
# Word: minutės, POS: NOUN
# Word: arba, POS: CCONJ
# Word: be, POS: ADP
# Word: penkiolikos, POS: NUM
# Word: minučių, POS: NOUN
# Word: vienuolika, POS: PRON
# Word: Pokalbis, POS: NOUN
# Word: telefonu, POS: NOUN
# Word: Sveika, POS: ADJ
# Word: Sigita, POS: PROPN
# Word: ,, POS: PUNCT
# Word: čia, POS: ADV
# Word: Katlyna, POS: PROPN
# Word: Sveika, POS: ADJ
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: sekasi, POS: VERB
# Word: Ačiū, POS: VERB
# Word: ,, POS: PUNCT
# Word: puikiai, POS: ADV
# Word: Aš, POS: PRON
# Word: einu, POS: VERB
# Word: dabar, POS: ADV
# Word: apsipirkti, POS: VERB
# Word: Aš, POS: PRON
# Word: taip, POS: ADV
# Word: pat, POS: X
# Word: Ruošiuosi, POS: VERB
# Word: eiti, POS: VERB
# Word: į, POS: ADP
# Word: turgų, POS: NOUN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: šiandien, POS: ADV
# Word: juk, POS: PART
# Word: turgaus, POS: NOUN
# Word: diena, POS: NOUN
# Word: Tada, POS: ADV
# Word: aš, POS: PRON
# Word: irgi, POS: ADV
# Word: eisiu, POS: VERB
# Word: į, POS: ADP
# Word: turgų, POS: NOUN
# Word: Ar, POS: PART
# Word: susitiksime, POS: VERB
# Word: Ar, POS: PART
# Word: tai, POS: DET
# Word: įmanoma, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: kur, POS: ADV
# Word: galėtumėm, POS: VERB
# Word: susitikti, POS: VERB
# Word: Prie, POS: ADP
# Word: pirmo, POS: NUM
# Word: prekystalio, POS: NOUN
# Word: Kada, POS: ADV
# Word: Tiksliai, POS: ADV
# Word: dešimtą, POS: NOUN
# Word: Ar, POS: PART
# Word: tinka, POS: VERB
# Word: Kiek, POS: ADV
# Word: dabar, POS: ADV
# Word: Greitai, POS: ADV
# Word: dešimt, POS: NUM
# Word: Iki, POS: ADP
# Word: Greitai, POS: ADV
# Word: pasimatysime, POS: VERB
# Word: Turguje, POS: NOUN
# Word: Ach, POS: X
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: puikiai, POS: ADV
# Word: kvepia, POS: VERB
# Word: braškės, POS: NOUN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: braškės, POS: NOUN
# Word: mano, POS: PRON
# Word: mėgstamiausios, POS: ADJ
# Word: uogos, POS: NOUN
# Word: Bet, POS: CCONJ
# Word: Ana, POS: NOUN
# Word: ,, POS: PUNCT
# Word: braškės, POS: NOUN
# Word: ne, POS: PART
# Word: šviežios, POS: ADJ
# Word: Ne, POS: PART
# Word: šviežios, POS: ADJ
# Word: Kaip, POS: ADV
# Word: gaila, POS: ADV
# Word: Prie, POS: ADP
# Word: daržovių, POS: NOUN
# Word: prekystalio, POS: ADJ
# Word: Man, POS: PRON
# Word: prašau, POS: VERB
# Word: ilgą, POS: ADJ
# Word: agurką, POS: NOUN
# Word: Dar, POS: PART
# Word: ką, POS: PRON
# Word: nors, POS: X
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: prašau, POS: VERB
# Word: gražių, POS: ADJ
# Word: salotų, POS: NOUN
# Word: Trys, POS: NUM
# Word: litai, POS: NOUN
# Word: Štai, POS: PART
# Word: dvidešimt, POS: NUM
# Word: litų, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Dešimt, POS: NUM
# Word: litų, POS: NOUN
# Word: ir, POS: CCONJ
# Word: vienas, POS: PRON
# Word: ,, POS: PUNCT
# Word: du, POS: NUM
# Word: ,, POS: PUNCT
# Word: trys, POS: NUM
# Word: ,, POS: PUNCT
# Word: keturi, POS: NUM
# Word: ,, POS: PUNCT
# Word: penki, POS: NUM
# Word: ,, POS: PUNCT
# Word: šeši, POS: NUM
# Word: ,, POS: PUNCT
# Word: septyni, POS: NUM
# Word: litai, POS: NOUN
# Word: grąžos, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Pas, POS: ADP
# Word: Sigitą, POS: PROPN
# Word: Aš, POS: PRON
# Word: alkanas(, POS: ADJ
# Word: -a, POS: NOUN
# Word: ), POS: PUNCT
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: tu, POS: PRON
# Word: Taip, POS: ADV
# Word: Kada, POS: ADV
# Word: priešpiečiai, POS: NOUN
# Word: Už, POS: ADP
# Word: kelių, POS: NUM
# Word: minučių, POS: NOUN
# Word: Saulė, POS: NOUN
# Word: šviečia, POS: VERB
# Word: Galėtumėm, POS: VERB
# Word: valgyti, POS: VERB
# Word: balkone, POS: NOUN
# Word: Puiku, POS: ADJ
# Word: Aš, POS: PRON
# Word: padengsiu, POS: VERB
# Word: stalą, POS: NOUN
# Word: Ką, POS: PRON
# Word: mes, POS: PRON
# Word: valgysim, POS: VERB
# Word: Šeduvos, POS: PROPN
# Word: sūrį, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kiaušinius, POS: NOUN
# Word: ir, POS: CCONJ
# Word: salotas, POS: NOUN
# Word: Gal, POS: PART
# Word: norėtum, POS: VERB
# Word: omleto, POS: PUNCT
# Word: Omleto, POS: PROPN
# Word: Ačiū, POS: VERB
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: nemėgstu, POS: VERB
# Word: Aš, POS: PRON
# Word: dar, POS: ADV
# Word: turiu, POS: VERB
# Word: keletą, POS: PRON
# Word: bandelių, POS: NOUN
# Word: Porą, POS: NOUN
# Word: bandelių, POS: NOUN
# Word: prašom, POS: VERB
# Word: Ar, POS: PART
# Word: galėtumėm, POS: VERB
# Word: šiandien, POS: ADV
# Word: susitikti, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: galim, POS: VERB
# Word: Gal, POS: PART
# Word: 9, POS: NUM
# Word: valandą, POS: NOUN
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: man, POS: PRON
# Word: netinka, POS: VERB
# Word: Aš, POS: PRON
# Word: norėčiau, POS: VERB
# Word: eiti, POS: VERB
# Word: apsipirkti, POS: VERB
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: parduotuvės, POS: NOUN
# Word: dirba, POS: VERB
# Word: nuo, POS: ADP
# Word: 8:30, POS: NUM
# Word: Tada, POS: ADV
# Word: būtų, POS: AUX
# Word: gerai, POS: ADV
# Word: puse, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Puiku, POS: ADJ
# Word: ,, POS: PUNCT
# Word: puse, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Kur, POS: ADV
# Word: mes, POS: PRON
# Word: susitiksime, POS: VERB
# Word: Gal, POS: PART
# Word: prie, POS: ADP
# Word: Hermio, POS: NOUN
# Word: banko, POS: NOUN
# Word: Oi, POS: VERB
# Word: ne, POS: PART
# Word: ,, POS: PUNCT
# Word: ne, POS: PART
# Word: ten, POS: ADV
# Word: Geriau, POS: ADV
# Word: kitoje, POS: PRON
# Word: pusėje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: Neringos, POS: ADJ
# Word: kavinėje, POS: NOUN
# Word: Gerai, POS: ADV
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: būsiu, POS: VERB
# Word: ten, POS: ADV
# Word: puse, POS: NOUN
# Word: vienuoliktos, POS: NOUN
# Word: Vyriškų, POS: ADJ
# Word: drabužių, POS: NOUN
# Word: parduotuvėje, POS: NOUN
# Word: Laba, POS: PROPN
# Word: diena, POS: NOUN
# Word: Kuo, POS: PRON
# Word: galiu, POS: VERB
# Word: padėti, POS: VERB
# Word: Norėčiau, POS: VERB
# Word: keletą, POS: PRON
# Word: porų, POS: NOUN
# Word: medvilninių, POS: ADJ
# Word: kojinių, POS: NOUN
# Word: Kokio, POS: DET
# Word: dydžio, POS: NOUN
# Word: Aš, POS: PRON
# Word: nešioju, POS: VERB
# Word: 43, POS: NUM
# Word: dydį, POS: NOUN
# Word: Štai, POS: PART
# Word: šitose, POS: PRON
# Word: yra, POS: VERB
# Word: 70, POS: NUM
# Word: %, POS: X
# Word: medvilnės, POS: NOUN
# Word: ir, POS: CCONJ
# Word: 30, POS: NUM
# Word: %, POS: X
# Word: neilono, POS: PUNCT
# Word: Mes, POS: PRON
# Word: neturime, POS: VERB
# Word: grynai, POS: ADV
# Word: medvilninių, POS: ADJ
# Word: Jos, POS: PRON
# Word: nepraktiškos, POS: ADJ
# Word: Atsiprašome, POS: VERB
# Word: Gaila, POS: ADV
# Word: Viso, POS: DET
# Word: gero, POS: ADV
# Word: Neringos, POS: PROPN
# Word: kavinėje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kavos, POS: NOUN
# Word: užsakymas, POS: NOUN
# Word: Galiu, POS: VERB
# Word: Jus, POS: PRON
# Word: pakviesti, POS: VERB
# Word: puodukui, POS: NOUN
# Word: kavos, POS: NOUN
# Word: Ačiū, POS: VERB
# Word: ,, POS: PUNCT
# Word: Jūs, POS: PRON
# Word: labai, POS: ADV
# Word: maloni, POS: ADJ
# Word: Pyragaičiai, POS: NOUN
# Word: labai, POS: ADV
# Word: skanūs, POS: ADJ
# Word: Norite, POS: VERB
# Word: dar, POS: PART
# Word: gabaliuko, POS: NOUN
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Tik, POS: PART
# Word: juodos, POS: ADJ
# Word: kavos, POS: NOUN
# Word: ,, POS: PUNCT
# Word: prašom, POS: VERB
# Word: Padavėjau, POS: VERB
# Word: ,, POS: PUNCT
# Word: puodelį, POS: NOUN
# Word: juodos, POS: ADJ
# Word: kavos, POS: NOUN
# Word: be, POS: ADP
# Word: grietinėlės, POS: NOUN
# Word: ir, POS: CCONJ
# Word: kavinuką, POS: NOUN
# Word: kavos, POS: NOUN
# Word: prašom, POS: NOUN
# Word: Galite, POS: VERB
# Word: man, POS: PRON
# Word: paduoti, POS: VERB
# Word: cukraus, POS: NOUN
# Word: Prašau, POS: VERB
# Word: Priėmime, POS: NOUN
# Word: Štai, POS: PART
# Word: vynas, POS: NOUN
# Word: Ar, POS: PART
# Word: norėtumėte, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: prašau, POS: VERB
# Word: Ateina, POS: VERB
# Word: mūsų, POS: PRON
# Word: šeimininkė, POS: NOUN
# Word: Laba, POS: PROPN
# Word: diena, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ponia, POS: PROPN
# Word: Becker, POS: PROPN
# Word: Malonu, POS: ADJ
# Word: Jus, POS: PRON
# Word: matyti, POS: VERB
# Word: Labai, POS: ADV
# Word: šilta, POS: ADJ
# Word: šiandien, POS: ADV
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: ne, POS: PART
# Word: tiesa, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: iš, POS: ADV
# Word: tikrųjų, POS: X
# Word: Bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: mėgstu, POS: VERB
# Word: šiltą, POS: ADJ
# Word: orą, POS: NOUN
# Word: Tikrai, POS: ADV
# Word: karšta, POS: ADJ
# Word: šiandien, POS: ADV
# Word: Jus, POS: PRON
# Word: su, POS: ADP
# Word: švarku, POS: NOUN
# Word: ir, POS: CCONJ
# Word: kaklaraiščiu, POS: NOUN
# Word: Galite, POS: VERB
# Word: nusirengti, POS: VERB
# Word: ,, POS: PUNCT
# Word: jei, POS: SCONJ
# Word: norite, POS: VERB
# Word: Universalinėje, POS: ADJ
# Word: parduotuvėje, POS: NOUN
# Word: ;, POS: PUNCT
# Word: ką, POS: PRON
# Word: nors, POS: X
# Word: pasimatuoti, POS: VERB
# Word: Ši, POS: DET
# Word: suknelė, POS: NOUN
# Word: 40, POS: NUM
# Word: dydžio, POS: NOUN
# Word: Ji, POS: PRON
# Word: per, POS: PART
# Word: maža, POS: ADJ
# Word: man, POS: PRON
# Word: Ar, POS: PART
# Word: neturite, POS: VERB
# Word: 42, POS: NUM
# Word: dydžio, POS: NOUN
# Word: Gaila, POS: ADV
# Word: ,, POS: PUNCT
# Word: neturime, POS: VERB
# Word: Bet, POS: CCONJ
# Word: pasimatuokite, POS: VERB
# Word: Gal, POS: PART
# Word: tiks, POS: VERB
# Word: Na, POS: INTJ
# Word: gerai, POS: ADV
# Word: Kur, POS: ADV
# Word: galima, POS: VERB
# Word: pasimatuoti, POS: VERB
# Word: Štai, POS: PART
# Word: ten, POS: ADV
# Word: ,, POS: PUNCT
# Word: prie, POS: ADP
# Word: didelio, POS: ADJ
# Word: veidrodžio, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Viešbutis, POS: NOUN
# Word: Astorija, POS: PROPN
# Word: Užsakyti, POS: VERB
# Word: kambarį, POS: NOUN
# Word: (, POS: PUNCT
# Word: telefonu, POS: NOUN
# Word: ), POS: PUNCT
# Word: Viešbutis, POS: NOUN
# Word: Astorija, POS: PROPN
# Word: ,, POS: PUNCT
# Word: Berlynas, POS: PROPN
# Word: Kuo, POS: PRON
# Word: galiu, POS: VERB
# Word: Jums, POS: PRON
# Word: padėti, POS: VERB
# Word: Ar, POS: PART
# Word: turite, POS: VERB
# Word: laisvų, POS: ADJ
# Word: kambarių, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: turime, POS: VERB
# Word: Kada, POS: ADV
# Word: norėsite, POS: VERB
# Word: Rytoj, POS: PRON
# Word: vakare, POS: NOUN
# Word: iki, POS: ADP
# Word: ketvirtadienio, POS: NOUN
# Word: ,, POS: PUNCT
# Word: vienai, POS: DET
# Word: nakčiai, POS: NOUN
# Word: Taip, POS: PART
# Word: dar, POS: X
# Word: turime, POS: VERB
# Word: laisvų, POS: ADJ
# Word: kambarių, POS: NOUN
# Word: Kokio, POS: DET
# Word: Jūs, POS: PRON
# Word: norėtumėte, POS: VERB
# Word: Dvi, POS: NUM
# Word: vienutes, POS: NOUN
# Word: su, POS: ADP
# Word: voniomis, POS: NOUN
# Word: Dvi, POS: NUM
# Word: vienutes, POS: NOUN
# Word: su, POS: ADP
# Word: voniomis, POS: NOUN
# Word: Jūsų, POS: PRON
# Word: pavardė, POS: NOUN
# Word: Vilsonas, POS: PROPN
# Word: ir, POS: CCONJ
# Word: Holzas, POS: PROPN
# Word: Tai, POS: DET
# Word: ponia, POS: VERB
# Word: Holz, POS: VERB
# Word: ir, POS: PART
# Word: aš, POS: PRON
# Word: Aš, POS: PRON
# Word: užrašiau, POS: VERB
# Word: ,, POS: PUNCT
# Word: ponas, POS: NOUN
# Word: Vilsonai, POS: PROPN
# Word: Prašau, POS: VERB
# Word: rytoj, POS: ADV
# Word: kreiptis, POS: VERB
# Word: į, POS: ADP
# Word: registratūrą, POS: NOUN
# Word: iki, POS: ADP
# Word: 14, POS: NUM
# Word: val, POS: PUNCT
# Word: Kitaip, POS: ADV
# Word: mes, POS: PRON
# Word: negarantuojame, POS: VERB
# Word: Jums, POS: PRON
# Word: kambario, POS: NOUN
# Word: Ačiū, POS: VERB
# Word: ,, POS: PUNCT
# Word: viso, POS: DET
# Word: gero, POS: PRON
# Word: Telegramos, POS: NOUN
# Word: perskaitymas, POS: NOUN
# Word: Čia, POS: ADV
# Word: yra, POS: AUX
# Word: telegrama, POS: NOUN
# Word: Jums, POS: PRON
# Word: Man, POS: PRON
# Word: Keista, POS: ADJ
# Word: Nuo, POS: ADP
# Word: ko, POS: PRON
# Word: Aš, POS: PRON
# Word: nežinau, POS: VERB
# Word: Atidaryk, POS: VERB
# Word: ir, POS: CCONJ
# Word: perskaityk, POS: PROPN
# Word: Atvykstu, POS: VERB
# Word: viena, POS: PRON
# Word: diena, POS: NOUN
# Word: vėliau, POS: ADV
# Word: -, POS: PUNCT
# Word: taškas, POS: NOUN
# Word: -, POS: PUNCT
# Word: pasilik, POS: PUNCT
# Word: Berlyne, POS: PROPN
# Word: -, POS: PUNCT
# Word: taškas, POS: NOUN
# Word: -, POS: PUNCT
# Word: gal, POS: PART
# Word: pasižvalgyk, POS: VERB
# Word: mieste, POS: NOUN
# Word: -, POS: PUNCT
# Word: taškas, POS: NOUN
# Word: -, POS: PUNCT
# Word: Pasimatysime, POS: VERB
# Word: -, POS: PUNCT
# Word: taškas, POS: NOUN
# Word: -, POS: PUNCT
# Word: Peter, POS: X
# Word: H, POS: X
# Word: Taigi, POS: PART
# Word: ,, POS: PUNCT
# Word: pasilieki, POS: VERB
# Word: Na, POS: INTJ
# Word: ,, POS: PUNCT
# Word: žinoma, POS: VERB
# Word: Dar, POS: PART
# Word: viena, POS: PRON
# Word: žinutė, POS: NOUN
# Word: Klausyk, POS: VERB
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: atvykstu, POS: VERB
# Word: ar, POS: CCONJ
# Word: Tu, POS: PRON
# Word: atvyksti, POS: PUNCT
# Word: Savaitgalyje, POS: NOUN
# Word: ar, POS: CCONJ
# Word: penktadienį, POS: NOUN
# Word: Pilyje, POS: NOUN
# Word: ar, POS: CCONJ
# Word: pilies, POS: NOUN
# Word: sode, POS: NOUN
# Word: Kur, POS: ADV
# Word: susitinkame, POS: VERB
# Word: Kas, POS: PRON
# Word: tai, POS: DET
# Word: siunčia, POS: VERB
# Word: Neįsivaizduoju, POS: VERB
# Word: Gal, POS: PART
# Word: dvasia, POS: NOUN
# Word: Labai, POS: ADV
# Word: keista, POS: ADJ
# Word: Kaip, POS: SCONJ
# Word: detektyve, POS: NOUN
# Word: Čia, POS: ADV
# Word: mašinas, POS: NOUN
# Word: statyti, POS: VERB
# Word: draudžiama, POS: VERB
# Word: Aš, POS: PRON
# Word: nežinojau, POS: VERB
# Word: Aš, POS: PRON
# Word: tuoj, POS: ADV
# Word: pat, POS: X
# Word: išvažiuosiu, POS: VERB
# Word: Savaitgaliais, POS: NOUN
# Word: galima, POS: VERB
# Word: O, POS: CCONJ
# Word: kokia, POS: DET
# Word: šiandien, POS: ADV
# Word: diena, POS: NOUN
# Word: Trečiadienis, POS: NOUN
# Word: Gaila, POS: ADV
# Word: Bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: negaliu, POS: VERB
# Word: dvi, POS: NUM
# Word: dienas, POS: NOUN
# Word: laukti, POS: VERB
# Word: Gaila, POS: ADV
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: niekuo, POS: PRON
# Word: negaliu, POS: VERB
# Word: padėti, POS: VERB
# Word: Paklausti, POS: VERB
# Word: apie, POS: ADP
# Word: viešąjį, POS: ADJ
# Word: transportą, POS: NOUN
# Word: Kur, POS: ADV
# Word: Jūs, POS: PRON
# Word: norėtumėte, POS: VERB
# Word: nueiti, POS: VERB
# Word: Į, POS: ADP
# Word: pilį, POS: NOUN
# Word: Metro, POS: NOUN
# Word: ar, POS: CCONJ
# Word: autobusu, POS: NOUN
# Word: O, POS: CCONJ
# Word: kaip, POS: SCONJ
# Word: geriau, POS: ADV
# Word: Metro, POS: NOUN
# Word: -, POS: PUNCT
# Word: greičiau, POS: ADV
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: autobusu, POS: NOUN
# Word: -, POS: PUNCT
# Word: pigiau, POS: ADV
# Word: Tada, POS: ADV
# Word: autobusu, POS: NOUN
# Word: Kuris, POS: DET
# Word: autobusas, POS: NOUN
# Word: 48, POS: NUM
# Word: numeris, POS: NOUN
# Word: važiuoja, POS: VERB
# Word: tiesiai, POS: ADV
# Word: prie, POS: ADP
# Word: pilies, POS: NOUN
# Word: Kur, POS: ADV
# Word: sustojimas, POS: NOUN
# Word: Sustojimas, POS: NOUN
# Word: čia, POS: PART
# Word: pat, POS: X
# Word: ,, POS: PUNCT
# Word: už, POS: ADP
# Word: kampo, POS: NOUN
# Word: ,, POS: PUNCT
# Word: dešinėje, POS: ADJ
# Word: pusėje, POS: NOUN
# Word: Dešinėje, POS: NOUN
# Word: Aš, POS: PRON
# Word: visai, POS: ADV
# Word: užmiršau, POS: VERB
# Word: Didelis, POS: ADJ
# Word: ačiū, POS: PRON
# Word: Nėr, POS: VERB
# Word: už, POS: ADP
# Word: ką, POS: PRON
# Word: Avarija, POS: NOUN
# Word: Kas, POS: PRON
# Word: atsitiko, POS: VERB
# Word: Avarija, POS: NOUN
# Word: Kanto, POS: PROPN
# Word: gatvėje, POS: NOUN
# Word: Kaip, POS: ADV
# Word: tai, POS: DET
# Word: buvo, POS: VERB
# Word: Šviesoforas, POS: NOUN
# Word: kryžkelėje, POS: NOUN
# Word: nedirba, POS: VERB
# Word: Susidūrė, POS: VERB
# Word: trys, POS: NUM
# Word: automobiliai, POS: NOUN
# Word: Ar, POS: PART
# Word: kas, POS: PRON
# Word: nors, POS: X
# Word: sužeistas, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: du, POS: NUM
# Word: vairuotojai, POS: NOUN
# Word: sunkiai, POS: ADV
# Word: sužeisti, POS: VERB
# Word: ,, POS: PUNCT
# Word: ačiū, POS: VERB
# Word: Dievui, POS: NOUN
# Word: -, POS: PUNCT
# Word: kiti, POS: PRON
# Word: nesunkiai, POS: ADV
# Word: Kada, POS: ADV
# Word: tai, POS: DET
# Word: atsitiko, POS: VERB
# Word: Prieš, POS: ADP
# Word: dešimt, POS: NUM
# Word: minučių, POS: NOUN
# Word: Kažkas, POS: PRON
# Word: iškvietė, POS: VERB
# Word: greitąją, POS: ADJ
# Word: Ji, POS: PRON
# Word: greitai, POS: ADV
# Word: atvyks, POS: VERB
# Word: Tikėkimės, POS: NOUN
# Word: Toks, POS: DET
# Word: didelis, POS: ADJ
# Word: judėjimas, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ar, POS: CCONJ
# Word: ne, POS: PART
# Word: Apie, POS: ADP
# Word: nesusipratimus, POS: VERB
# Word: telefonu, POS: NOUN
# Word: Alio, POS: PROPN
# Word: ,, POS: PUNCT
# Word: Sauer, POS: X
# Word: &, POS: X
# Word: Co, POS: PUNCT
# Word: Labas, POS: PROPN
# Word: rytas, POS: PROPN
# Word: Bekerio, POS: PROPN
# Word: mados, POS: NOUN
# Word: Šiandien, POS: ADV
# Word: gavome, POS: VERB
# Word: Jūsų, POS: PRON
# Word: siuntinį, POS: NOUN
# Word: Apie, POS: ADP
# Word: kurį, POS: DET
# Word: siuntinį, POS: NOUN
# Word: Jūs, POS: PRON
# Word: kalbate, POS: VERB
# Word: Siuntinys, POS: NOUN
# Word: su, POS: ADP
# Word: kojinėmis, POS: NOUN
# Word: Prisimenu, POS: VERB
# Word: Gerai, POS: ADV
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: gavote, POS: VERB
# Word: Visai, POS: ADV
# Word: ne, POS: PART
# Word: gerai, POS: ADV
# Word: Jame, POS: PRON
# Word: 300, POS: NUM
# Word: porų, POS: NOUN
# Word: pilkų, POS: NOUN
# Word: kojinių, POS: NOUN
# Word: Teisingai, POS: ADV
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: neteisingai, POS: ADV
# Word: ,, POS: PUNCT
# Word: panele, POS: PROPN
# Word: Ponia, POS: PROPN
# Word: Ponia, POS: PROPN
# Word: Ernst, POS: PROPN
# Word: Ponia, POS: NOUN
# Word: Ernst, POS: X
# Word: ,, POS: PUNCT
# Word: mes, POS: PRON
# Word: iš, POS: ADV
# Word: tikrųjų, POS: X
# Word: neužsakėme, POS: VERB
# Word: 300, POS: NUM
# Word: porų, POS: NOUN
# Word: pilkų, POS: NOUN
# Word: kojinių, POS: NOUN
# Word: Užsakėte, POS: VERB
# Word: Aš, POS: PRON
# Word: matau, POS: VERB
# Word: knygoje, POS: NOUN
# Word: Ponia, POS: NOUN
# Word: Ernst, POS: X
# Word: ,, POS: PUNCT
# Word: kažkas, POS: PRON
# Word: čia, POS: ADV
# Word: negerai, POS: ADV
# Word: Mes, POS: PRON
# Word: užsakėme, POS: VERB
# Word: 30, POS: NUM
# Word: porų, POS: NOUN
# Word: pilkų, POS: NOUN
# Word: kojinių, POS: NOUN
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: ne, POS: PART
# Word: 300, POS: NUM
# Word: Ne, POS: PART
# Word: 300, POS: NUM
# Word: Ach, POS: X
# Word: ,, POS: PUNCT
# Word: išsiųskite, POS: VERB
# Word: mums, POS: PRON
# Word: ,, POS: PUNCT
# Word: jeigu, POS: SCONJ
# Word: Jūs, POS: PRON
# Word: jų, POS: PRON
# Word: nenorite, POS: VERB
# Word: Viso, POS: DET
# Word: gero, POS: ADV
# Word: Aš, POS: PRON
# Word: tiesiog, POS: ADV
# Word: nežinau, POS: VERB
# Word: ,, POS: PUNCT
# Word: ką, POS: PRON
# Word: pasakyti, POS: VERB
# Word: Bet, POS: CCONJ
# Word: ką, POS: PRON
# Word: aš, POS: PRON
# Word: galiu, POS: VERB
# Word: padaryti, POS: VERB
# Word: Susitikimas, POS: NOUN
# Word: lėktuve, POS: NOUN
# Word: Sveika, POS: ADJ
# Word: ,, POS: PUNCT
# Word: ponia, POS: NOUN
# Word: Šmidt, POS: PUNCT
# Word: Koks, POS: DET
# Word: netikėtumas, POS: NOUN
# Word: Jus, POS: PRON
# Word: čia, POS: ADV
# Word: lėktuve, POS: NOUN
# Word: sutikti, POS: VERB
# Word: Tikrai, POS: ADV
# Word: Kaip, POS: ADV
# Word: sekasi, POS: VERB
# Word: Puikiai, POS: ADV
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: Jums, POS: PRON
# Word: Kur, POS: ADV
# Word: Jūs, POS: PRON
# Word: vykstate, POS: VERB
# Word: Ruošiuosi, POS: VERB
# Word: aplankyti, POS: VERB
# Word: savo, POS: PRON
# Word: sūnų, POS: NOUN
# Word: Jis, POS: PRON
# Word: gyvena, POS: VERB
# Word: Šveicarijoje, POS: PROPN
# Word: O, POS: CCONJ
# Word: Jūs, POS: PRON
# Word: Aš, POS: PRON
# Word: vėl, POS: ADV
# Word: komandiruotėje, POS: NOUN
# Word: Aš, POS: PRON
# Word: dažnai, POS: ADV
# Word: skrendu, POS: VERB
# Word: šiuo, POS: DET
# Word: maršrutu, POS: NOUN
# Word: Matau, POS: VERB
# Word: Kaip, POS: ADV
# Word: dažnai, POS: ADV
# Word: Maždaug, POS: ADV
# Word: tris, POS: NUM
# Word: kartus, POS: NOUN
# Word: per, POS: ADP
# Word: mėnesį, POS: NOUN
# Word: O, POS: CCONJ
# Word: aš, POS: PRON
# Word: skrendu, POS: VERB
# Word: šiandien, POS: ADV
# Word: antrą, POS: NUM
# Word: kartą, POS: NOUN
# Word: Ne, POS: PART
# Word: nuostabu, POS: ADJ
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: mes, POS: PRON
# Word: ne, POS: PART
# Word: dažnai, POS: ADV
# Word: susitinkame, POS: VERB
# Word: Pokalbis, POS: NOUN
# Word: apie, POS: ADP
# Word: pomėgius, POS: NOUN
# Word: Kuo, POS: PRON
# Word: Jūs, POS: PRON
# Word: domitės, POS: NOUN
# Word: Kaip, POS: ADV
# Word: čia, POS: ADV
# Word: pasakius, POS: VERB
# Word: Aš, POS: PRON
# Word: domiuosi, POS: VERB
# Word: daugeliu, POS: NOUN
# Word: dalykų, POS: NOUN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: domitės, POS: NOUN
# Word: menu, POS: NOUN
# Word: Žiūrint, POS: ADP
# Word: ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: galvoje, POS: NOUN
# Word: Tapybą, POS: NOUN
# Word: O, POS: CCONJ
# Word: taip, POS: ADV
# Word: Man, POS: PRON
# Word: patinka, POS: VERB
# Word: tapyba, POS: NOUN
# Word: Kokia, POS: DET
# Word: tapybos, POS: NOUN
# Word: rūšimi, POS: NOUN
# Word: Jūs, POS: PRON
# Word: daugiausiai, POS: ADV
# Word: domitės, POS: NOUN
# Word: Ekspresionistai, POS: NOUN
# Word: ,, POS: PUNCT
# Word: pavyzdžiui, POS: NOUN
# Word: tokie, POS: DET
# Word: kaip, POS: SCONJ
# Word: Kandinskis, POS: PROPN
# Word: ir, POS: CCONJ
# Word: Šmidt-Rotlufas, POS: PROPN
# Word: Aš, POS: PRON
# Word: juos, POS: PRON
# Word: abu, POS: NUM
# Word: mėgstu, POS: VERB
# Word: Taigi, POS: PART
# Word: ,, POS: PUNCT
# Word: Jūs, POS: PRON
# Word: domitės, POS: NOUN
# Word: tik, POS: PART
# Word: moderniu, POS: ADJ
# Word: menu, POS: NOUN
# Word: O, POS: CCONJ
# Word: ne, POS: PART
# Word: Man, POS: PRON
# Word: patinka, POS: VERB
# Word: ir, POS: PART
# Word: impresionistai, POS: NOUN
# Word: ,, POS: PUNCT
# Word: nors, POS: SCONJ
# Word: ne, POS: PART
# Word: perdaug, POS: PUNCT
# Word: O, POS: CCONJ
# Word: man, POS: PRON
# Word: visai, POS: ADV
# Word: nepatinka, POS: VERB
# Word: tapyba, POS: NOUN
# Word: Aš, POS: PRON
# Word: domiuosi, POS: VERB
# Word: fotografija, POS: NOUN
# Word: Pokalbis, POS: NOUN
# Word: apie, POS: ADP
# Word: orą, POS: NOUN
# Word: Ar, POS: PART
# Word: žinote, POS: VERB
# Word: ,, POS: PUNCT
# Word: koks, POS: DET
# Word: bus, POS: AUX
# Word: oras, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: atsitiktinai, POS: ADV
# Word: perskaičiau, POS: VERB
# Word: orų, POS: NOUN
# Word: prognozę, POS: NOUN
# Word: Koks, POS: DET
# Word: bus, POS: AUX
# Word: oras, POS: NOUN
# Word: Londone, POS: PROPN
# Word: Bus, POS: AUX
# Word: vėsu, POS: ADJ
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: žada, POS: VERB
# Word: pasitaisyti, POS: VERB
# Word: O, POS: CCONJ
# Word: koks, POS: DET
# Word: bus, POS: AUX
# Word: oras, POS: NOUN
# Word: Berlyne, POS: PROPN
# Word: Ž, POS: PROPN
# Word: ada, POS: NOUN
# Word: būti, POS: AUX
# Word: saulėtas, POS: VERB
# Word: ir, POS: CCONJ
# Word: šiltas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: toks, POS: DET
# Word: kaip, POS: SCONJ
# Word: vakar, POS: PUNCT
# Word: Puiki, POS: ADJ
# Word: vasara, POS: NOUN
# Word: Jūs, POS: PRON
# Word: teisus, POS: PROPN
# Word: Jau, POS: ADV
# Word: net, POS: PART
# Word: dabar, POS: ADV
# Word: šilta, POS: ADJ
# Word: Pagal, POS: ADP
# Word: prognozę, POS: NOUN
# Word: bus, POS: AUX
# Word: šiandien, POS: ADV
# Word: 30, POS: NUM
# Word: o, POS: CCONJ
# Word: šilumos, POS: NOUN
# Word: Ar, POS: PART
# Word: Jums, POS: PRON
# Word: patinka, POS: VERB
# Word: Ar, POS: PART
# Word: patinka, POS: VERB
# Word: Jums, POS: PRON
# Word: Berlynas, POS: PROPN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: labai, POS: ADV
# Word: patinka, POS: VERB
# Word: O, POS: CCONJ
# Word: kas, POS: PRON
# Word: daugiausiai, POS: ADV
# Word: patinka, POS: VERB
# Word: Daugiausiai, POS: ADV
# Word: Nacionalinė, POS: ADJ
# Word: galerija, POS: NOUN
# Word: ir, POS: CCONJ
# Word: Šarlotenburgo, POS: PROPN
# Word: pilis, POS: NOUN
# Word: Taip, POS: PART
# Word: pat, POS: X
# Word: patinka, POS: VERB
# Word: pilies, POS: NOUN
# Word: sodas, POS: NOUN
# Word: Ar, POS: PART
# Word: norėtumėte, POS: VERB
# Word: gyventi, POS: VERB
# Word: Berlyne, POS: PROPN
# Word: Tai, POS: DET
# Word: būtų, POS: AUX
# Word: puiku, POS: ADJ
# Word: Aš, POS: PRON
# Word: geriau, POS: ADV
# Word: kalbėčiau, POS: VERB
# Word: vokiškai, POS: ADV
# Word: Kur, POS: ADV
# Word: Jūs, POS: PRON
# Word: gyvenate, POS: VERB
# Word: Aš, POS: PRON
# Word: gyvenu, POS: VERB
# Word: Londone, POS: NOUN
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: Jūs, POS: PRON
# Word: Aš, POS: PRON
# Word: gyvenu, POS: VERB
# Word: čia, POS: ADV
# Word: Šprimetropolyje, POS: NOUN
# Word: jau, POS: PART
# Word: keturis, POS: NUM
# Word: metus, POS: NOUN
# Word: Esu, POS: AUX
# Word: tikras, POS: X
# Word: berlynietis, POS: NOUN
# Word: Apie, POS: ADP
# Word: mokėjimo, POS: NOUN
# Word: būdus, POS: NOUN
# Word: Tai, POS: DET
# Word: bus, POS: AUX
# Word: 125, POS: NUM
# Word: markės, POS: NOUN
# Word: ir, POS: CCONJ
# Word: 50, POS: NUM
# Word: Gaila, POS: ADV
# Word: ,, POS: PUNCT
# Word: prie, POS: ADP
# Word: savęs, POS: PRON
# Word: aš, POS: PRON
# Word: neturiu, POS: VERB
# Word: tiek, POS: ADV
# Word: daug, POS: ADV
# Word: Tai, POS: DET
# Word: nieko, POS: PRON
# Word: Jūs, POS: PRON
# Word: galite, POS: VERB
# Word: mokėti, POS: VERB
# Word: kreditine, POS: ADJ
# Word: kortele, POS: NOUN
# Word: O, POS: CCONJ
# Word: ar, POS: PART
# Word: galiu, POS: VERB
# Word: čekiais, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: jeigu, POS: SCONJ
# Word: jie, POS: PRON
# Word: galiojantys, POS: VERB
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: žinoma, POS: VERB
# Word: Gerai, POS: ADV
# Word: Išrašykite, POS: VERB
# Word: tada, POS: ADV
# Word: čekį, POS: NOUN
# Word: Ciles, POS: VERB
# Word: ir, POS: CCONJ
# Word: Ko, POS: PRON
# Word: vardu, POS: NOUN
# Word: Štai, POS: PART
# Word: čekis, POS: NOUN
# Word: ,, POS: PUNCT
# Word: prašau, POS: VERB
# Word: Ach, POS: X
# Word: ,, POS: PUNCT
# Word: Jūs, POS: PRON
# Word: anglas, POS: PROPN
# Word: Bet, POS: CCONJ
# Word: Jūs, POS: PRON
# Word: kalbate, POS: VERB
# Word: puikiai, POS: ADV
# Word: vokiškai, POS: ADV
# Word: Sveikinu, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Apie, POS: ADP
# Word: dovanas, POS: NOUN
# Word: (, POS: PUNCT
# Word: kokybė, POS: NOUN
# Word: ), POS: PUNCT
# Word: Pažiūrėk, POS: VERB
# Word: ,, POS: PUNCT
# Word: kokią, POS: DET
# Word: dovaną, POS: NOUN
# Word: aš, POS: PRON
# Word: nupirkau, POS: VERB
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: piniginė, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ir, POS: CCONJ
# Word: odinė, POS: ADJ
# Word: Kam, POS: ADV
# Word: tai, POS: DET
# Word: Maksui, POS: PROPN
# Word: ,, POS: PUNCT
# Word: jo, POS: PRON
# Word: gimtadienis, POS: NOUN
# Word: O, POS: CCONJ
# Word: aš, POS: PRON
# Word: nupirkau, POS: VERB
# Word: jam, POS: PRON
# Word: dėklą, POS: NOUN
# Word: akiniams, POS: NOUN
# Word: iš, POS: ADP
# Word: gražios, POS: ADJ
# Word: medžiagos, POS: NOUN
# Word: o, POS: CCONJ
# Word: nuo, POS: ADP
# Word: savo, POS: PRON
# Word: mergaitės, POS: NOUN
# Word: jis, POS: PRON
# Word: gaus, POS: VERB
# Word: tikrą, POS: DET
# Word: sidabrinį, POS: NOUN
# Word: žiedą, POS: NOUN
# Word: Tikrai, POS: ADV
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: tikrą, POS: DET
# Word: sidabrinį, POS: NOUN
# Word: Jam, POS: PRON
# Word: sekasi, POS: VERB
# Word: šiemet, POS: PUNCT
# Word: Apibūdinti, POS: VERB
# Word: asmenį, POS: NOUN
# Word: Ar, POS: PART
# Word: negalėtum, POS: VERB
# Word: 12, POS: NUM
# Word: 57, POS: NUM
# Word: sutikti, POS: VERB
# Word: mano, POS: PRON
# Word: dėdę, POS: NOUN
# Word: Aš, POS: PRON
# Word: neturiu, POS: VERB
# Word: laiko, POS: NOUN
# Word: Turi, POS: VERB
# Word: galvoje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: nuo, POS: ADP
# Word: stoties, POS: NOUN
# Word: Na, POS: INTJ
# Word: gerai, POS: ADV
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: kaip, POS: SCONJ
# Word: jis, POS: PRON
# Word: atrodo, POS: VERB
# Word: Jis, POS: PRON
# Word: labai, POS: ADV
# Word: aukštas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: apie, POS: ADP
# Word: 1,8, POS: NUM
# Word: m, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ir, POS: CCONJ
# Word: pilnas, POS: ADJ
# Word: Ar, POS: PART
# Word: jis, POS: PRON
# Word: nešioja, POS: VERB
# Word: akinius, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: jis, POS: PRON
# Word: visada, POS: ADV
# Word: apsirengęs, POS: VERB
# Word: elegantiškai, POS: ADV
# Word: Dažniausiai, POS: ADV
# Word: tamsiu, POS: ADJ
# Word: kostiumu, POS: NOUN
# Word: ,, POS: PUNCT
# Word: visada, POS: ADV
# Word: su, POS: ADP
# Word: portfeliu, POS: NOUN
# Word: Tokių, POS: DET
# Word: šimtai, POS: NUM
# Word: Koks, POS: DET
# Word: gi, POS: PART
# Word: jo, POS: PRON
# Word: vardas, POS: NOUN
# Word: ir, POS: CCONJ
# Word: pavardė, POS: NOUN
# Word: Henrikas, POS: PROPN
# Word: Mejeris, POS: PROPN
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: ir, POS: PART
# Word: aš, POS: PRON
# Word: Palinkkėimai, POS: NOUN
# Word: pasveikti, POS: VERB
# Word: Ar, POS: PART
# Word: ką, POS: PRON
# Word: nors, POS: X
# Word: šiandien, POS: ADV
# Word: planavai, POS: ADV
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: turiu, POS: VERB
# Word: nueiti, POS: VERB
# Word: į, POS: ADP
# Word: ligoninę, POS: NOUN
# Word: O, POS: CCONJ
# Word: kas, POS: PRON
# Word: atsitiko, POS: VERB
# Word: Mano, POS: PRON
# Word: senelis, POS: NOUN
# Word: ligoninėje, POS: NOUN
# Word: Norėčiau, POS: VERB
# Word: jį, POS: PRON
# Word: aplankyti, POS: VERB
# Word: Tu, POS: PRON
# Word: gi, POS: PART
# Word: žinai, POS: VERB
# Word: ,, POS: PUNCT
# Word: jis, POS: PRON
# Word: buvo, POS: AUX
# Word: papuolęs, POS: VERB
# Word: į, POS: ADP
# Word: avariją, POS: NOUN
# Word: O, POS: CCONJ
# Word: kaip, POS: SCONJ
# Word: jis, POS: PRON
# Word: dabar, POS: ADV
# Word: Ačiū, POS: VERB
# Word: Dievui, POS: NOUN
# Word: ,, POS: PUNCT
# Word: dabar, POS: ADV
# Word: jaučiasi, POS: VERB
# Word: geriau, POS: ADV
# Word: Tai, POS: DET
# Word: buvo, POS: AUX
# Word: automobilio, POS: NOUN
# Word: avarija, POS: NOUN
# Word: ,, POS: PUNCT
# Word: tu, POS: PRON
# Word: žinai, POS: VERB
# Word: Kai, POS: SCONJ
# Word: aš, POS: PRON
# Word: apie, POS: ADP
# Word: tai, POS: DET
# Word: galvoju, POS: VERB
# Word: ,, POS: PUNCT
# Word: man, POS: PRON
# Word: tiesiog, POS: ADV
# Word: bloga, POS: ADJ
# Word: Man, POS: PRON
# Word: gaila, POS: ADV
# Word: Jis, POS: PRON
# Word: norėjo, POS: VERB
# Word: į, POS: ADP
# Word: Ciuriką, POS: NOUN
# Word: skrįsti, POS: VERB
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: ne, POS: PART
# Word: Tiksliai, POS: ADV
# Word: ,, POS: PUNCT
# Word: šiandien, POS: ADV
# Word: Jam, POS: PRON
# Word: tiesiog, POS: ADV
# Word: nepasisekė, POS: VERB
# Word: Linkiu, POS: VERB
# Word: jam, POS: PRON
# Word: kuo, POS: CCONJ
# Word: greičiau, POS: ADV
# Word: pasveikti, POS: VERB
# Word: Ačiū, POS: PRON
# Word: Kol, POS: ADV
# Word: kas, POS: PRON
# Word: Iki, POS: ADP
# Word: Paslaptingas, POS: ADJ
# Word: portfelis, POS: NOUN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: ponas, POS: NOUN
# Word: B, POS: PUNCT
# Word: ,, POS: PUNCT
# Word: Jūsų, POS: PRON
# Word: portfelis, POS: NOUN
# Word: atrodo, POS: VERB
# Word: labai, POS: ADV
# Word: įdomiai, POS: ADV
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: ten, POS: ADV
# Word: turite, POS: VERB
# Word: Aš, POS: PRON
# Word: iš, POS: ADV
# Word: tikrųjų, POS: X
# Word: pats, POS: DET
# Word: nežinau, POS: VERB
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: sakote, POS: VERB
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: pats, POS: DET
# Word: nežinote, POS: VERB
# Word: ,, POS: PUNCT
# Word: ką, POS: PRON
# Word: turite, POS: VERB
# Word: portfelyje, POS: NOUN
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: girdėjote, POS: VERB
# Word: Ir, POS: CCONJ
# Word: nenorite, POS: VERB
# Word: žinoti, POS: VERB
# Word: Žinoma, POS: VERB
# Word: ,, POS: PUNCT
# Word: noriu, POS: VERB
# Word: Jausčiausi, POS: ADV
# Word: tada, POS: ADV
# Word: geriau, POS: ADV
# Word: Tai, POS: DET
# Word: kodėl, POS: ADV
# Word: tada, POS: ADV
# Word: nepažiūrite, POS: VERB
# Word: Gerai, POS: ADV
# Word: ,, POS: PUNCT
# Word: pažiūrėk, POS: VERB
# Word: pats, POS: DET
# Word: Nieko, POS: PRON
# Word: ,, POS: PUNCT
# Word: tik, POS: PART
# Word: popieriai, POS: NOUN
# Word: Ar, POS: PART
# Word: dabar, POS: ADV
# Word: Jums, POS: PRON
# Word: geriau, POS: ADV
# Word: Vakarėlyje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: apie, POS: ADP
# Word: šeimą, POS: NOUN
# Word: Šimtą, POS: NUM
# Word: metų, POS: NOUN
# Word: nesimatėme, POS: VERB
# Word: Kaip, POS: SCONJ
# Word: Jūsų, POS: PRON
# Word: vaikai, POS: NOUN
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: du, POS: NUM
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: ne, POS: PART
# Word: Taip, POS: ADV
# Word: Nuo, POS: ADP
# Word: to, POS: DET
# Word: laiko, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kai, POS: SCONJ
# Word: buvome, POS: VERB
# Word: susitikę, POS: VERB
# Word: ,, POS: PUNCT
# Word: mano, POS: PRON
# Word: duktė, POS: NOUN
# Word: ištekėjo, POS: VERB
# Word: Jūsų, POS: PRON
# Word: duktė, POS: NOUN
# Word: gydytoja, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ar, POS: CCONJ
# Word: ne, POS: PART
# Word: Ne, POS: PART
# Word: ,, POS: PUNCT
# Word: mano, POS: PRON
# Word: žmona, POS: NOUN
# Word: yra, POS: AUX
# Word: gydytoja, POS: NOUN
# Word: Mano, POS: PRON
# Word: duktė, POS: NOUN
# Word: dar, POS: ADV
# Word: studijuoja, POS: VERB
# Word: universitete, POS: NOUN
# Word: ,, POS: PUNCT
# Word: taip, POS: PART
# Word: pat, POS: X
# Word: ir, POS: PART
# Word: sūnus, POS: NOUN
# Word: Ką, POS: PRON
# Word: jie, POS: PRON
# Word: studijuoja, POS: VERB
# Word: Abu, POS: NUM
# Word: tą, POS: DET
# Word: patį, POS: DET
# Word: dalyką, POS: NOUN
# Word: Vadybą, POS: NOUN
# Word: O, POS: CCONJ
# Word: Jūsų, POS: PRON
# Word: vaikai, POS: NOUN
# Word: Ką, POS: PRON
# Word: jie, POS: PRON
# Word: veikia, POS: VERB
# Word: Aš, POS: PRON
# Word: neturiu, POS: VERB
# Word: vaikų, POS: NOUN
# Word: Ir, POS: CCONJ
# Word: nesu, POS: VERB
# Word: vedęs, POS: VERB
# Word: Jūs, POS: PRON
# Word: tikriausiai, POS: ADV
# Word: galvojate, POS: VERB
# Word: apie, POS: ADP
# Word: mano, POS: PRON
# Word: seserį, POS: NOUN
# Word: Ji, POS: PRON
# Word: turi, POS: VERB
# Word: du, POS: NUM
# Word: vaikus, POS: NOUN
# Word: Atostogos, POS: NOUN
# Word: Kaip, POS: SCONJ
# Word: Tavo, POS: PRON
# Word: atostogos, POS: NOUN
# Word: Puikiai, POS: ADV
# Word: Mes, POS: PRON
# Word: keliavome, POS: VERB
# Word: po, POS: ADP
# Word: pietinę, POS: ADJ
# Word: Vokietiją, POS: PROPN
# Word: automobiliu, POS: NOUN
# Word: Aš, POS: PRON
# Word: visai, POS: ADV
# Word: nežinau, POS: VERB
# Word: pietinės, POS: ADJ
# Word: Vokietijos, POS: PROPN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: vietos, POS: NOUN
# Word: puikios, POS: ADJ
# Word: Pievos, POS: NOUN
# Word: ,, POS: PUNCT
# Word: miškai, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kalnai, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ir, POS: CCONJ
# Word: ežerai, POS: NOUN
# Word: Mums, POS: PRON
# Word: labai, POS: ADV
# Word: patiko, POS: VERB
# Word: O, POS: CCONJ
# Word: koks, POS: DET
# Word: buvo, POS: AUX
# Word: oras, POS: NOUN
# Word: Septynias, POS: NUM
# Word: dienas, POS: NOUN
# Word: lijo, POS: VERB
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: tris, POS: NUM
# Word: -, POS: PUNCT
# Word: švietė, POS: NOUN
# Word: saulė, POS: NOUN
# Word: Iškylos, POS: NOUN
# Word: planavimas, POS: NOUN
# Word: Pasiūlymai, POS: NOUN
# Word: Ar, POS: PART
# Word: Tu, POS: PRON
# Word: jau, POS: PART
# Word: alkanas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: dar, POS: PART
# Word: ne, POS: PART
# Word: Aš, POS: PRON
# Word: alkanas, POS: NOUN
# Word: ir, POS: CCONJ
# Word: ištroškęs, POS: VERB
# Word: Ar, POS: PART
# Word: jau, POS: PART
# Word: valgysime, POS: VERB
# Word: Tai, POS: DET
# Word: puiki, POS: ADJ
# Word: mintis, POS: NOUN
# Word: Kur, POS: ADV
# Word: bus, POS: AUX
# Word: mūsų, POS: PRON
# Word: piknikas, POS: NOUN
# Word: Siūlau, POS: VERB
# Word: pilies, POS: NOUN
# Word: sode, POS: NOUN
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: mes, POS: PRON
# Word: galime, POS: VERB
# Word: eiti, POS: VERB
# Word: į, POS: ADP
# Word: vidų, POS: NOUN
# Word: ir, POS: CCONJ
# Word: apžiūrėti, POS: VERB
# Word: pilį, POS: NOUN
# Word: Aš, POS: PRON
# Word: norėčiau, POS: VERB
# Word: pamatyti, POS: VERB
# Word: porceliano, POS: NOUN
# Word: kolekciją, POS: NOUN
# Word: Ji, POS: PRON
# Word: gana, POS: ADV
# Word: garsi, POS: ADJ
# Word: Visi, POS: DET
# Word: daiktai, POS: NOUN
# Word: originalūs, POS: ADJ
# Word: ,, POS: PUNCT
# Word: iš, POS: ADP
# Word: 18, POS: NUM
# Word: amžiaus, POS: NOUN
# Word: Aš, POS: PRON
# Word: girdėjau, POS: VERB
# Word: apie, POS: ADP
# Word: tai, POS: DET
# Word: Tikiuosi, POS: VERB
# Word: ,, POS: PUNCT
# Word: mes, POS: PRON
# Word: jų, POS: PRON
# Word: nesudaužysime, POS: VERB
# Word: Nesijaudink, POS: VERB
# Word: Jie, POS: PRON
# Word: visi, POS: DET
# Word: po, POS: ADP
# Word: stiklu, POS: NOUN
# Word: Vėlavimas, POS: NOUN
# Word: į, POS: ADP
# Word: susitikimą, POS: NOUN
# Word: Jau, POS: ADV
# Word: 20, POS: NUM
# Word: minučių, POS: NOUN
# Word: po, POS: ADP
# Word: dvyliktos, POS: NOUN
# Word: Aš, POS: PRON
# Word: Jūsų, POS: PRON
# Word: laukiau, POS: VERB
# Word: dvyliktą, POS: PROPN
# Word: Bet, POS: CCONJ
# Word: Jūs, POS: PRON
# Word: gi, POS: PART
# Word: uždusęs, POS: VERB
# Word: Atsiprašau, POS: VERB
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: man, POS: PRON
# Word: labai, POS: ADV
# Word: nesisekė, POS: VERB
# Word: Nesėkminga, POS: ADJ
# Word: diena, POS: NOUN
# Word: Viskas, POS: PRON
# Word: buvo, POS: AUX
# Word: blogai, POS: ADV
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: galvoje, POS: NOUN
# Word: Nagi, POS: PROPN
# Word: ,, POS: PUNCT
# Word: traukinys, POS: NOUN
# Word: vėlavo, POS: VERB
# Word: Po, POS: ADP
# Word: to, POS: X
# Word: negalėjau, POS: VERB
# Word: rasti, POS: VERB
# Word: taksi, POS: NOUN
# Word: ,, POS: PUNCT
# Word: be, POS: ADP
# Word: to, POS: DET
# Word: čia, POS: ADV
# Word: ir, POS: CCONJ
# Word: liftas, POS: VERB
# Word: nedirba, POS: VERB
# Word: Tikrai, POS: ADV
# Word: blogai, POS: ADV
# Word: Bet, POS: CCONJ
# Word: pirmiausia, POS: ADV
# Word: atgaukite, POS: VERB
# Word: kvapą, POS: NOUN
# Word: Atsisėskite, POS: VERB
# Word: Nieko, POS: PRON
# Word: nuostabaus, POS: NOUN
# Word: ,, POS: PUNCT
# Word: šiandien, POS: ADV
# Word: vasario, POS: NOUN
# Word: 13, POS: NUM
# Word: diena, POS: NOUN
# Word: Išreikšti, POS: VERB
# Word: nustebimą, POS: NOUN
# Word: ir, POS: CCONJ
# Word: netikėjimą, POS: NOUN
# Word: Turiu, POS: VERB
# Word: Tau, POS: PRON
# Word: siurprizą, POS: NOUN
# Word: Kas, POS: PRON
# Word: tai, POS: DET
# Word: ,, POS: PUNCT
# Word: pasakyk, POS: PRON
# Word: Spėk, POS: PROPN
# Word: Kas, POS: PRON
# Word: tai, POS: DET
# Word: galėtų, POS: VERB
# Word: būti, POS: AUX
# Word: Neturiu, POS: VERB
# Word: supratimo, POS: NOUN
# Word: Įsivaizduokite, POS: VERB
# Word: ,, POS: PUNCT
# Word: išlošėte, POS: VERB
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: galvoje, POS: NOUN
# Word: Aš, POS: PRON
# Word: gi, POS: PART
# Word: pasakiau, POS: VERB
# Word: Jūs, POS: PRON
# Word: laimėjote, POS: VERB
# Word: krūvą, POS: NOUN
# Word: pinigų, POS: NOUN
# Word: Kas, POS: PRON
# Word: Aš, POS: PRON
# Word: Iš, POS: ADV
# Word: tikrųjų, POS: X
# Word: Kaip, POS: ADV
# Word: Aš, POS: PRON
# Word: nežinau, POS: VERB
# Word: ,, POS: PUNCT
# Word: ką, POS: PRON
# Word: ir, POS: PART
# Word: sakyti, POS: VERB
# Word: Turime, POS: VERB
# Word: išgerti, POS: VERB
# Word: Žinoma, POS: VERB
# Word: Aš, POS: PRON
# Word: moku, POS: VERB
# Word: Paslaptis, POS: NOUN
# Word: Pasakykite, POS: VERB
# Word: prašom, POS: VERB
# Word: ,, POS: PUNCT
# Word: inspektoriau, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kas, POS: PRON
# Word: čia, POS: ADV
# Word: per, POS: ADP
# Word: paslaptis, POS: NOUN
# Word: Aš, POS: PRON
# Word: galiu, POS: VERB
# Word: pasakyti, POS: VERB
# Word: ,, POS: PUNCT
# Word: jam, POS: PRON
# Word: nusišypsojo, POS: VERB
# Word: laimė, POS: NOUN
# Word: Ir, POS: CCONJ
# Word: jis, POS: PRON
# Word: netiki, POS: VERB
# Word: Ką, POS: PRON
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: galvoje, POS: NOUN
# Word: Jis, POS: PRON
# Word: negali, POS: VERB
# Word: patikėti, POS: VERB
# Word: Ar, POS: PART
# Word: jis, POS: PRON
# Word: tikrai, POS: ADV
# Word: laimėjo, POS: VERB
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: tikras, POS: ADJ
# Word: ,, POS: PUNCT
# Word: tai, POS: PART
# Word: tiesa, POS: NOUN
# Word: Nėra, POS: VERB
# Word: jokios, POS: DET
# Word: abejonės, POS: NOUN
# Word: Ką, POS: PRON
# Word: visa, POS: DET
# Word: tai, POS: X
# Word: reiškia, POS: VERB
# Word: Aš, POS: PRON
# Word: tikrai, POS: ADV
# Word: netikiu, POS: VERB
# Word: Tai, POS: DET
# Word: būtų, POS: AUX
# Word: per, POS: PART
# Word: daug, POS: ADV
# Word: gerai, POS: ADV
# Word: Du, POS: NUM
# Word: draugai, POS: NOUN
# Word: atostogauja, POS: VERB
# Word: Aš, POS: PRON
# Word: turiu, POS: VERB
# Word: nueiti, POS: VERB
# Word: į, POS: ADP
# Word: banką, POS: NOUN
# Word: ir, POS: CCONJ
# Word: pakeisti, POS: VERB
# Word: pinigus, POS: NOUN
# Word: Eikime, POS: VERB
# Word: kartu, POS: ADV
# Word: Man, POS: PRON
# Word: taip, POS: PART
# Word: pat, POS: X
# Word: reikia, POS: VERB
# Word: pinigų, POS: NOUN
# Word: Koks, POS: DET
# Word: kursas, POS: NOUN
# Word: šiandien, POS: ADV
# Word: Ne, POS: PART
# Word: toks, POS: DET
# Word: jau, POS: PART
# Word: geras, POS: ADJ
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: aš, POS: PRON
# Word: nebeturiu, POS: VERB
# Word: grynųjų, POS: ADJ
# Word: Tik, POS: PART
# Word: kelioninius, POS: ADJ
# Word: čekius, POS: NOUN
# Word: Restorane, POS: NOUN
# Word: ,, POS: PUNCT
# Word: priešais, POS: ADP
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: mokėjau, POS: VERB
# Word: kreditine, POS: ADJ
# Word: kortele, POS: NOUN
# Word: Ar, POS: PART
# Word: galima, POS: VERB
# Word: Kaip, POS: SCONJ
# Word: ten, POS: ADV
# Word: valgis, POS: NOUN
# Word: Man, POS: PRON
# Word: patiko, POS: VERB
# Word: Virėjas, POS: NOUN
# Word: moka, POS: VERB
# Word: virti, POS: VERB
# Word: Banke, POS: NOUN
# Word: Iškeiskite, POS: VERB
# Word: prašom, POS: VERB
# Word: 500, POS: NUM
# Word: markių, POS: NOUN
# Word: į, POS: ADP
# Word: šveicariškus, POS: ADJ
# Word: frankus, POS: NOUN
# Word: Eikite, POS: VERB
# Word: prašom, POS: VERB
# Word: prie, POS: ADP
# Word: užsienio, POS: NOUN
# Word: valiutos, POS: NOUN
# Word: keitimo, POS: NOUN
# Word: langelio, POS: NOUN
# Word: Ačiū, POS: PRON
# Word: Prie, POS: ADP
# Word: užsienio, POS: NOUN
# Word: valiutos, POS: NOUN
# Word: keitimo, POS: NOUN
# Word: langelio, POS: NOUN
# Word: Norėčiau, POS: VERB
# Word: šveicariškų, POS: ADJ
# Word: frankų, POS: NOUN
# Word: už, POS: ADP
# Word: 500, POS: NUM
# Word: markių, POS: NOUN
# Word: Prašom, POS: VERB
# Word: Štai, POS: PART
# Word: Jūsų, POS: PRON
# Word: pinigai, POS: NOUN
# Word: ir, POS: CCONJ
# Word: kvitas, POS: NOUN
# ...
# Word: skauda, POS: VERB
# Word: galvą, POS: NOUN
# Word: Žinoma, POS: VERB
# Word: ,, POS: PUNCT
# Word: gerai, POS: ADV
# Word: Mes, POS: PRON
# Word: užeisime, POS: VERB
# Word: į, POS: ADP
# Word: kavinę, POS: NOUN
# Word: ir, POS: CCONJ
# Word: išgersime, POS: VERB
# Word: puoduką, POS: NOUN
# Word: kavos, POS: NOUN
# Word: Aš, POS: PRON
# Word: turiu, POS: VERB
# Word: aspirino, POS: VERB
# Word: tabletę, POS: NOUN
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: kavinėje, POS: NOUN
# Word: gausime, POS: VERB
# Word: vandens, POS: NOUN
# Word: Planai, POS: NOUN
# Word: vakarui, POS: NOUN
# Word: Ką, POS: PRON
# Word: mes, POS: PRON
# Word: darysime, POS: VERB
# Word: šį, POS: DET
# Word: vakarą, POS: NOUN
# Word: Gal, POS: PART
# Word: eisime, POS: VERB
# Word: į, POS: ADP
# Word: kiną, POS: NOUN
# Word: ar, POS: CCONJ
# Word: teatrą, POS: NOUN
# Word: Galėtumėm, POS: VERB
# Word: dar, POS: PART
# Word: gauti, POS: VERB
# Word: bilietus, POS: NOUN
# Word: Galėtumėm, POS: VERB
# Word: ir, POS: CCONJ
# Word: pašokti, POS: VERB
# Word: nueiti, POS: VERB
# Word: Aš, POS: PRON
# Word: mėgstu, POS: VERB
# Word: viską, POS: PRON
# Word: ,, POS: PUNCT
# Word: ir, POS: CCONJ
# Word: baletą, POS: NOUN
# Word: ir, POS: CCONJ
# Word: teatrą, POS: NOUN
# Word: Aš, POS: PRON
# Word: mėgstu, POS: VERB
# Word: ir, POS: CCONJ
# Word: kiną, POS: NOUN
# Word: ;, POS: PUNCT
# Word: sugalvok, POS: VERB
# Word: ,, POS: PUNCT
# Word: ką, POS: PRON
# Word: mes, POS: PRON
# Word: darysime, POS: VERB
# Word: Aš, POS: PRON
# Word: tiesiog, POS: ADV
# Word: norėčiau, POS: VERB
# Word: kur, POS: ADV
# Word: nors, POS: X
# Word: išeiti, POS: VERB
# Word: Piteris, POS: PROPN
# Word: prisimena, POS: VERB
# Word: ,, POS: PUNCT
# Word: kaip, POS: SCONJ
# Word: sunku, POS: ADJ
# Word: prie, POS: ADP
# Word: kasos, POS: NOUN
# Word: Bet, POS: CCONJ
# Word: jis, POS: PRON
# Word: negali, POS: VERB
# Word: pasiūlyti, POS: VERB
# Word: televizijos, POS: NOUN
# Word: Jie, POS: PRON
# Word: pasiskolina, POS: VERB
# Word: laikraštį, POS: NOUN
# Word: iš, POS: ADP
# Word: vyriškio, POS: ADJ
# Word: prie, POS: ADP
# Word: gretimo, POS: NOUN
# Word: staliuko, POS: NOUN
# Word: ir, POS: CCONJ
# Word: žiūri, POS: VERB
# Word: teatrų, POS: NOUN
# Word: programą, POS: NOUN
# Word: Jie, POS: PRON
# Word: neranda, POS: VERB
# Word: nieko, POS: PRON
# Word: tinkamo, POS: ADJ
# Word: ir, POS: CCONJ
# Word: nusprendžia, POS: VERB
# Word: nueiti, POS: VERB
# Word: į, POS: ADP
# Word: restoraną, POS: NOUN
# Word: Žinoma, POS: VERB
# Word: ,, POS: PUNCT
# Word: aš, POS: PRON
# Word: jus, POS: PRON
# Word: kviečiu, POS: VERB
# Word: Aš, POS: PRON
# Word: žinau, POS: VERB
# Word: gerą, POS: ADJ
# Word: restoraną, POS: NOUN
# Word: Jis, POS: PRON
# Word: nedidelis, POS: ADJ
# Word: ir, POS: CCONJ
# Word: nebrangus, POS: ADJ
# Word: Aptarnavimas, POS: NOUN
# Word: geras, POS: ADJ
# Word: ir, POS: CCONJ
# Word: maistas, POS: NOUN
# Word: puikus, POS: ADJ
# Word: O, POS: CCONJ
# Word: tai, POS: DET
# Word: svarbiausia, POS: ADJ
# Word: ,, POS: PUNCT
# Word: ar, POS: SCONJ
# Word: ne, POS: PART
# Word: Taip, POS: ADV
# Word: ,, POS: PUNCT
# Word: ačiū, POS: PRON
# Word: Ap, POS: X
# Word: galiu, POS: VERB
# Word: apsivilkti, POS: VERB
# Word: marškinius, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kuriuos, POS: DET
# Word: tik, POS: PART
# Word: ką, POS: PRON
# Word: nusipirkau, POS: VERB
# Word: ir, POS: PART
# Word: kaklaraištį, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kurį, POS: DET
# Word: tu, POS: PRON
# Word: man, POS: PRON
# Word: padovanojai, POS: ADV
# Word: Mes, POS: PRON
# Word: turėtumėm, POS: VERB
# Word: jau, POS: PART
# Word: eiti, POS: VERB
# Word: Parduotuvės, POS: NOUN
# Word: užsidaro, POS: VERB
# Word: 6-tą, POS: NOUN
# Word: ,, POS: PUNCT
# Word: o, POS: CCONJ
# Word: aš, POS: PRON
# Word: dar, POS: PART
# Word: noriu, POS: VERB
# Word: ką, POS: PRON
# Word: nors, POS: X
# Word: nusipirkti, POS: VERB
# Word: Padavėjau, POS: VERB
# Word: ,, POS: PUNCT
# Word: prašom, POS: VERB
# Word: sąskaitą, POS: NOUN
# Word: Mažas, POS: ADJ
# Word: kavinukas, POS: NOUN
# Word: kavos, POS: NOUN
# Word: ,, POS: PUNCT
# Word: arbata, POS: NOUN
# Word: su, POS: ADP
# Word: citrina, POS: NOUN
# Word: ir, POS: CCONJ
# Word: 2, POS: NUM
# Word: gabaliukai, POS: NOUN
# Word: pyrago, POS: NOUN
# Word: ;, POS: PUNCT
# Word: už, POS: ADP
# Word: visa, POS: PRON
# Word: tai, POS: X
# Word: 9, POS: NUM
# Word: markės, POS: NOUN
# Word: 70, POS: NUM
# Word: Štai, POS: PART
# Word: Jūsų, POS: PRON
# Word: sąskaita, POS: NOUN
# Word: Ar, POS: PART
# Word: aš, POS: PRON
# Word: turiu, POS: VERB
# Word: duoti, POS: VERB
# Word: arbatpinigių, POS: ADJ
# Word: Tiktai, POS: PART
# Word: 30, POS: NUM
# Word: pfenigių, POS: NOUN
# Word: ,, POS: PUNCT
# Word: jeigu, POS: SCONJ
# Word: nori, POS: VERB
# Word: Vokietijoje, POS: PROPN
# Word: aptarnavimas, POS: NOUN
# Word: visada, POS: ADV
# Word: įjungtas, POS: VERB
# Word: Išaiškinti, POS: VERB
# Word: nesusipratimą, POS: NOUN
# Word: (, POS: PUNCT
# Word: blogas, POS: ADJ
# Word: adresas, POS: NOUN
# Word: ), POS: PUNCT
# Word: Labas, POS: PROPN
# Word: rytas, POS: PROPN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: iš, POS: ADP
# Word: ekspreso, POS: NOUN
# Word: kurjerių, POS: NOUN
# Word: tarnybos, POS: NOUN
# Word: Taip, POS: ADV
# Word: Mes, POS: PRON
# Word: laukėme, POS: VERB
# Word: Jūsų, POS: PRON
# Word: Prašom, POS: VERB
# Word: įeiti, POS: VERB
# Word: Ačiū, POS: PRON
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: laukėte, POS: VERB
# Word: ilgai, POS: ADV
# Word: Nieko, POS: PRON
# Word: Kur, POS: ADV
# Word: paketas, POS: NOUN
# Word: Ar, POS: PART
# Word: Jūs, POS: PRON
# Word: turite, POS: VERB
# Word: jį, POS: PRON
# Word: Žinoma, POS: VERB
# Word: Štai, POS: PART
# Word: ,, POS: PUNCT
# Word: abu, POS: NUM
# Word: Šmidto, POS: NOUN
# Word: vardu, POS: NOUN
# Word: Šmidto, POS: NOUN
# Word: Mano, POS: PRON
# Word: vardas, POS: NOUN
# Word: Šulz, POS: PROPN
# Word: ,, POS: PUNCT
# Word: Elvyra, POS: PROPN
# Word: Šulz, POS: PROPN
# Word: Tai, POS: DET
# Word: kažkas, POS: PRON
# Word: negerai, POS: ADV
# Word: Bet, POS: CCONJ
# Word: čia, POS: ADV
# Word: parašyta, POS: VERB
# Word: :, POS: PUNCT
# Word: Šmidt, POS: PROPN
# Word: ,, POS: PUNCT
# Word: Bahnhof, POS: X
# Word: Street, POS: X
# Word: 12, POS: NUM
# Word: ,, POS: PUNCT
# Word: trečias, POS: NUM
# Word: aukštas, POS: ADJ
# Word: Taip, POS: ADV
# Word: adresas, POS: NOUN
# Word: teisingas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: bet, POS: CCONJ
# Word: mes, POS: PRON
# Word: esame, POS: VERB
# Word: ketvirtame, POS: ADJ
# Word: aukšte, POS: NOUN
# Word: Šmidtai, POS: ADV
# Word: gyvena, POS: VERB
# Word: trečiajame, POS: NUM
# Word: O, POS: CCONJ
# Word: ,, POS: PUNCT
# Word: atsiprašau, POS: VERB
# Word: Viso, POS: DET
# Word: gero, POS: ADV
# Word: Kas, POS: PRON
# Word: gi, POS: PART
# Word: po, POS: ADP
# Word: galais, POS: NOUN
# Word: čia, POS: ADV
# Word: dedasi, POS: VERB
# Word: Ir, POS: CCONJ
# Word: dar, POS: PART
# Word: ekspreso, POS: NOUN
# Word: kurjeriai, POS: NOUN
# Word: Lėktuvo, POS: NOUN
# Word: katastrofa, POS: NOUN
# Word: Vilniuje, POS: PROPN
# Word: –, POS: PUNCT
# Word: kas, POS: PRON
# Word: žinoma, POS: VERB
# Word: apie, POS: ADP
# Word: įvykį, POS: NOUN
# Word: Pirmadienio, POS: NOUN
# Word: rytą, POS: NOUN
# Word: sostinėje, POS: NOUN
# Word: įvyko, POS: VERB
# Word: lėktuvo, POS: NOUN
# Word: katastrofa, POS: NOUN
# Word: –, POS: PUNCT
# Word: Liepkalnyje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: netoli, POS: NOUN
# Word: Vilniaus, POS: PROPN
# Word: oro, POS: NOUN
# Word: uosto, POS: NOUN
# Word: ,, POS: PUNCT
# Word: nukrito, POS: VERB
# Word: krovininis, POS: ADJ
# Word: orlaivis, POS: NOUN
# Word: „, POS: PUNCT
# Word: Boeing, POS: X
# Word: 737, POS: NUM
# Word: “, POS: PUNCT
# Word: Per, POS: ADP
# Word: įvykį, POS: NOUN
# Word: vienas, POS: PRON
# Word: žmogus, POS: NOUN
# Word: žuvo, POS: VERB
# Word: ,, POS: PUNCT
# Word: trys, POS: NUM
# Word: sužeisti, POS: VERB
# Word: ,, POS: PUNCT
# Word: vienas, POS: PRON
# Word: iš, POS: ADP
# Word: jų, POS: PRON
# Word: yra, POS: AUX
# Word: lietuvis, POS: NOUN
# Word: Pirmadienį, POS: NOUN
# Word: 5, POS: NUM
# Word: 28, POS: NUM
# Word: val, POS: PUNCT
# Word: ryto, POS: NOUN
# Word: gauta, POS: VERB
# Word: informacija, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: krovininis, POS: ADJ
# Word: lėktuvas, POS: NOUN
# Word: nukrito, POS: VERB
# Word: Liepkalnyje, POS: NOUN
# Word: šalia, POS: ADP
# Word: namo, POS: NOUN
# Word: Krovininis, POS: ADJ
# Word: lėktuvas, POS: NOUN
# Word: į, POS: ADP
# Word: Vilnių, POS: PROPN
# Word: skrido, POS: VERB
# Word: iš, POS: ADP
# Word: Leipcigo, POS: PROPN
# Word: ,, POS: PUNCT
# Word: Vokietijos, POS: PROPN
# Word: Prieš, POS: ADP
# Word: skrydį, POS: NOUN
# Word: į, POS: ADP
# Word: Vilnių, POS: PROPN
# Word: lėktuvas, POS: NOUN
# Word: dvi, POS: NUM
# Word: dienas, POS: NOUN
# Word: ,, POS: PUNCT
# Word: lapkričio, POS: NOUN
# Word: 23–24, POS: NUM
# Word: d, POS: X
# Word: ,, POS: PUNCT
# Word: Leipcigo, POS: PROPN
# Word: oro, POS: NOUN
# Word: uoste, POS: NOUN
# Word: stovėjo, POS: VERB
# Word: nenaudojamas, POS: VERB
# Word: ,, POS: PUNCT
# Word: nors, POS: SCONJ
# Word: įprastai, POS: ADV
# Word: orlaiviu, POS: NOUN
# Word: buvo, POS: AUX
# Word: skraidoma, POS: VERB
# Word: kasdien, POS: ADV
# Word: Lėktuvas, POS: NOUN
# Word: nukrito, POS: VERB
# Word: Liepkalnyje, POS: NOUN
# Word: ,, POS: PUNCT
# Word: ties, POS: ADP
# Word: Žirnių, POS: NOUN
# Word: ir, POS: CCONJ
# Word: Liepkalnio, POS: PROPN
# Word: gatvėmis, POS: NOUN
# Word: Bendrovės, POS: NOUN
# Word: DHL, POS: X
# Word: užsakomuosius, POS: VERB
# Word: skrydžius, POS: NOUN
# Word: vykdė, POS: VERB
# Word: lėktuvas, POS: NOUN
# Word: ,, POS: PUNCT
# Word: priklausęs, POS: VERB
# Word: Ispanijos, POS: PROPN
# Word: oro, POS: NOUN
# Word: linijoms, POS: NOUN
# Word: „, POS: PUNCT
# Word: Swiftair, POS: ADV
# Word: “, POS: PUNCT
# Word: Internete, POS: NOUN
# Word: pasirodžius, POS: VERB
# Word: pilotų, POS: NOUN
# Word: ir, POS: CCONJ
# Word: skrydžio, POS: NOUN
# Word: vadovo, POS: NOUN
# Word: garso, POS: NOUN
# Word: įrašui, POS: NOUN
# Word: ,, POS: PUNCT
# Word: pastebėta, POS: VERB
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: pokalbis, POS: NOUN
# Word: buvo, POS: AUX
# Word: visiškai, POS: ADV
# Word: rutininis, POS: ADJ
# Word: ,, POS: PUNCT
# Word: nefiksuota, POS: VERB
# Word: jokių, POS: DET
# Word: nerimo, POS: NOUN
# Word: ženklų, POS: NOUN
# Word: DHL, POS: X
# Word: informavo, POS: VERB
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: dėl, POS: ADP
# Word: lėktuvo, POS: NOUN
# Word: katastrofos, POS: NOUN
# Word: pradėtas, POS: VERB
# Word: tyrimas, POS: NOUN
# Word: Incidento, POS: NOUN
# Word: vietoje, POS: NOUN
# Word: buvo, POS: AUX
# Word: matyti, POS: VERB
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: orlaivio, POS: NOUN
# Word: nuolaužos, POS: NOUN
# Word: pažiro, POS: VERB
# Word: net, POS: PART
# Word: 100, POS: NUM
# Word: m, POS: NOUN
# Word: atstumu, POS: NOUN
# Word: Medikai, POS: NOUN
# Word: į, POS: ADP
# Word: įvykio, POS: NOUN
# Word: vietą, POS: NOUN
# Word: atvyko, POS: VERB
# Word: per, POS: ADP
# Word: 6, POS: NUM
# Word: minutes, POS: NOUN
# Word: Vilniaus, POS: PROPN
# Word: greitosios, POS: ADJ
# Word: medicinos, POS: NOUN
# Word: pagalbos, POS: NOUN
# Word: Išvažiuojamųjų, POS: VERB
# Word: brigadų, POS: NOUN
# Word: tarnybos, POS: NOUN
# Word: vadovas, POS: NOUN
# Word: Igoris, POS: PROPN
# Word: Lukaševas, POS: PROPN
# Word: LRT, POS: X
# Word: RADIJUI, POS: NOUN
# Word: teigė, POS: VERB
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: iš, POS: ADP
# Word: sužeistų, POS: VERB
# Word: įgulos, POS: NOUN
# Word: narių, POS: NOUN
# Word: sunkiausia, POS: ADJ
# Word: būklė, POS: NOUN
# Word: –, POS: PUNCT
# Word: 54, POS: NUM
# Word: ir, POS: CCONJ
# Word: 40, POS: NUM
# Word: metų, POS: NOUN
# Word: asmenų, POS: NOUN
# Word: Vienas, POS: PRON
# Word: jų, POS: PRON
# Word: bent, POS: PART
# Word: kurį, POS: DET
# Word: laiką, POS: NOUN
# Word: buvo, POS: AUX
# Word: sąmoningas, POS: ADJ
# Word: ,, POS: PUNCT
# Word: kalbėjo, POS: VERB
# Word: angliškai, POS: ADV
# Word: Skrydžio, POS: NOUN
# Word: metu, POS: NOUN
# Word: jie, POS: PRON
# Word: buvo, POS: AUX
# Word: piloto, POS: NOUN
# Word: kabinoje, POS: NOUN
# Word: Išgyvenęs, POS: VERB
# Word: 34, POS: NUM
# Word: metų, POS: NOUN
# Word: amžiaus, POS: NOUN
# Word: įgulos, POS: NOUN
# Word: narys, POS: NOUN
# Word: lietuvis, POS: NOUN
# Word: nelaimės, POS: NOUN
# Word: metu, POS: NOUN
# Word: buvo, POS: AUX
# Word: orlaivio, POS: NOUN
# Word: salone, POS: NOUN
# Word: ,, POS: PUNCT
# Word: jo, POS: PRON
# Word: sužalojimai, POS: NOUN
# Word: lengvesni, POS: ADJ
# Word: Vilniaus, POS: PROPN
# Word: meras, POS: PROPN
# Word: Valdas, POS: PROPN
# Word: Benkunskas, POS: NOUN
# Word: informavo, POS: VERB
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: katastrofos, POS: NOUN
# Word: teritorijoje, POS: NOUN
# Word: bus, POS: AUX
# Word: paskelbta, POS: VERB
# Word: lokali, POS: ADJ
# Word: ekstremalioji, POS: ADJ
# Word: situacija, POS: NOUN
# Word: ,, POS: PUNCT
# Word: tai, POS: DET
# Word: padės, POS: VERB
# Word: pasirūpinti, POS: VERB
# Word: gyventojais, POS: NOUN
# Word: ,, POS: PUNCT
# Word: teritorijos, POS: NOUN
# Word: tvarkymu, POS: NOUN
# Word: ,, POS: PUNCT
# Word: pagalbos, POS: NOUN
# Word: teikimu, POS: NOUN
# Word: Pasak, POS: ADP
# Word: mero, POS: PROPN
# Word: ,, POS: PUNCT
# Word: pavojaus, POS: NOUN
# Word: žmonių, POS: NOUN
# Word: sveikatai, POS: NOUN
# Word: dėl, POS: ADP
# Word: oro, POS: NOUN
# Word: ,, POS: PUNCT
# Word: vandens, POS: NOUN
# Word: užterštumo, POS: NOUN
# Word: nėra, POS: VERB
# Word: Policijos, POS: NOUN
# Word: departamentas, POS: NOUN
# Word: kartu, POS: ADV
# Word: su, POS: ADP
# Word: Generaline, POS: ADJ
# Word: prokuratūra, POS: NOUN
# Word: pradėjo, POS: VERB
# Word: ikiteisminį, POS: ADJ
# Word: tyrimą, POS: NOUN
# Word: įvykio, POS: NOUN
# Word: aplinkybėms, POS: NOUN
# Word: išsiaiškinti, POS: VERB
# Word: Tiriamos, POS: VERB
# Word: visos, POS: DET
# Word: galimos, POS: VERB
# Word: avarijos, POS: NOUN
# Word: priežastys, POS: NOUN
# Word: Terorizmo, POS: NOUN
# Word: versija, POS: NOUN
# Word: neatmetama, POS: VERB
# Word: ,, POS: PUNCT
# Word: nes, POS: SCONJ
# Word: liepos, POS: NOUN
# Word: 19, POS: NUM
# Word: d, POS: X
# Word: iš, POS: ADP
# Word: Lietuvos, POS: PROPN
# Word: per, POS: ADP
# Word: „, POS: PUNCT
# Word: DHL, POS: X
# Word: Lietuva, POS: PROPN
# Word: “, POS: PUNCT
# Word: buvo, POS: AUX
# Word: išsiųsti, POS: VERB
# Word: savaime, POS: ADV
# Word: užsidegantys, POS: VERB
# Word: siuntiniai, POS: NOUN
# Word: ,, POS: PUNCT
# Word: jie, POS: PRON
# Word: sukėlė, POS: VERB
# Word: gaisrus, POS: NOUN
# Word: logistikos, POS: NOUN
# Word: centruose, POS: NOUN
# Word: Leipcige, POS: PROPN
# Word: ir, POS: CCONJ
# Word: Birmingame, POS: PROPN
# Word: Tik, POS: PART
# Word: per, POS: ADP
# Word: atsitiktinumą, POS: NOUN
# Word: krovinys, POS: NOUN
# Word: Leipcige, POS: PROPN
# Word: tuomet, POS: ADV
# Word: nebuvo, POS: VERB
# Word: pakrautas, POS: VERB
# Word: į, POS: ADP
# Word: orlaivį, POS: NOUN
# Word: Visgi, POS: ADV
# Word: pirmadienį, POS: NOUN
# Word: popiet, POS: PROPN
# Word: Vokietijos, POS: PROPN
# Word: vidaus, POS: NOUN
# Word: reikalų, POS: NOUN
# Word: ministerijos, POS: NOUN
# Word: atstovas, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kurį, POS: DET
# Word: citavo, POS: VERB
# Word: „, POS: PUNCT
# Word: Reuters“, POS: X
# Word: ,, POS: PUNCT
# Word: teigė, POS: VERB
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: nėra, POS: VERB
# Word: jokių, POS: DET
# Word: požymių, POS: NOUN
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: DHL, POS: X
# Word: krovininio, POS: ADJ
# Word: lėktuvo, POS: NOUN
# Word: katastrofa, POS: NOUN
# Word: Lietuvoje, POS: PROPN
# Word: gali, POS: VERB
# Word: būti, POS: AUX
# Word: susijusi, POS: VERB
# Word: su, POS: ADP
# Word: Vokietijos, POS: PROPN
# Word: valdžios, POS: NOUN
# Word: institucijų, POS: NOUN
# Word: vasarą, POS: NOUN
# Word: paskelbtu, POS: VERB
# Word: įspėjimu, POS: NOUN
# Word: apie, POS: ADP
# Word: lėktuvais, POS: NOUN
# Word: skraidintus, POS: VERB
# Word: paketus, POS: NOUN
# Word: su, POS: ADP
# Word: padegamaisiais, POS: VERB
# Word: įtaisais, POS: NOUN
# Word: Vilniaus, POS: PROPN
# Word: Gedimino, POS: PROPN
# Word: technikos, POS: NOUN
# Word: universiteto, POS: NOUN
# Word: (, POS: PUNCT
# Word: VILNIUS, POS: PROPN
# Word: TECH, POS: SYM
# Word: ), POS: PUNCT
# Word: Antano, POS: PROPN
# Word: Gustaičio, POS: PROPN
# Word: aviacijos, POS: NOUN
# Word: instituto, POS: NOUN
# Word: lektorius, POS: NOUN
# Word: Vincas, POS: PROPN
# Word: Šnirpūnas, POS: PROPN
# Word: LRT, POS: X
# Word: lt, POS: X
# Word: teigė, POS: VERB
# Word: ,, POS: PUNCT
# Word: kad, POS: SCONJ
# Word: tokių, POS: DET
# Word: įvykių, POS: NOUN
# Word: priežasčių, POS: NOUN
# Word: gali, POS: VERB
# Word: būti, POS: AUX
# Word: ne, POS: PART
# Word: viena, POS: NUM
# Word: Anot, POS: ADP
# Word: jo, POS: PRON
# Word: ,, POS: PUNCT
# Word: vis, POS: CCONJ
# Word: dėlto, POS: X
# Word: dažniausiai, POS: ADV
# Word: tai, POS: DET
# Word: susiję, POS: VERB
# Word: su, POS: ADP
# Word: žmogiška, POS: ADJ
# Word: klaida, POS: NOUN

# %%
# Creating a DataFrame with POS tags and their frequencies
df = pd.DataFrame(pos_counts.items(), columns = ["POS", "Frequency"])

# Sorting the DataFrame by frequency
df = df.sort_values(by = "Frequency", ascending = False)

# Plotting the bar chart
plt.figure(figsize = (10, 6))  # Set the figure size
ax = sns.barplot(x = "Frequency", y = "POS", data=df, palette = "viridis")

# Add labels and title
plt.xlabel("Frequency")
plt.ylabel("Part-of-Speech (POS) Tags")
plt.title("Frequency of POS Tags in Lithuanian Sentences (Combined Dataset)")

# Adding values on the columns
for i, v in enumerate(df["Frequency"]):
    ax.text(v + 0.1, i, str(v), color='black', va='center', fontsize=12)
    
# Saving the graph
plt.savefig('pos_tag_frequency_plot_combined.png', dpi=300, bbox_inches='tight')

# Showing the plot
plt.show()
# Out:
# /var/folders/8n/bffnmy712gb5xcnz6597rjb80000gn/T/ipykernel_75404/3483164574.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x = "Frequency", y = "POS", data=df, palette = "viridis")

# %%
# POS tag counting for each sentence
sentence_pos_counts = []

# POS tagging for each sentence
for sentence in combined_sentences:
    # Process the sentence using the Stanza pipeline
    doc = nlp(sentence)
    
    # Count POS tags for this sentence
    pos_counts = Counter(word.upos for sent in doc.sentences for word in sent.words)
    sentence_pos_counts.append(pos_counts)

# Aggregating POS counts across all sentences
total_pos_counts = Counter()
for pos_counts in sentence_pos_counts:
    total_pos_counts.update(pos_counts)

# Calculating the average number of each POS tag per sentence
average_pos_counts = {tag: total / len(combined_sentences) for tag, total in total_pos_counts.items()}

# Displaying the results
print("Average number of each POS tag per sentence (combined dataset):")
for tag, avg in average_pos_counts.items():
    print(f"{tag}: {avg:.3f}")
# Out:
# Average number of each POS tag per sentence (combined dataset):
# NOUN: 1.022
# PROPN: 0.166
# PART: 0.194
# ADV: 0.393
# VERB: 0.754
# PRON: 0.532
# PUNCT: 0.418
# CCONJ: 0.186
# AUX: 0.058
# ADP: 0.181
# ADJ: 0.186
# NUM: 0.144
# SCONJ: 0.068
# X: 0.080
# DET: 0.109
# INTJ: 0.005
# SYM: 0.002
